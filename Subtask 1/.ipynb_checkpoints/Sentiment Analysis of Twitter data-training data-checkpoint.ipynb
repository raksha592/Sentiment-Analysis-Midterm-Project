# %% [markdown]
# ## Task 1: Sentiment analysis of twitter and stockwits data

# %%
import json
from pprint import pprint
import matplotlib as mpl
import matplotlib.pyplot as pltfrom 

from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
 
import numpy as np
import pandas as pd

from keras.layers import Flatten
from keras import regularizers

# %% [markdown]
# ### Loading data from JSON

# %%
with open('Microblog_Trainingdata.json') as data_file:    
    Microblog_Trainingdata = json.load(data_file)

for i in range(0,len(Microblog_Trainingdata)):
    Microblog_Trainingdata[i]['spans']=Microblog_Trainingdata[i]['spans'][0]
    Microblog_Trainingdata[i]['sentiment score']=float(Microblog_Trainingdata[i]['sentiment score'])
#pprint(Microblog_Trainingdata)
with open('Microblog_Trialdata.json') as data_file:   
    Microblog_Trialdata = json.load(data_file)
    

#pprint(data)
for i in range(0,len(Microblog_Trialdata)):
    Microblog_Trialdata[i]['spans']=Microblog_Trialdata[i]['spans'][0]
    Microblog_Trialdata[i]['sentiment score']=float(Microblog_Trialdata[i]['sentiment score'])

# %%
with open('Microblogs_Testdata.json') as data_file:   
    Microblogs_Testdata = json.load(data_file)
    
#pprint(Microblog_Testdata)

# %%
for i in Microblog_Trialdata:
    Microblog_Trainingdata.append(i)

# %%
def lower_keys(x):
    if isinstance(x, list):
        return [lower_keys(v) for v in x]
    elif isinstance(x, dict):
        return dict((k.lower(), v.lower() if isinstance(v, str) else v) for k, v in x.items())
    else:
        return x
Microblog_Trainingdata=lower_keys(Microblog_Trainingdata)

# %%
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
import string
def stringClean( inputString ) :
    return inputString.translate(str.maketrans('','',string.punctuation)).encode("ascii", errors="ignore").decode()

# %%
def removeStopWords(inputString):
    splitString = inputString.split()
    for word in stop:
        for s in splitString:
            if s == word:
                splitString.remove(s)
    return " ".join(splitString)

# %%
from sklearn.metrics.pairwise import cosine_similarity
def calculateCosineSimilarity( pVal,gVal ):
    similarity = cosine_similarity(pVal,gVal)
    pNorm = np.linalg.norm(pVal)
    gNorm = np.linalg.norm(gVal)
    wt = pNorm/gNorm
    return wt * similarity #[0][0]

# %% [markdown]
# ### Loading Testing and Testing data

# %%
maxlen = 0

X_train = []
X_trial=[]
Y_trial=[]
X_test = [Microblog['spans'] for Microblog in Microblogs_Testdata]
Y_train = []
Y_test = []
output=[]
for Microblog in Microblog_Trainingdata :
    X_train.append(removeStopWords(stringClean(Microblog['spans'])))
    Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
    output.append(Microblog['sentiment score'])
    if maxlen < len(Microblog['spans'].split()) :
        maxlen = len(Microblog['spans'].split())

#for Microblog in Microblog_Trialdata :
 #   X_train.append(Microblog['spans'])
  #  Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
   # if maxlen < len(Microblog['spans'].split()) :
    #    maxlen = len(Microblog['spans'].split())


print(len(X_train)+len(X_test), len(Y_train))
# Out:
# 2510 1710

# %% [markdown]
# ### Selecting top 15000 words using tokenizer library in keras

# %%
tokenizer = Tokenizer(num_words=15000)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen)
data.shape
# Out:
# (1710, 25)

# %% [markdown]
# ### LSTM Model

# %%
model = Sequential()
model.add(Embedding(15000, 32, input_length=maxlen))
#model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='leakyrelu'))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Flatten())
model.add(LSTM(32, dropout=0.3, recurrent_dropout=0.15))
#, kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l1(0.01)
model.add(Dense(4, activation='tanh'))
model.add(Dense(1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, 25, 32)            480000
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_43 (Dense)             (None, 4)                 132
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 488,457
# Trainable params: 488,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(data, np.array(Y_train), validation_split=0.2, epochs=15,verbose = 1)
# Out:
# Train on 1368 samples, validate on 342 samples
# Epoch 1/15
# 1368/1368 [==============================] - 3s - loss: 1.3127 - acc: 0.4020 - val_loss: 0.6555 - val_acc: 0.6374
# Epoch 2/15
# 1368/1368 [==============================] - 1s - loss: 0.6559 - acc: 0.6404 - val_loss: 0.6482 - val_acc: 0.6404
# Epoch 3/15
# 1368/1368 [==============================] - 1s - loss: 0.6433 - acc: 0.6352 - val_loss: 0.6413 - val_acc: 0.6404
# Epoch 4/15
# 1368/1368 [==============================] - 1s - loss: 0.6267 - acc: 0.6528 - val_loss: 0.6215 - val_acc: 0.6491
# Epoch 5/15
# 1368/1368 [==============================] - 1s - loss: 0.5697 - acc: 0.7507 - val_loss: 0.5795 - val_acc: 0.6725
# Epoch 6/15
# 1368/1368 [==============================] - 1s - loss: 0.4709 - acc: 0.8501 - val_loss: 0.4935 - val_acc: 0.7807
# Epoch 7/15
# 1368/1368 [==============================] - 1s - loss: 0.3287 - acc: 0.9115 - val_loss: 0.4483 - val_acc: 0.7719
# Epoch 8/15
# 1368/1368 [==============================] - 1s - loss: 0.2466 - acc: 0.9159 - val_loss: 0.5809 - val_acc: 0.7719
# Epoch 9/15
# 1368/1368 [==============================] - 1s - loss: 0.1925 - acc: 0.8604 - val_loss: 0.7467 - val_acc: 0.7222
# Epoch 10/15
# 1368/1368 [==============================] - 1s - loss: 0.1472 - acc: 0.8151 - val_loss: 0.8383 - val_acc: 0.7018
# Epoch 11/15
# 1368/1368 [==============================] - 1s - loss: 0.1247 - acc: 0.7946 - val_loss: 0.6932 - val_acc: 0.7339
# Epoch 12/15
# 1368/1368 [==============================] - 1s - loss: 0.1342 - acc: 0.7909 - val_loss: 0.9470 - val_acc: 0.6784
# Epoch 13/15
# 1368/1368 [==============================] - 1s - loss: 0.1095 - acc: 0.7814 - val_loss: 1.0084 - val_acc: 0.6842
# Epoch 14/15
# 1368/1368 [==============================] - 1s - loss: 0.1052 - acc: 0.7580 - val_loss: 1.1005 - val_acc: 0.6374
# Epoch 15/15
# 1368/1368 [==============================] - 1s - loss: 0.1075 - acc: 0.7442 - val_loss: 0.9277 - val_acc: 0.6784

# %%
sequences = tokenizer.texts_to_sequences(np.array(X_train))
data = pad_sequences(sequences, maxlen)
predictions = model.predict(data)
for i in range(len(predictions)):
    print(Microblog_Trainingdata[i]['spans'],Microblog_Trainingdata[i]['sentiment score'],"%.3f" % predictions[i])
# Out:
# watching for bounce tomorrow 0.366 0.976
# record number of passengers served in 2015 0.638 0.982
# out $nflx -.35 -0.494 -0.532
# looking for a strong bounce 0.46 0.974
# very intrigued with the technology and growth potential 0.403 0.982
# short worked 0.0 -0.744
# overbought -0.296 -0.814
# absolute garbage still up -0.546 -0.607
# biggest market losers -0.438 -0.864
# love this company long time. 0.408 0.957
# $goog $googl would suck -0.398 -0.638
# who won't pay anymore -0.349 -0.824
# no edge offered 0.025 0.979
# runs into the 50sma on the acquisition news 0.486 0.980
# t can't go down 0.308 0.971
# now seems like its helping the downtrend -0.372 -0.617
# mastered their supply chain 0.461 0.980
# most bullish stocks on twitter during this dip 0.408 0.980
# big dumping -0.699 -0.360
# trade continuing very nicely from yesterday 0.495 0.982
# in from 3.61 0.306 0.972
# stochastic overbought -0.385 -0.892
# unusual call buying 0.336 0.982
# reserves are in decline 0.279 0.975
# all on a longer-term, technical swing long basis. 0.591 0.982
# insiders are selling -0.351 0.127
# what goes up... -0.514 -0.328
# if $249.84 breaks we see $245 then $240 -0.519 -0.676
# let's see a big bounce 0.361 0.964
# i don't think it will move $fb in the short term -0.042 -0.647
# above 2.25 and it could get going? 0.26 0.958
# hold 0.099 0.944
# may feed off $tsla momentum run lately. 0.359 0.981
# possible double bottom set up 0.29 0.969
# trading at all-time high 0.887 0.977
# if positive outcome w/ lung study5/8 we may see a 13d filing by soros 0.33 0.981
# put the chum out there at key support then next level down -0.32 -0.517
# #tesla: great company, bad #stock $tsla -0.065 -0.175
# good idea buy half this and half bac? 0.329 0.979
# alibaba ipo hoopla canâ€™t hide risk of chinese stocks -0.39 -0.542
# all on a longer-term, technical swing long basis. 0.591 0.982
# on the fence with this one 0.0 -0.619
# stay long apple 0.337 0.978
# looks like drought conditions in soil already -0.122 -0.353
# unusual call activity 0.332 0.982
# $mdxg -0.402 -0.608
# biggest market losers -0.438 -0.864
# hip sinking? -0.411 -0.486
# can't imagine shorts wanting to go into the weekend without taking care of their position 0.36 0.982
# nice volume 0.113 0.951
# $simo basing nice 0.408 0.980
# big money is pouring into facebook from all directions 0.645 0.981
# placed an order to sell 5 shares -0.379 -0.221
# go $fb go 0.302 0.970
# out $bidu for now -0.221 -0.586
# short setups looking nice....really nice -0.464 -0.533
# defying the downturn 0.407 0.980
# but man this is one to be careful with -0.291 -0.766
# downgrade -0.463 -0.801
# short $tsla calls -0.618 -0.278
# was looking for a long entry but today's price action wasn't appealing 0.215 0.980
# just follow the trend, follow the money flow 0.165 0.981
# tapping on 10.00 0.224 0.977
# will re-enter short on bounce.. -0.46 -0.090
# found some good bull setups this week 0.448 0.981
# all going down -0.559 0.008
# so volatile! -0.131 -0.315
# sold my 81 calls 0.328 0.771
# i'm watching(and buy targets) 0.344 0.978
# beats the estimize eps consensus by 6c and the estimize revenue consensus by 0.366 0.981
# short percent of float 16.80% -0.16 -0.542
#  -0.373 0.799
# add to $fxp $skf positions 0.5 0.981
# long 0.488 0.979
# bottom losses -0.473 -0.807
# ure wish bad news came out just a few days earlier -0.221 -0.722
#  0.0 0.799
# $wmt, 13% 0.382 0.958
# added 0.274 0.977
# mkt fell on debt downgrade -0.159 -0.886
# $fcx +3.53% 0.339 0.939
# been very frustrating -0.136 -0.329
# thanks for the short -0.264 -0.725
# need to break $4 again 0.132 0.965
# fed cuts rates forecast 0.449 0.977
# stochastic overbought -0.516 -0.892
# very tight price 0.0 -0.137
# #oversold 0.406 0.978
# a great step for #china to let $fb in 0.417 0.974
# new squeeze plays -0.339 -0.387
# $crm seems a little to high also -0.344 -0.437
# pie in the sky 0.365 0.981
# moved upper bollinger band 0.498 0.982
# highest call to put ratio 0.348 0.982
# offers will take place until next week 0.409 0.980
# currently it is the shorts rejoicing -0.54 -0.618
# breaking out when the market pulls back 0.413 0.962
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.982
# buy the dip' 0.38 0.934
# $mdxg -0.361 -0.608
# blackberry messenger is second only to facebook in user loyalty 0.158 0.982
# headed to all time highs 0.407 0.963
# your shit is broke -0.348 -0.151
# buy 0.458 0.940
# weak open and it goes r/g within first 30 mins -0.229 -0.483
# down $2.84 premarket -0.512 -0.230
# guess who sold off about $800 million in $mdlz -0.428 -0.532
# buying on weakness 0.511 0.948
# shareholders welcome marriott-starwood deal 0.322 0.980
# peachy prospects 0.339 0.980
# another sell rating, sell rating -0.513 -0.720
# nice day rally! 0.529 0.980
# nice day rally! 0.529 0.980
# quality stocks with high cash returns 0.274 0.981
# led light bulb prices rise in japan 0.054 0.981
# closed buy 0.466 0.979
# highest down volume in last 10 days -0.31 -0.127
# with $ibb back over support 0.285 0.808
# long into earnings 0.484 0.980
# considering yahoo bid 0.288 0.982
# after weeks of steady gains,advances in mkt breadth slowe -0.146 -0.606
# i will buy aggressively if pulls back 0.386 0.981
# nice day rally! 0.529 0.980
# gets 26 patents and goes down -0.373 -0.575
# buying on weakness 0.511 0.948
# led light bulb prices rise in japan 0.054 0.981
# is a later riser, 0.203 0.974
# could that have been a strategy to exit shorts before the big pop? 0.316 0.979
# piper upgrades symantec on improving renewal rates and enterprise growth 0.525 0.982
# look for strong solar rebound today! 0.304 0.982
# i think the dnf crew can get this $nflx short into the next 30 days heading into earnings -0.308 -0.760
# red $aapl dragging down $qqq -0.5 -0.663
# cuts outlook down -0.236 -0.672
# weakness continues again. -0.41 0.311
# watchlist top stocks 0.342 0.980
# long 0.428 0.979
# joint bid for yahoo's internet assets 0.228 0.982
# patience pays off 0.272 0.976
# bad governance -0.331 -0.696
# bottom losses -0.756 -0.807
# sales numbers still holding up so well 0.315 0.974
# i just feel the people who are buying are the same ones with their finger on the sell button -0.054 -0.763
# gap filled 0.226 0.977
# debt crisis entered a dangerous new phase -0.331 -0.750
# just about to break out to new highs 0.469 0.981
# next resist is 64.40's 0.201 0.972
#  0.0 0.799
# looks really toppy right here. -0.191 -0.510
# this will pop after the holiday 0.555 0.980
# breakup will cost billions -0.397 -0.645
# news breaks first and fastest on twitter $twtr 0.364 0.972
# overbought -0.296 -0.814
# continues to consolidate above previous break out area. 0.375 0.978
# good to load up be confident 0.281 0.981
# long 0.394 0.979
# buy call! 0.095 0.980
# companies shld be worried about icloud -0.329 -0.862
# $spy -0.05% 0.028 0.975
# but decent supt here-expect some upside 0.302 0.982
# monday sold -0.37 -0.680
# sector has been taking a beating recently, could be positive here 0.361 0.982
# at 11x earnings, $aapl is a steal 0.561 0.959
# multi top on $mcd -0.474 -0.581
# us adds 321k jobs in november 0.243 0.982
# why is $fb falling? -0.304 -0.414
# calls for nice gains 0.396 0.981
# someone bought lots of calls mon 0.444 0.982
# moving up again 0.12 0.889
# $ea points to the two facebook games 0.048 0.981
# ready to exit bankruptcy 0.298 0.975
# starting to creep up 0.28 0.728
# looks like bo coming 0.36 0.979
# 2m this year would be amazing 0.151 0.971
# moved upper bollinger band 0.498 0.982
# $gogo short -0.318 -0.757
# eu getting closer to charging google over android -0.319 -0.771
# supermarket stocks rally as tesco plans to axe non-core uk assets 0.346 0.981
# china winners 0.452 0.974
# looks like an ascending channel 0.363 0.977
# patience on the buy precedes patience on the sell 0.0 -0.476
# oil to break out 0.666 0.971
# brand name is to big for it to fail 0.226 0.981
# top #netpayoutyields 0.426 0.978
# long $amzn oct $240 calls 0.628 0.981
# under pressure along with the market 0.014 0.979
# patience pays off 0.272 0.976
# stock splits are lipstick on a pig! -0.347 -0.348
# making new highs for the year 0.53 0.980
# held up well after the big gains! 0.695 0.979
# wait and see before taking any action 0.0 -0.641
# markets are still acting weak -0.443 -0.853
# breaking below support -0.397 0.922
# sold 20% of our concentrated stake -0.344 -0.318
# want to go this morning 0.28 0.980
# cracking lower early -0.511 -0.717
# $fb & $ibb down -0.527 0.023
# higher in afternoon trade 0.243 0.980
# oil to break out 0.666 0.971
# added $sso 64.33 0.626 0.982
# $fb $112 calls .55 entry 0.509 0.972
# is tiffany's overvalued -0.25 -0.608
# $intc & $aapl strong 0.722 0.965
# after crunching #'s 0.477 0.959
# biggest gainers today large caps 0.556 0.982
# $aapl a new long if 110.61 is broke 0.379 0.981
# added to our $gild position 0.422 0.982
# largest online gaming market 0.226 0.970
#  -0.541 0.799
# bottom losses -0.659 -0.807
# stopped out even from yesterdays entry -0.413 -0.708
# micron shares pounded on fears of loss of business from apple -0.596 -0.177
# closed buy 0.466 0.979
# over 225 million new internet users are being added globally every year 0.337 0.982
# $uvxy broke 10.00 amazing!!! 0.265 0.981
# long leaps 0.438 0.981
# looks like that support line around 24.90 held 0.331 0.982
# retreats like clockwork -0.488 -0.534
#  0.0 0.799
# its time to sell banks -0.763 -0.805
# upgrades to outperform 0.61 0.981
# unusual call buying 0.336 0.982
# holding strong 0.192 0.979
# three of my hot stocks today 0.461 0.981
# bulls are out 0.323 0.972
# patents system 0.271 0.976
# markets back in black for 2016 0.271 0.979
# the losers buying $tsla at these levels -0.545 -0.830
# adding $expe and $pcln to the mix soon 0.554 0.982
# today's losers -0.317 -0.762
# not feel terribly good -0.126 -0.468
# $spy up only 0.6% 0.228 0.971
# record number of passengers served in 2015 0.638 0.982
# while we think $tnh is a winner 0.415 0.977
# reiterated 'outperform' rating 0.694 0.977
# airplanes are still flying 0.262 0.970
# $mtd $341 from $325 0.362 0.979
# bond buying is signaling some bad moves for the market -0.361 -0.373
# i see more downside in next two weeks -0.477 -0.636
# has just about run its course -0.449 -0.314
# biggest market losers -0.438 -0.864
# loaded up on $bsx yesterday 0.664 0.980
# notable gainers among liquid option names this morning 0.513 0.981
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.026 0.982
# 5-star analyst @brianwieser from pivotal research upgraded rating on $googl to buy 0.561 0.980
# santa rally 0.22 0.977
# iphone 6s is still better than galaxy s7 0.385 0.976
# didn't factor in anything other than google and repeated good earnings 0.102 0.980
# facebook is succeeding where google should have dominated 0.531 0.981
# $uco +4.44% 0.442 0.979
# up on day and will continue a surge next week. 0.509 0.980
# facebook stock is now +$72 0.272 0.981
# ripe for a squeeze again -0.216 -0.657
# biggest market losers -0.438 -0.864
# with personal story sharing declining -0.393 -0.839
# upgrades 0.334 0.975
# saying this is a peak = fear mongering 0.329 0.977
# the most trending 0.216 0.972
# who won't pay anymore -0.349 -0.824
# still they are saying bullish lol -0.038 -0.195
# today's bull flag 0.2 0.973
# growth rate of approximately 122.0% to 124.9%. 0.305 0.982
# lots of nice setups in energy  0.293 0.980
# bad governance -0.331 -0.696
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# landed in $ea 0.422 0.977
# bought $skf as a hedge 0.466 0.978
# transports always lead the way 0.594 0.982
# here is no case here 0.18 0.951
# $joe getting attention. no.2 on nyse 100 top buying list 0.788 0.982
# short setups looking nice....really nice -0.464 -0.533
# highest close since 0.387 0.954
# should bring $spx down into the close. -0.462 -0.285
#  0.295 0.799
# money flow & stochastic dropping -0.577 -0.845
# 9% run for this watch list winner 0.066 0.982
# have had 2 wks of fund inflows for the first time 0.58 0.972
# $goog $googl would suck -0.404 -0.638
# ses warrants to buy $1.17b & 14.97% of amerisourcebergen(pbr16) shares 0.301 0.980
# not every idea $amzn has is bad. 0.235 0.970
# looks primed 0.4 0.976
# yahoo extends bidding deadline as interest grows 0.613 0.981
# good news for domestic automakers 0.413 0.978
# mrkt needs to washout -0.055 -0.767
# valuation is high -0.355 -0.406
# $wfm dropping below $30 again -0.499 -0.419
# $htz -0.341 -0.354
# recall adds to reliability issues -0.267 -0.383
# i'm out -0.14 0.117
# think i may just start to avoid bios -0.23 -0.362
# lvmh affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.982
# no crying you get out -0.462 -0.511
# trying to break daily trend line! 0.485 0.982
# went long on this 0.449 0.978
# if bulls lucky enuff to get an upside gap fill, better take it 0.054 0.981
# wouldn't call any of these banks h+s quite yet 0.335 0.980
# banks to implode -0.298 -0.499
# new recommendation from carl kirst of bmo capital markets 0.566 0.982
# near a buy point last week 0.102 0.975
# pc shipments drop to lowest level since 2007 -0.452 -0.710
# momentum building for breakout trigger 0.592 0.982
# consistent gains but small 0.219 0.980
# $aapl cult on stocktwits is actually disgusting -0.151 -0.799
# higher in afternoon trade 0.243 0.980
# sector stocks leading today 0.454 0.982
# $adbe flying 0.361 0.950
# tesla to recall 2,700 model x suvs over seat issue -0.31 -0.781
# back in 0.383 0.901
# us adds 321k jobs in november 0.243 0.982
# under pressure along with the market 0.014 0.979
# cash & cheap financing is fueling a wave of acquisitions 0.39 0.982
# worst #sentiment for #sp1500 #stocks at market close -0.479 -0.392
# gold going parabolic 0.442 0.973
# i would take profits if you have them -0.244 -0.707
# never widen your stop to stay in a trade -0.412 -0.408
# slips alongside shares on nsa leak news -0.198 -0.696
# best outperformers ranked 0.492 0.981
# $googl is setting up above its 50-day moving average 0.696 0.967
# weakest sector this year -0.458 -0.264
# tesla is recalling 2,700 model x cars -0.291 -0.513
# unusual call activity 0.421 0.982
# wish had my puts bac -0.485 -0.691
# see if they maintain 15% yield 0.078 0.980
# look at all the shorts running for cover 0.375 0.976
# as with all 3x etfs, it is subject to decay due to daily rebalancin -0.234 -0.600
# signs of life are emerging :) 0.27 0.979
# markets back in black for 2016 0.271 0.979
# i rather be neutral to bullish rather than bearish 0.185 0.974
# diversifies. adds international exposure 0.219 0.975
# out $aapl -0.27 -0.145
# capped -0.172 -0.428
# long on 0.185 0.979
# $googl patents turn signal detector for autonomous cars. 0.241 0.980
# moves up a little more today off of cup and handle 0.306 0.981
# makes less profit than the sales of $aapl watch -0.641 -0.387
# comparable store sales -4% -0.441 -0.514
# making higher highs & higher lows as it consolidates over past several weeks 0.478 0.981
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.980
# sold at 139.26 and flat -0.695 -0.773
# suddenly realizing -0.147 -0.578
# long 0.488 0.979
# $fit and $sune have not changed. -0.179 -0.365
# $nugt fucking beast mode, kicking shirts in the nugt pouch 0.665 0.981
# my hospital reits are slaughtered -0.399 -0.715
# i want to cry -0.595 -0.291
# 3 top japan etfs to surge higher in 2h 0.456 0.982
# new bullish conversation activity 0.461 0.982
# bottom losses -0.411 -0.807
# just follow the trend, follow the money flow 0.165 0.981
# short squeeze ready to upside w crossing important technical level 0.219 0.980
# i'll take the other side of that trade 0.422 0.982
# i love this stock/co -0.125 -0.130
# no choice but to be positve 0.323 0.979
# word on the street is that allergen is looking at endo international 0.472 0.981
# buy $wynn 0.489 0.974
# $tsla hype the news -0.073 0.244
# three black crows followed by a potential bear flag -0.569 -0.540
# looking for a strong bounce 0.46 0.974
# trails $msft $orcl $goog $crm $adbe 0.177 0.979
# stay with best of breed 0.417 0.981
# nice day rally! 0.529 0.980
# orgetting the potential relative value of its users 0.316 0.982
# looking goo for 35.80s break out. it must hold 35.40s 0.307 0.982
# usio ops are profitable -0.362 -0.601
# bot $gmcr 75 nov call 0.614 0.982
# reasons for caution about chinese stocks -0.317 -0.555
# outperforms 0.525 0.973
# earish trader bets $550k that stock will sell off -0.493 -0.744
# congrats shorts -0.494 -0.332
# downbeaten stocks may be ripe for buys 0.316 0.982
# picked some up 0.653 0.973
# worst performers today -0.351 -0.182
# nt done good with that name so will pass it -0.319 -0.288
# its been nothing but down -0.43 -0.075
# bullish ma crossovers 0.457 0.978
# player onto the 211 puts -0.652 -0.833
# someone wants in 0.29 0.965
# $pcln back over 'up' trendline 0.308 0.966
# found some good bull setups this week 0.448 0.981
# is just humming easing overbought -0.404 -0.872
# just follow the trend, follow the money flow 0.165 0.981
# is up 19% 0.128 0.874
# sector stocks leading today 0.454 0.982
# ron johnson tried, and failed, to inject a bit of apple culture into jc penney -0.335 -0.641
# not the prettiest candlesticks 0.0 -0.768
# agree risky watching very closely -0.375 -0.721
# breakout from the consolidation zone 0.724 0.981
# took small posistion on $tsla -0.114 -0.625
# flop would just get everyone running to the fences. -0.546 -0.429
# unusual call activity 0.421 0.982
# worst #sentiment for #sp1500 #stocks at market close -0.479 -0.392
# new squeeze plays -0.339 -0.387
# people are calling it bearish -0.148 -0.736
# long $sq 0.325 0.981
# fader play here -0.219 -0.491
# all sectors improved in bullish breadth. 0.647 0.980
# top-rated 0.428 0.973
# stochastic overbought -0.516 -0.892
# china february retail sales: e-commerce remains resilient 0.383 0.979
# china february retail sales: e-commerce remains resilient 0.383 0.979
# large cap tech is finally trying to catch up with the rest of the market 0.373 0.981
# stock dropping hard... -0.626 -0.308
# recall will not impact financial results 0.198 0.979
#  0.39 0.799
# very weak res -0.263 -0.827
# gap up today?  0.454 0.974
# top-rated 0.428 0.973
# coming from far could go far 0.298 0.982
# lnkd is great but doesnt the potential side with fb 0.484 0.978
# long $endp @ $26.23 on $agn b/o rumor 0.57 0.982
# oil back above 60 0.543 0.966
# short setups looking nice....really nice -0.464 -0.533
# gist of downgrades was apple failed to make a phone th -0.312 -0.759
# another 3% gain in $rigl 0.378 0.958
# $stx 0.334 0.973
# $grpn having a much better day than $fb -0.285 -0.033
# stocks insiders are bullish on 0.433 0.975
# hipments on track to exceed forecasts 0.367 0.981
# lvmh affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.982
# cover all 0.114 0.975
# ss interest rose on 12/15 on day before we hit our lows. http://stks.co/c1qkr -0.405 -0.467
# most bullish stocks on twitter during this dip 0.408 0.980
# $fcx 1.9% now -0.327 0.085
# first quarter is amazing 0.322 0.982
# $sap q1 disappoints as #software licenses down -0.431 -0.554
# today's losers -0.317 -0.762
# looking for a sharp move up in equities 0.368 0.972
# gap fill coming up 0.511 0.979
# report: apple signs up for google's cloud -0.38 0.788
# $fb to $107 tomorrow!? 0.539 0.976
# over 225 million new internet users are being added globally every year 0.337 0.982
# covered call 0.329 0.982
# long 0.66 0.979
# i've been picking up railroad stocks for the retirement acct 0.441 0.982
# when there is turmoil in the mena region shippers perform 0.397 0.981
# going back in, but slowly 0.119 0.938
# down 12% since i alerted it a short sell on 3-25 -0.391 -0.657
# bet the farm on 0.395 0.978
# interest heats up for @yahoo $yhoo 0.413 0.981
# the parties over -0.223 -0.649
# stocks higher in afternoon trade 0.314 0.982
# highest call to put ratio 0.348 0.982
# apparently intel thinks women should get paid the same as men 0.447 0.981
# $gs is looking weak while this market is moving higher not a good sign -0.597 0.161
# 1mil buy order at 0.426 0.968
# top stocks 0.376 0.977
# top stocks in 2015 are ready to lead again in 2016 0.414 0.982
# 640m globally this week on avengers really sick ,stan lee is a beast 0.24 0.982
# plus its irish based 0.226 0.981
# in 0.646 0.799
# 13f shows new stakes in  0.468 0.981
# gap up today?  0.446 0.974
# breakout watch 0.352 0.980
# short setups looking nice....really nice -0.464 -0.533
# getting a lot of hype 0.095 0.891
# court tells states to leave $goog alone 0.291 0.981
# got a nice push today 0.28 0.978
# unloaded $16,673 worth of the ensign group, inc. (nasdaq:ensg) shares -0.46 -0.404
# $23 by the end of the week..did you snatch ur 21 0.257 0.980
# continues its rally 0.538 0.914
# it with lawsuit from russian search engine -0.17 -0.750
# #oversold 0.406 0.978
# have had 2 wks of fund inflows for the first time 0.58 0.972
# mu down 2.3% today and down 8.9% -0.469 -0.460
# unusual call buying 0.336 0.982
# $ko:us #coca-cola co 19oct positive 0.646 0.982
# sales weak -0.515 -0.837
# just broke resistance 0.598 0.956
# $ffiv up 7$ 0.32 0.978
# bot $chrw 0.437 0.979
# break-out thru 50 & 200- dma 0.504 0.981
# now up 2.2% 0.523 0.971
# bid for reargument denied by judge -0.354 -0.718
# with upcoming first support in a few days or weeks! 0.274 0.960
# $cafn cachet financial solutions surging forward today post earnings up +13.26% 0.418 0.982
# lots of green on the 5 min 0.318 0.981
# looking to buy 0.32 0.907
# i don't think is the right fit -0.296 -0.862
# stochastics finally starting to turn up 0.702 0.981
# another sell rating -0.389 -0.465
# very nice breakout on a very nice stock 1.0 0.982
# launching shopping bot 0.348 0.980
# buy these 3 stocks while there's blood in the streets 0.415 0.982
# goldman sachs reiterates conviction buy on 0.334 0.981
# losers -0.383 -0.831
# long term uptrend intract so far 0.368 0.981
# the most trending 0.216 0.972
#  0.0 0.799
# will be adding on dips 0.154 0.975
# added long at friday close 0.513 0.982
# losing $400m of $aapl's business -0.015 -0.821
# #oversold 0.406 0.978
# picking up a couple shares of $goog today 0.364 0.975
# my broker has no shorts who has them? -0.533 -0.343
# sales numbers still holding up so well 0.315 0.974
# trying to drag $bidu with it. -0.524 -0.752
# over 225 million new internet users are being added globally every year 0.337 0.982
# downgraded to neutral at deutsche bank -0.446 -0.739
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.982
# buy zone today 0.285 0.979
# big picture is brilliant 0.355 0.981
# bounce right now has no vol, more vol when it slid 0.19 0.962
# another story stock with an unhappy ending -0.426 -0.686
# love it 0.648 0.917
# most bullish stocks on twitter during this dip 0.408 0.980
# mark zuckerberg is doing an amazing job 0.326 0.982
# today's top gainers 0.447 0.980
# has had a history of a lack of pr -0.21 -0.709
# closed friday with the rs line in new highs 0.371 0.982
# look out belooooooowwww -0.85 -0.139
# whole semiconductor space looks interesting 0.328 0.981
# to combine in $37 billion deal 0.241 0.978
# peaks above hod 0.318 0.980
# problem for shorts 0.358 0.944
# awesomely bullish stocks 0.68 0.981
# there is a good base building 0.228 0.980
# biggest market losers -0.438 -0.864
# highest call to put ratio 0.348 0.982
# sold to close $qqq puts for +34% -0.059 -0.464
# ooks pretty bullish for now 0.323 0.982
# looks really interesting on drop 0.579 0.932
# covered some shorts 0.294 0.969
# add to 0.483 0.975
# triple top forming. 0.028 0.980
# will end up selling for pennies on the dollar -0.441 -0.405
# looking sexy this morning 0.678 0.973
# whole foods shareholders vote down activist initiatives -0.076 -0.541
# imagine $aapl tv impact!! $$$ 0.24 0.978
# southwest is at its lowest multiple ever 0.106 0.982
# still too early for an entry -0.387 -0.189
# moved upper bollinger band 0.498 0.982
# today i bought more 0.087 0.980
# won't have anyone buying products -0.429 -0.643
# short setups looking nice....really nice -0.464 -0.533
# still long term fan! 0.377 0.981
# what a nice reversal. 0.318 0.976
# tripadvisor jumps on m&a rumors 0.47 0.981
# $tsla recalls 2,700 model x vehicle -0.336 -0.808
# long tech 0.384 0.981
# breakout should be confirmed 0.448 0.976
# best performers 0.376 0.951
# very tight on the avail stock for shorting -0.406 -0.778
# get into $wfm and $mjn 0.415 0.976
# stochastic overbought -0.516 -0.892
# bounced off target buy area -0.299 -0.111
# oversold 0.43 0.978
# double top reject -0.341 -0.333
# added. 0.47 0.977
# working on cuba deals 0.419 0.981
# dividend hike green light 0.316 0.981
# i am excited about all these plays 0.322 0.968
# commodity weakness -0.376 -0.362
# $fb small flong 109.25 via calls 0.352 0.981
# had a nice breakout of the recent consolidation 0.452 0.982
# sells flat..i am out.. -0.541 -0.744
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# reserves are in decline 0.279 0.975
# this pull back of -0.03 0.142
# pie in the sky 0.365 0.981
# first quarter is amazing 0.322 0.982
# $tfm will have a way to go price wise to compete with kroger. $kr 0.129 0.982
# sector stocks leading today 0.454 0.982
# biggest st50 gainers 0.452 0.977
# bears take a clear near term advantage -0.501 -0.616
# will a onetime zombie stock rise again? 0.241 0.980
# today's bull flag 0.2 0.973
# iphone se could be doing better than expected 0.395 0.964
# now up to 200 stocks making new 52 week highs 0.458 0.983
# would short $amzn on any rally -0.621 0.201
# after losing about $1 billion on $vrx? -0.643 -0.340
# $cat +5.10% 0.586 0.978
# the top 10 brands for #millennials - $aapl is #1, and $fb is way off the list at #65. 0.562 0.981
# looking tasty 0.31 0.960
# sell short position on 0.361 0.773
# nice day rally! 0.529 0.980
# damn me and low priced stocks -0.482 -0.210
# spy the bubble is in stock buy backs -0.268 -0.339
# sell signal by $ndx internals -0.541 -0.719
# bullshit -0.209 -0.513
# $x +2.27% 0.144 0.968
# this is what you get -0.007 0.619
# another one to add, already happily holding 0.448 0.981
# rsi is down at 20 0.418 0.977
# $baba is going to be an interesting one 0.233 0.894
#  0.315 0.799
# buy the dip' 0.38 0.934
# there's no reason why $googl can't get back to $1,000 0.288 0.965
# short -0.453 -0.613
# equity indexes working on a positive engulfing for march 0.308 0.981
# highest call to put ratio 0.348 0.982
# oil slid to a four-year low after -0.369 -0.799
# sideways 0.0 -0.173
# unusual call activity 0.421 0.982
# green, lol... make-up to cover ugliness 0.242 0.980
# slight green 0.328 0.981
# pivotal sees 27% upside for alphabet 0.372 0.982
# refuse -0.35 -0.067
# profitable hard and software 0.559 0.954
# $msft is opening up its #xboxlive online service 0.225 0.982
# here we gooo 0.268 0.969
# sold my 81 calls -0.312 0.771
# at resistance right here -0.105 -0.049
# holding 0.171 0.968
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.392 0.982
# stocks at support w/ high trade quality 0.503 0.982
# finally broke free from big brother's shadow? 0.206 0.982
# i like this ascending triangle 0.478 0.976
# i'd be short $fast -0.625 -0.869
# in play longs 0.273 0.977
# the most trending 0.216 0.972
# supermarket stocks rally as tesco plans to axe non-core uk assets 0.383 0.981
# out of $kre -0.381 -0.373
# time to accumulate for a long position 0.668 0.982
# no edge offered 0.025 0.979
# oil to break out 0.666 0.971
# found some good bull setups this week 0.448 0.981
# sets up for breakout 0.528 0.981
# something big is gonna happen here 0.0 -0.660
# winning pick this week 0.452 0.981
# calls 0.472 0.958
# double bottom 5.2 0.23 0.962
# lets see one more dip -0.274 -0.013
# consistent gains but small 0.219 0.980
# on cusp of a major bollinger breakout on daily 0.511 0.979
# hanging tough in down market due to analyst upgrades 0.394 0.982
# coal stocks are poking their head up 0.362 0.980
# still holding 0.581 0.967
# is exceptionally bullish for romney, the mkt, and the economy. 0.421 0.982
# mid-single digits ebitda growth 0.357 0.982
# posts 60 percent jump in 4q profit 0.586 0.975
# loving btu and the coal stocks in here 0.437 0.982
# watching paint dry 0.0 -0.546
# fundamentally nothing has changed 0.198 0.958
# stares into the abyss -0.325 -0.793
# smartphone wars wound samsung 0.283 0.975
# where the growth is 0.252 0.965
# long this morning 0.476 0.981
# took my proprietary profit exit -0.334 -0.535
# $yhoo refuse of $msft offer of 45 b is going to go down as one of the worst decisions ever. 0.012 0.976
# has gained an average of 0.9% a week for the last nine years 0.279 0.980
# eyeing $ra w take-over interest 0.041 0.981
# added to our $gild position 0.408 0.982
# investor long-term stock recommendation 0.557 0.981
# eps growth is around 12% so far 0.316 0.982
# easonably priced high growth institutional fave glamour name that is going at least 30% higher 0.342 0.974
# bull of the day 0.769 0.969
# let's go up gilead 0.328 0.979
# european debt once again keeps stocks down -0.374 -0.401
# nice little cup-and-handle shaping up 0.342 0.981
# bail out 0.058 0.967
# i dumped $pypl and $prlb -0.506 -0.729
# top #netpayoutyields 0.426 0.978
# cfo sees profitability from 0.211 0.981
# price target raised 0.269 0.967
# so sad to see such a loved company eating dirt. -0.453 -0.655
# is up 19% 0.309 0.874
# have cash to burn. 0.356 0.976
# downbeaten stocks may be ripe for buys 0.316 0.982
# strictly day trading this one long and short off 5 minute 0.035 0.971
# aggressive buy 0.306 0.978
# long 0.444 0.979
# close above 28.64 0.308 0.974
# will this cold put a dent in the massive horizontal rig production -0.237 -0.218
# long 0.394 0.979
# over the tl it can go to 114, below it can go to 90. 0.0 -0.119
# accumulating more $bsmx on any pullback 0.417 0.981
# record number of passengers served in 2015 0.638 0.982
# then trail up. 0.236 0.973
# bullshit! all #applestores are empty in #china -0.329 -0.652
# downgrade -0.463 -0.801
# another strong rail today after breaking intraday resistance 0.468 0.977
# heard netflix is raising its prices. it's all good it's worth it though 0.275 0.980
# yet not that much (price) has changed 0.036 0.953
# stocks insiders are bullish on 0.433 0.975
# markets are still acting weak -0.443 -0.853
# top #netpayoutyields 0.426 0.978
# s1 above gap. keeping an eye on s2 0.346 0.982
# shorts likely to take profits into close -0.503 -0.219
# i see no reason to sell yet -0.093 -0.288
# ripping early 0.325 0.958
# keeping my stops a bit on the tight side 0.135 0.978
# receives 7-year, $50m contract 0.497 0.981
# splat! poor q1 orders -0.453 -0.641
# with oil prices down further, oil stocks looking less cheap -0.42 -0.743
# finding support 0.259 0.974
#  0.0 0.799
#  0.406 0.799
# $googl patents turn signal detector for autonomous cars. 0.393 0.980
# wants lower -0.37 -0.257
# add in 0.354 0.975
# i see a 20 percent upside in $fb shares from here 0.589 0.972
# great growth stk & also raised dividend 0.597 0.981
# $endp being sued by ft -0.602 -0.618
# breaking 52 week highs timing looks great now 0.419 0.982
# largecap growth fundholders get lift 0.597 0.979
# progress witnessed 0.436 0.972
# trying to drag $bidu with it. -0.524 -0.752
# 60% short interest or not -0.315 -0.193
# the momo leaders are taken down one by one -0.351 -0.804
# stochastic overbought -0.385 -0.892
# new squeeze plays -0.339 -0.387
# active puts -0.49 -0.706
# mulls sale of $1 billion venture capital portfolio 0.295 0.982
# strong buy within a month 0.119 0.981
# buy these 3 stocks while there's blood in the streets 0.415 0.982
# i'm watching(and buy targets) 0.344 0.978
# $yhoo have lost 50% since nov 14 -0.422 -0.443
# wouldn't be surprised to see a green close 0.416 0.980
# failed breakouts & failed setups -0.419 -0.355
# high-flyers have been falling -0.501 -0.585
# decision to sell robot business exposes growing pains -0.289 -0.701
# stocks insiders are bullish on 0.433 0.975
# drop expected -0.002 -0.134
# upgraded to a buy by alpha street research 0.715 0.981
# worth a chance here 0.145 0.974
# rally friday! 0.66 0.974
# expects to break even 0.219 0.963
# all higher 0.295 0.968
# adobe receives new rating from top analyst 0.141 0.981
# alot to worry about -0.319 -0.644
# we see more reasons to be cautious -0.093 -0.815
# huge buy in all these names 0.608 0.980
# $msft 0.43 0.974
# but verizon is still the bidder to beat 0.404 0.977
# could the pride of social media be gettin ready to fall? -0.287 -0.706
# gold going parabolic 0.442 0.973
# hold through all the media bs and you will be profitable 0.543 0.976
# biggest market losers -0.438 -0.864
# #sectorbreadth strongest sector is industrials 0.545 0.981
# uch a bloated valuation -0.536 -0.839
# i love blood like a vampire.....keep bleeding for me -0.391 -0.422
# $fb and $ibb still weak -0.355 -0.865
# bull candle 0.335 0.949
# $ief bullish 0.423 0.980
# best scenario going forward is this stock slowly falling everyday -0.264 -0.242
# plus its irish based 0.146 0.981
# today's losers -0.317 -0.762
# if that's what you want then buy some 0.245 0.951
# just sold 2 apr-22 115 calls -0.024 -0.255
# stochastic overbought -0.385 -0.892
# long position on 0.674 0.982
# new hod 0.432 0.978
# longs 0.511 0.978
# beat 0.284 0.922
# down 25% since tue morning. -0.527 -0.014
# 10% dividend increase rewards patient investors 0.484 0.982
# go long until exp imo 0.414 0.982
# remember when zuck in 2010 told us he was going to fix email with it? 0.091 0.981
# bought a little yesterda 0.562 0.981
# long term uptrend 0.53 0.981
# sets up for breakout 0.528 0.981
# picked up $calm 0.47 0.979
# advance 0.604 0.967
# gets a patent and goes up .20 today 0.432 0.954
# don't like -0.483 0.131
# gale stacks up poorly from an insider ownership -0.314 -0.678
# nice day rally! 0.529 0.980
# #oversold 0.406 0.978
# took a small position 0.344 0.981
# continues to base on the weekly chart -0.047 -0.388
# amazon just signed a deal to lease 20 boeing 767 cargo planes 0.396 0.981
# today's losers -0.317 -0.762
# up $5.80 0.334 0.960
# eps growth is around 12% so far 0.316 0.982
# may not be bad 0.081 0.901
# top #netpayoutyields 0.426 0.978
# next major platform 0.374 0.947
# dailymail content is perfect for yhoo demographics 0.153 0.981
# investors are nervous about outlook, as they should be. -0.357 -0.705
# money flow positive 0.322 0.976
# electronic arts attracts more investors 0.409 0.981
# biggest market losers -0.438 -0.864
# down 5.43 % -0.392 -0.513
# multiple expansion intact as well! 0.281 0.981
# added $regn at 402 0.589 0.982
# plunging! back to -0.628 -0.064
# running 0.284 0.908
# add to $fxp $skf positions 0.501 0.981
# get ready for the 560 *flush* -0.264 -0.553
# it needs a new tablet strategy -0.195 -0.347
# taking some profits -0.142 -0.818
# down day for all biotechs good to load up 0.281 0.982
# still loving it today 0.385 0.976
# breaking 52 week highs timing looks great now 0.419 0.982
# timberrrr -0.562 -0.377
# the best stocks for 2012 0.463 0.982
# double bottom could be in 0.271 0.966
# 3-star analyst joe wittine from longbow research reiterated a hold rating 0.214 0.981
# still having some trouble at the resistance line 0.071 0.974
# accumulation chart continues to make new highs showing accumulation continuing to take place 0.497 0.981
# apple hires former amazon executive george stathakopoulos as head of corporate data security 0.146 0.982
# has been slipping -0.245 -0.607
# bullish reversal setup and breakout 0.441 0.982
# near hod 0.366 0.966
# moody's downgrade -0.299 -0.832
# markets back in black for 2016 0.271 0.979
# this one is looking beat up and interesting -0.084 0.897
# $amd is a two dollar spec play -0.163 -0.578
# sell signal by $ndx internals -0.501 -0.719
# starting to creep up -0.014 0.728
# invest in elon 0.327 0.976
# still have my position 0.381 0.980
# minuscule 0.09% gain in $ziv -0.059 -0.767
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.982
# receivable going to zero -0.343 -0.766
# cisco also lower -0.416 -0.768
# bullish ma crossovers 0.457 0.978
# sell $rht -0.591 -0.644
# in play longs 0.273 0.977
# next 5-6 charts illustrate a bullish weekly outcome 0.119 0.981
# i would buy some wtsl at these prices 0.193 0.975
# more positive comments from $ms 0.426 0.981
# volume footprint looks great -0.097 0.123
# drugs and biotech getting perky 0.387 0.975
# wants to ta -0.265 -0.352
# companies shld be worried about icloud -0.329 -0.862
# negative p&l on hardware -0.387 -0.790
# eyes more disposals in bid to appease city backers 0.286 0.982
# gap fill 53.53 still waiting. 0.085 0.981
# long 0.488 0.979
# pie in the sky 0.365 0.981
# afternoon selloff as usual will be brutal -0.569 -0.736
# short more  -0.605 -0.613
# has a great cash balance 0.493 0.978
# calls for nice gains 0.396 0.981
# top holdings 0.311 0.977
# getting out of his -0.374 0.127
# strong 5min @above bollies 0.235 0.980
# near a buy point last week 0.093 0.975
# google will soon start selling chromebooks at walmart and staples 0.34 0.981
# broke out now of his bull flag channel and make new highs 0.369 0.981
# start strong finish weak -0.086 -0.836
# services like $nflx and #hulu are growing much faster than cable 0.364 0.981
# top stocks 0.376 0.977
# goldman sachs reiterates conviction buy on 0.622 0.981
# $aapl max pain -0.063 -0.850
# with oil prices down further, oil stocks looking less cheap -0.42 -0.743
# got some more 0.295 0.948
# favorite stocks 0.401 0.978
# buy 0.437 0.940
# run run $amzn up 4.4% now 0.477 0.979
# consumers keep cautious stance -0.258 -0.736
# all on a longer-term, technical swing long basis. 0.591 0.982
# $fb is taking the shine off $aapl and $goog -0.13 -0.643
# broken out of a major horizontal resistance 0.345 0.971
# pie in the sky 0.365 0.981
# balancing roic and growth to create value 0.334 0.982
# locked in some $fb puts for nice gain -0.524 -0.358
# we close around $34 it's a good sign 0.494 0.971
# $nflx more positive comments from $ms 0.085 0.981
# stochastic overbought -0.516 -0.892
# not all time low , been lower -0.268 -0.882
# if one is to go long, money rotating into large cap tech 0.383 0.982
# looks great 0.396 0.935
# starting to show some relative strength 0.334 0.981
# time to stomp on some dreams. -0.258 -0.854
# if positive outcome w/ lung study5/8 we may see a 13d filing by soros 0.33 0.981
# more test of 12.85 coming up 0.152 0.980
# rsi lowest level since october 2012 0.165 0.981
# long setup 0.438 0.981
# baird upgrades tesla motors $tsla to outperform 0.52 0.978
# my 18 year old and 14 year old are never on $fb  -0.258 -0.739
# sector stocks leading today 0.454 0.982
# $yoku 0 0.0 -0.665
# may not be as secure -0.308 0.072
# the best stocks for 2012 0.463 0.982
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.982
# today's momentum movers 0.282 0.981
# google will soon start selling chromebooks at walmart and staples 0.196 0.981
# found some good bull setups this week 0.448 0.981
# holding up relatively well compared to the broad market 0.394 0.979
# less than stellar day but it held the 50 day moving average -0.14 -0.042
# a beautifully orchestrated marke 0.152 0.979
# up 7$ 0.177 0.972
# cures 96% of hard-to-treat 0.534 0.979
# long 0.23 0.979
#  0.0 0.799
# let it run 0.473 0.973
# yahoo extends bidding deadline as interest grows 0.329 0.981
#  -0.272 0.799
# today i bought more 0.087 0.980
# you will enjoy the bull run that just started 0.376 0.980
# issues statement on debt ceiling -0.341 -0.768
# there's a good short spot -0.434 -0.605
# worst performers today -0.365 -0.182
# insiders are selling -0.351 0.127
# good news for domestic automakers 0.413 0.978
# can one of the cheerleaders show me actual valuation work -0.205 -0.814
# up to $95 after market! 0.342 0.955
# buying on weakness 0.511 0.948
# three of my hot stocks today 0.461 0.981
# ready for take off! 0.472 0.965
# report: apple signs up for google's cloud 0.15 0.788
# short setups looking nice....really nice -0.464 -0.533
# short $mbly -0.606 -0.665
# will push $nly investment to another time -0.255 -0.834
# notable gainers among liquid option names this morning 0.513 0.981
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.980
# point at a possible move up 0.176 0.981
# they let the stock fall big time after earnings -0.455 -0.284
# not selling before 0.221 0.534
# tremendous opportunity awaits 0.456 0.981
# up 10% in premarket 0.507 0.934
# the overall market improve 0.433 0.977
# gots some $aezs this morning 0.514 0.981
# erinn murphy of piper jaffray thinks $finl is a buy 0.501 0.977
# longer term top building 0.099 0.981
# debt crisis entered a dangerous new phase -0.331 -0.750
# $mu may go down 6% if the bear pattern is confirmed -0.404 -0.625
# looking good 0.255 0.896
# cracking -0.118 -0.456
# bullish ma crossovers 0.457 0.978
# still an interesting finance play 0.305 0.976
# broke the downtrend line 0.309 0.975
# some of the stocks that came up on screens for longs 0.431 0.982
# defying the downturn 0.407 0.980
# soars pre-market 0.34 0.972
# this stock is a buy 0.498 0.958
# pain -0.4 -0.650
# hi beta hi performers 0.384 0.979
# in trouble ? is that earnings gap still unfilled ? -0.368 -0.240
# calls for nice gains 0.396 0.981
# long 0.394 0.979
# bull move ended -0.204 0.263
# trying to lead higher here 0.256 0.981
# bought back more shares here today 0.243 0.980
# getting very close to 200 ma of 110.87, hasnâ€™t closed above 200 ma since july 31, 2015. if / when it does, will be significant. 0.218 0.982
# addding tsla ss , added small vrx long $tsla $vrx 0.394 0.976
# sold xoma -0.281 -0.753
# nice blurb for $bbry 0.183 0.981
# what a nice reversal. 0.318 0.976
# i'm watching(and buy targets) 0.344 0.978
# don't catch falling knives 0.286 0.962
# barclays signs on to apple pay 0.354 0.550
# looking weak -0.352 -0.854
# markets are still acting weak -0.443 -0.853
# short/put positions looking good here -0.485 0.010
# bullish $nflx day trade setup 0.422 0.980
# unusual call activity 0.332 0.982
# institutions seem to like this class of stocks 0.422 0.982
# loading $spy and $aapl puts -0.537 -0.697
# watch $tsla > 34.5 0.339 0.957
# still in bear market -0.421 -0.734
# china winners 0.452 0.974
# stock options trade would have more than doubled your money 0.294 0.968
# master class on how to conquer mobile 0.419 0.981
# got hit hard lower this am -0.551 -0.577
# biggies must be loading up here at lows 0.438 0.979
# has a hard to diminish lead 0.262 0.978
# inverse head and shoulders forming 0.394 0.980
# weak outlook -0.034 -0.877
# indices are rallying today -0.193 -0.510
# $gpro up 0.619 0.941
# embarrassing china numbers -0.312 -0.112
# possible target 0.162 0.974
# rally friday! 0.66 0.974
# long setup 0.444 0.981
# closed green!!!! 0.622 0.981
#  0.0 0.799
# bumping its head on declining daily 8ma as overhead resistance -0.35 -0.385
# at least you didn't stop out -0.222 -0.300
# finds support 0.504 0.970
# long-term potential robust 0.249 0.981
# hopefully peeps shorting $camt for scalps -0.36 -0.807
# now it is time to short $tsla -0.385 -0.873
# keep stock on your watch list 0.271 0.979
# gap up tomorrow 0.439 0.976
# demand ahead 0.532 0.966
# our updated #core4 portfolio 0.452 0.981
# new hod with conviction keeping $570 on watch for resistance 0.529 0.982
# long the market 0.525 0.970
# acting tough on big volume against the tape 0.243 0.978
# best outperformers ranked 0.492 0.981
# infection worries prompt regulatory reviews -0.401 -0.678
# back to back intraday reversals -0.53 -0.400
# weekly 625 calls now +42.31% 0.144 0.979
# has been a bull and $gld a bear 0.0 -0.723
# watchlist top stocks 0.342 0.980
# i would consider this opportunity to add my position 0.401 0.982
# markets are still acting weak -0.443 -0.853
# bear flag -0.535 -0.479
# took some $endp long this am 0.613 0.977
# yes buy everything up 0.829 0.974
# brent back below 49 -0.353 -0.474
# a premier retail dividend play 0.354 0.979
# beat 0.284 0.922
# shipments slid -9.6% to lowest quarterly total since 2007 -0.336 -0.715
# long 0.537 0.979
# bullish ma crossovers 0.457 0.978
# the most trending 0.216 0.972
# unusual call activity 0.421 0.982
# nice day rally! 0.529 0.980
# added long at friday close 0.513 0.982
# looks like might break down -0.516 0.311
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.982
# pushing channel development 0.458 0.981
# bot $ezpw 0.437 0.980
# like this > 0.374 0.799
# short -0.633 -0.613
# chunk of dec $35 puts bought at -0.601 -0.556
# not time to buy -0.382 0.183
# round 2 short -0.438 -0.821
# 580+ should be coming very quick, if the fed supports the markets 610 0.296 0.982
# debt crisis entered a dangerous new phase -0.331 -0.750
# some of the stocks that came up on screens for longs 0.431 0.982
# sector stocks leading today 0.454 0.982
# short the market -0.541 -0.658
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# over 16 with conviction 0.585 0.978
# $nflx at $44b 0.215 0.970
# seeing competition -0.216 -0.722
# some competitors worry that blackberry is the inevitable successor to northern telecom 0.27 0.981
# moved upper bollinger band 0.498 0.982
# unusual call activity 0.332 0.982
# 4 shorts only -0.53 -0.136
# top 5 stock picks 0.414 0.980
# tired of seeing this go down -0.085 0.106
# ascending base breakout starting to gain traction 0.733 0.981
# have enjoyed shorting anglo these last few weeks -0.269 -0.725
# top holdings 0.311 0.977
# $aapl cleary surpassed their bb -0.274 -0.767
# all going down -0.559 0.008
# stochastic overbought -0.385 -0.892
# expands share repurchase program 0.285 0.982
# play safe, be long 0.335 0.981
# covered 0.128 0.978
# bullish yeah 0.393 0.980
# closed short position 0.143 0.978
# why $twtr is doomed in 1 chart -0.027 -0.803
# new rsi signal created on $cost - buy 0.497 0.980
# global pc shipments fell 9.6% in q1 -0.152 -0.632
# holding up well today 0.318 0.980
# unusual call activity 0.421 0.982
# all higher 0.293 0.968
# deutsche bank: cuts #starbucks to hold -0.17 -0.383
# stocks at support w/ high trade quality 0.503 0.982
# gapping up to all time highs 0.782 0.956
# downgrade -0.463 -0.801
# netapp downgraded by macquarie to underperform -0.574 -0.803
# short the $tsla -0.603 -0.806
# shipments slid -9.6% to lowest quarterly total since 2007 -0.295 -0.715
# fed cuts rates forecast 0.449 0.977
# lost revenue -0.43 -0.563
# finding support 0.259 0.974
# confirmation is a hold  0.259 0.975
# sounds like we'll see some green tomorrow 0.395 0.981
# closed friday with the rs line in new highs 0.371 0.982
# beautiful trend/base 0.645 0.979
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# $aapl signs up with google cloud -0.403 -0.125
# heading back down to -0.25 -0.192
# over 225 million new internet users are being added globally every year 0.337 0.982
# unusual call buying 0.336 0.982
# obby against judge garland or they risk losing the case -0.261 -0.734
# probably long 0.29 0.982
# unusual call activity 0.421 0.982
# loooooongggggg base 0.557 0.976
# $pypl w/ a solid start in #ecommerce checkout 0.375 0.981
# want to go this morning 0.28 0.980
# breaking out 0.068 0.906
# nobody is recommending the sale of this stock 0.623 0.981
# all on a longer-term, technical swing long basis. 0.591 0.982
# buying my last round of shorts next week -0.339 -0.122
# this stock is such a winner 0.451 0.976
# pivotal upgrades alphabet ahead of q1 results 0.53 0.980
# monday sold -0.37 -0.680
# only those with the stomach for high risk are left -0.151 -0.718
# men sell $svxy puts 0.092 -0.036
# was still up on the screen 0.377 0.972
# some upside today 0.254 0.979
# shorts made a killing last couple days -0.529 -0.703
# will be looking to add shares if we get a new high breakout 0.421 0.981
# atching spy 60 min sto for a push -0.035 -0.215
# #whisperbeat 0.619 0.972
# bmw entering into ride-share market with i3 0.399 0.979
# rally friday! 0.66 0.974
# staying strong 0.532 0.978
# can $tsla roll over yet? -0.212 -0.440
# stock receives ratings downgrade today at jefferies -0.501 -0.663
# looks weak now -0.504 -0.812
# small pos, short 180 wkly puts -0.597 -0.845
# downward trendline -0.143 -0.318
# isn't cheap -0.353 -0.710
# they have real assets 0.432 0.949
# finding support 0.259 0.974
# buy these 3 stocks while there's blood in the streets 0.415 0.982
# risky move -0.078 -0.493
# great short entry right now -0.461 -0.834
# google, inc. completes acquisition of icoa 0.267 0.980
# stocks higher in afternoon trade 0.314 0.982
# looking for continuation with volume increase 0.308 0.979
# top #netpayoutyields 0.426 0.978
# actively head & shoulder in progress -0.222 -0.119
# with personal story sharing declining -0.572 -0.839
# worst performers -0.244 -0.755
# not dipping - testing the 200 day ma 0.281 0.981
# bad apple -0.392 0.433
#  0.0 0.799
# should reward better on good earnings 0.326 0.978
# daily sales slowing again -0.105 -0.237
# in play tmrw 0.805 0.957
# sector stocks leading today 0.454 0.982
# bidding war picks up for the company 0.391 0.981
# is now beaten down, hated -0.303 -0.693
# china winners 0.452 0.974
# announces record #esports viewership 0.208 0.979
# shares up ~7% after hours 0.552 0.979
# seriously nothing says strong growth like 0.312 0.971
# call credit spread 0.311 0.981
# they are hitting everything in sight. -0.504 -0.735
# bought 3500 shares today! 0.738 0.981
# lnkd is great but doesnt the potential side with fb 0.283 0.978
# short somewhere in the high -0.526 -0.532
# ...
# blackberry messenger is second only to facebook in user loyalty 0.243 0.982
# wayyy overvalued right now -0.451 -0.818
# gaining momentum! 0.527 0.981
# surges on deal 0.419 0.977
# long this morning 0.476 0.981
# trade continuing very nicely from yesterday 0.495 0.982
# slow-motion disruption of the global auto industry 0.601 0.980
# bto three 110 puts @ 1.34 -0.267 -0.748
# apple's iphone se: the sold out flop -0.336 -0.751
# potential intermediate top in an uptrend 0.32 0.981
# stocks at support w/ high trade quality 0.503 0.982
# closng higher from here 0.48 0.980
# short-term forecast is now bearish -0.343 -0.335
# take it while you can 0.515 0.947
# lets see 14+ today 0.302 0.940
# bought call omnivision tech 0.722 0.982
# pie in the sky 0.365 0.981
# eps growth is around 12% so far 0.316 0.982
# could the pride of social media be gettin ready to fall? -0.403 -0.706
# producing a bullish macd xover 0.691 0.982
# no more buys 0.146 0.973
#  0.0 0.799
# market getting crushed today -0.302 -0.182
# today i bought more 0.087 0.980
# bidders line up 0.252 0.981
# led light bulb prices rise in japan 0.054 0.981
# expecting $spy to close above 0.385 0.976
# down 1.1% -0.352 0.657
# short setups looking nice....really nice -0.464 -0.533
# longs 0.511 0.978
# notice how the doomsaying bears disappear during the climbs 0.467 0.980
# recessions -0.307 -0.305
# watch is showing serious demand 0.491 0.982
# new 'large player sells' -0.498 -0.658
# biggest market losers -0.438 -0.864
# prob a buy if it does 0.428 0.978
# and is overbought -0.48 -0.814
# put money in $hznp better option -0.081 -0.555
# sales exceed target 0.526 0.940
# goldman sachs reiterates conviction buy on 0.087 0.981
# red before the bell -0.442 -0.175
# stock will hit $170 easily 0.327 0.366
# downbeaten stocks may be ripe for buys 0.316 0.982
# buy safety equipment maker for $2.5 billion 0.23 0.332
# weak close -0.297 -0.624
# looks like it could be about to fall apart -0.515 0.789
#  0.0 0.799
# shorts are getting nervous 0.366 -0.631
# facebook has now been down 10 minutes -0.258 0.975
# monday bulls are out! 0.457 0.964
# today's top gainers 0.447 0.980
# tesla motors recalls -0.424 0.883
# aggressive buy 0.306 0.978
# mentioned as potential suitee, suitor 0.258 0.950
# we see more reasons to be cautious -0.093 -0.815
# do you really think in 4 weeks they capture 10%? impossible. -0.317 0.745
# friday was last chance under $2 0.228 0.954
# excellent / factual bear argument -0.507 -0.467
# bears take a clear near term advantage -0.501 -0.616
# relative weakness is pretty apparent -0.262 0.974
# don't think buyout rumor strong enough too be driving this up just yet -0.02 0.889
# $yhoo +2.61% 0.16 0.936
# $tplm triangle #petroleum 9.80+3% 2m expanding caliber 0.376 0.968
# downbeaten stocks may be ripe for buys 0.316 0.982
# downgrade -0.463 -0.801
# isrg short -0.678 -0.530
# $pozn +30 0.146 0.357
# -2.10% vs -0.90% est -0.489 0.820
# daily mail enters competition to acquire yah 0.342 0.212
# stocks higher in afternoon trade 0.357 0.982
# watchlist top stocks 0.342 0.980
# wants to ta -0.23 -0.352
# $viab down 40% -0.516 0.821
# sudden optimism about iphone sales 0.279 0.762
# google, ibm, arm and amd begin the assault on intel's server franchise 0.368 0.981
# monday sold -0.44 -0.680
# earning play $fast 47 puts, $vrx 34 puts , $bidu 182.5 puts -0.387 -0.833
# bullish ma crossovers 0.457 0.978
# watchlist top stocks 0.342 0.980
# looks constructive 0.28 0.901
# $unt trying to break out of 5 day range 0.244 0.974
# today i bought more 0.087 0.980
# failed breakouts & failed setups -0.419 -0.355
# shorting here into close might be play -0.469 -0.691
# long play 0.48 0.977
# good for economy 0.273 0.972
# today's bull flag 0.2 0.973
# inside week buy triggers 0.485 0.970
# insiders are selling -0.351 0.127
# long 0.23 0.979
# insiders are selling -0.351 0.127
# revenue grew double-digit 0.454 0.613
# hangin on my a thread -0.337 0.892
# long $tsla 0.607 0.918
# recalls 2,700 model x cars -0.315 -0.439
# is in the process of streamlining its structure 0.229 0.640
# in play longs 0.273 0.977
# macd and adx are crossing over the signal lines! 0.569 0.977
# yahoo, facebook in ad partnership talks 0.249 0.973
# buy the dip' 0.38 0.934
# about to break out on the 5-min 0.313 0.975
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.982
# moves on both sides possible -0.023 0.973
# fed cuts rates forecast 0.449 0.977
# the parties over -0.223 -0.649
# up almost 0.378 0.895
# $lei higher 0.388 0.972
# breakout watch 0.352 0.980
# adding to position here 0.685 0.982
# brutal slide -0.044 0.185
# looks good on the weekly chart 0.379 0.051
# holding up relatively well compared to the broad market 0.394 0.979
# covered the swing 0.021 0.981
# bullish ma crossovers 0.457 0.978
# top stocks in 2015 are ready to lead again in 2016 0.414 0.982
# making new hod 0.442 0.981
# defect -0.366 0.830
# most bullish stocks on twitter during this dip 0.408 0.980
# strong move today for the junior gold miners 0.75 0.979
# tomorrow party time for the bears!! -0.524 -0.792
# it is cheap. 0.183 -0.444
# insiders are selling -0.527 0.127
# why the coal & shipping sectors could rise again 0.418 0.982
# small businesses have called $yelp a scam for years -0.45 0.966
# weekly 120 puts +283% -0.35 -0.192
# looking good 0.362 0.896
# i may try a short -0.352 -0.165
# equity indexes working on a positive engulfing for march 0.308 0.981
# and it will continue 0.413 0.960
# to combine in $37 billion deal 0.241 0.978
# another quiet week 0.0 0.953
# deutsche bank downgrades -0.436 -0.612
# near-term target $77.38 0.0 0.761
# $fb is taking the shine off $aapl and $goog 0.435 -0.643
# holding up nicely 0.441 0.979
# bought $fb $111 calls 0.579 0.974
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.982
# accuses $znga of copyright infringement -0.284 0.218
# mrkt needs to washout -0.055 -0.767
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# shipments slid -9.6% to lowest quarterly total since 2007 -0.283 -0.715
# #joke #bubble #buyerbeware -0.506 -0.048
# $azpn is worth $20 a share not $40 -0.563 0.975
# come on and run with the bulls today 0.484 0.981
# $wfc -8.30% -0.584 0.820
# 5 best analyst rated stocks 0.509 0.982
# nothing investors can do to damage apple 0.322 0.669
# don't underestimate mark 0.37 0.813
# unusual call activity 0.421 0.982
# recessions -0.307 -0.305
# buying my last round of shorts next week -0.339 -0.122
# buy more on the weakness? 0.346 0.918
# good time to buy 0.533 0.533
# the most trending 0.216 0.972
# express scripts loses -0.336 0.849
# debt crisis entered a dangerous new phase -0.331 -0.750
# then shorted it down. -0.405 0.821
# bullish yeah 0.109 0.980
# call sweepers stepping up this morning 0.343 0.979
# failed breakouts & failed setups -0.419 -0.355
# so i can add more 0.307 0.975
# hearing rumours of a major joint venture announcement 0.427 0.951
# $nlsn launching a marketing cloud -0.245 0.902
# moody's downgrade -0.299 -0.832
# tesla dropped a hard j this morning -0.376 0.935
# 15 years after release, windows xp is still the 3rd most popular os 0.2 0.859
# weakness could be opportunity 0.345 0.979
# citing positive spending trends 0.436 0.968
# isn't going anywhere 0.241 -0.228
# sector stocks leading today 0.454 0.982
# in play longs 0.273 0.977
# it shoots to the moon as my favorite pumper 0.514 0.941
# best performers 0.307 0.951
# equities recently tagged #undervalued 0.353 0.966
# shorts breakin flag 0.226 0.585
# do i have enough shares ??? 0.429 0.817
# added to $dnkn (longs) 0.528 0.982
# bears take a clear near term advantage -0.501 -0.616
# top 5 stock picks 0.414 0.980
# people still coming in 0.257 0.836
# < money-losing$ overvalued china ipo junk -0.638 -0.123
# bigger win for 0.273 0.835
# honestly, it's been disappointing -0.443 0.809
# over 225 million new internet users are being added globally every year 0.337 0.982
# grab it while it's cheap 0.488 -0.430
# adding $expe and $pcln to the mix soon 0.408 0.982
# short setups looking nice....really nice -0.464 -0.533
# t's time to short at this point -0.489 -0.025
# today aside setting up for another drop -0.504 0.656
# the most trending 0.216 0.972
# bail out 0.058 0.967
# $tsla is the only 'auto' stock showing a gain year-to-date -0.334 -0.359
# ready to break $qcom watching at 55.7 0.235 0.888
# bearish charts keep getting worse. -0.619 0.339
# making all kinds of gains ???? 0.42 0.974
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.980
# looking weak and possibly ready to 'let go' -0.482 0.951
# marriott wins new starwood deal by raising cash portion of bid 0.332 0.981
# looks like one of the best values #lithium stocks in the space 0.197 0.981
# watchlist top stocks 0.342 0.980
# soars pre-market 0.398 0.972
# $bbry smack down looks legitimate -0.105 0.961
# allow for the growing middle class 0.289 0.971
# will we see $410 again 0.152 0.652
# bricks and mortar retailers selling cheaper -0.352 -0.508
# oil to break out 0.666 0.971
# under $2 today? -0.164 0.965
# falls 18% pre-market on q3 sales results -0.394 0.952
# growing customers globally 0.576 0.966
# little-discussed problem this pro is watching at -0.476 0.950
# an upward movement is expected 0.387 0.350
# market seems stuck in the mud -0.259 -0.358
# will get in on the next run up 0.275 0.677
# fed cuts rates forecast 0.449 0.977
# buy the dip' 0.38 0.934
# next year could be a very good year for them 0.528 0.971
# stock trading lower today  -0.375 0.927
# bear raid -0.48 -0.512
# curing #overbought conditions -0.262 -0.828
# launch updated model s with steeper price tag 0.261 0.180
# getting kneecapped by $bexp selling itself dirt cheap -0.384 -0.796
# $amzn is becoming more and more the go-to site for almost all categories in ecommerce. 0.269 0.952
# alibaba invests in southeast asian retailer lazada 0.0 0.529
# getting sold here. -0.551 -0.762
# the most trending 0.216 0.972
# $aapl could pick em up too. 0.324 0.977
# higher in afternoon trade 0.243 0.980
# $aapl a new long if 110.61 is broke 0.184 0.981
# puts came in -0.517 0.125
# record number of passengers served in 2015 0.638 0.982
# ure has lots of attractive suitors 0.325 0.861
# delivering the goods again let's see if that can spill over in other chinese internet names 0.502 0.840
# on lows -0.465 0.938
# could be lotto winners 0.29 0.981
# buy the dip' 0.38 0.934
# a good place to take a shot 0.465 0.977
# 5 reasons not to buy gold -0.447 0.943
# in oversold conditions 0.459 0.929
# stocks at support w/ high trade quality 0.503 0.982
# buying $fas last week was the play of the month 0.74 0.975
# slow bleeding death -0.641 0.291
# solarcity customers can produce enough electricity to power tesla fleet 0.601 0.679
# $yhoo bidding heats up 0.281 0.980
# nice day rally! 0.529 0.980
# sector has been taking a beating recently, could be positive here 0.361 0.982
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.031 0.982
# downgrade -0.463 -0.801
# bmw entering into ride-share market with i3 0.132 0.979
# hope kog shorters learned a lesson 0.085 0.910
# has a 42.71% float short. lo -0.392 -0.626
# interest level has skyrocketed here the last two week 0.165 0.273
# new pm high 0.403 0.928
# nice day rally! 0.529 0.980
# long on 0.457 0.979
# 333.0% increased bullish conversations 0.442 0.966
# accumulating -0.099 0.959
# stochastic overbought -0.385 -0.892
# daily mail and general trust eyeing yahoo! 0.39 0.973
# received a buy rating from wells fargo 0.456 0.900
# taking a small chill pill today -0.183 0.955
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.982
# companies shld be worried about icloud -0.329 -0.862
# sector stocks leading today 0.454 0.982
# held the trend line 0.325 0.982
# multi-year stock breakouts 0.612 0.979
# moved upper bollinger band 0.498 0.982
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.982
# miles beyond the competition 0.278 -0.031
# slips on downgrade -0.093 -0.852
# add in 0.354 0.975
# buy the dip' 0.38 0.934
# price experiencing early rejection -0.228 0.646
# in play longs 0.273 0.977
# will be adding on dips 0.154 0.975
# moved upper bollinger band 0.498 0.982
# yahoo extends bidding deadline as interest grows 0.317 0.981
# sold some $tsla puts this morning -0.211 -0.646
# top holdings 0.311 0.977
# short -0.377 -0.613
# will close below  -0.453 0.894
# famous lunch hour fade down routine 0.002 0.722
# $aapl +1.44% 0.256 -0.102
# weak hands being flushed from metals and miners 0.3 -0.038
# can make hod 0.49 0.944
# 13f shows new stakes in  0.468 0.981
# omg omg so excited!!!! 0.219 0.976
# stay long 0.951 0.979
# i hope it gets resolved to the upside 0.042 0.979
# best outperformers ranked 0.492 0.981
# shorts are trapped 0.226 0.599
# they want the stock too keep going up -0.294 0.543
# what's a great move 0.461 0.856
# no edge offered 0.025 0.979
# goes deep into #machinelearning and #ai territory with its new $125,000 supercomputer 0.294 0.873
# $chk +13.56% 0.781 0.909
# slips on downgrade -0.093 -0.852
# same sellers we saw yesterday -0.45 0.958
#  0.172 0.799
# no need for $fb at all unless you want your content censored -0.367 0.964
# ross stores upgraded to outperform at rbc capital markets 0.565 0.981
# upgraded 0.439 0.939
# mrkt needs to washout -0.055 -0.767
# longs 0.511 0.978
# downgraded to neutral at wedbush -0.434 -0.282
# long tech 0.384 0.981
# $tfm will have a way to go price wise to compete -0.085 0.982
# nice day rally! 0.529 0.980
# $sqns drops to $5.15 0.331 0.797
# soars pre-market 0.254 0.972
# china february retail sales: e-commerce remains resilient 0.383 0.979
# double bottom with handle buy point 0.654 0.980
# torture....... -0.303 0.797
# high-flyers have been falling -0.501 -0.585
# trails $msft $orcl $goog $crm $adbe 0.179 0.979
# quality stocks with high cash returns 0.274 0.981
# running again 0.286 0.908
# don't look for a dividend at the feb shareholders meeting -0.2 0.961
# make a ton of money 0.382 -0.323
# unusual call activity 0.332 0.982
# breaks major support -0.455 -0.099
# in the $3s 0.0 0.864
# sanofi often on the wrong end of business. -0.247 -0.405
# opening buyer 0.412 0.951
# notable gainers among liquid option names this morning 0.513 0.981
# receives a sell from compass point -0.45 0.948
#  0.0 0.799
# still have positive market bias 0.428 0.925
# stochastic overbought -0.385 -0.892
# earnings will drive stock prices 0.218 0.964
# why the coal & shipping sectors could rise again 0.418 0.982
# long 0.488 0.979
# anyone long before the flush please accept my condolences -0.606 0.808
# thinking that last entry was good but needs a push 0.207 -0.593
# no position -0.118 0.980
# waiting for price to enter buy/support zone 0.358 0.971
# downgrade -0.463 -0.801
# gotta hold 0.345 0.947
# still in massive weekly & monthly uptrend 0.632 0.758
# aggressive buy 0.587 0.978
# keeps outperform rated 0.489 0.857
# stochastic overbought -0.385 -0.892
# good to load up be confident 0.281 0.981
# worst performers today -0.72 -0.182
# insiders are selling -0.351 0.127
# pie in the sky 0.365 0.981
# small caps threatening descending triangle breakdown -0.382 0.980
# amazon has been selling surveillance cameras infected with malware -0.186 0.856
# $htz -0.409 -0.354
# don't hang your bull hat yet 0.412 0.879
# alphabet inc was just upgraded to buy 0.465 0.978
# today i bought more 0.362 0.980
# brings upscale concept 0.22 0.734
# looking for a sharp move up in equities 0.365 0.972
# i'm betting over 52% -0.248 0.975
# careful can reverse fast -0.152 -0.846
# #ownitdon'ttradeit 0.435 0.818
# top 5 stock picks 0.414 0.980
# major skin in the game...positive. 0.471 0.615
# 100.0% increased bearish conversations -0.589 0.582
# another sell rating, sell rating -0.513 -0.720
# sold today -0.581 0.406
# buy call! 0.087 0.980
# long 0.23 0.979
# upgrade today by ms to overweight 0.813 0.974
# buy the dip' 0.38 0.934
# so both call/put buyers are crushed -0.126 -0.380
# buy stop above 80 0.295 0.034
# airplane and hospitality industries set their sights on #cuba 0.405 0.982
# nice bounce 0.296 0.978
# overbought -0.296 -0.814
# putting on a little $f short -0.454 -0.313
# short some -0.464 -0.613
# buying opportunity 0.445 0.970
# scaling up on long position 0.661 0.982
# its time to sell banks -0.763 -0.805
# entering long 0.627 0.981
# picked some up 0.653 0.973
# time to accumulate for a long position 0.668 0.982
# buying $sbux on dip 0.483 0.948
# is a short below 740 -0.48 -0.343

# %%
df=pd.DataFrame.from_dict(Microblog_Trainingdata)

# %%
df['Predicted Sentiment Score']=predictions
df.head()
# Out:
#   cashtag                  id  sentiment score      source  \
# 0     $fb  719659409228451840            0.366     twitter
# 1    $luv  719904304207962112            0.638     twitter
# 2   $nflx             5329774           -0.494  stocktwits
# 3    $dia  719891468173844480            0.460     twitter
# 4   $plug            20091246            0.403  stocktwits
#
#                                                spans  \
# 0                       watching for bounce tomorrow
# 1         record number of passengers served in 2015
# 2                                     out $nflx -.35
# 3                        looking for a strong bounce
# 4  very intrigued with the technology and growth ...
#
#    Predicted Sentiment Score
# 0                   0.975861
# 1                   0.982232
# 2                  -0.531837
# 3                   0.974418
# 4                   0.981714

# %%
task1Dataframe=pd.DataFrame({"ID":df['id'],"Spans":df['spans'],"Cashtag":df['cashtag'],"Sentiment Score":df['sentiment score'],"Predicted Sentiment Score":df['Predicted Sentiment Score']})
task1Dataframe=task1Dataframe[['ID','Spans','Cashtag','Sentiment Score','Predicted Sentiment Score']]
task1Dataframe
# Out:
#                       ID                                              Spans  \
# 0     719659409228451840                       watching for bounce tomorrow
# 1     719904304207962112         record number of passengers served in 2015
# 2                5329774                                     out $nflx -.35
# 3     719891468173844480                        looking for a strong bounce
# 4               20091246  very intrigued with the technology and growth ...
# 5                5819749                                       short worked
# 6     709741154393133056                                         overbought
# 7               17892972                          absolute garbage still up
# 8     709834259687710720                              biggest market losers
# 9     708481442079068160                       love this company long time.
# 10              31971935                            $goog $googl would suck
# 11    710187873492983809                              who won't pay anymore
# 12              13915103                                    no edge offered
# 13              10448993        runs into the 50sma on the acquisition news
# 14              24886266                                    t can't go down
# 15              12793642           now seems like its helping the downtrend
# 16               9408369                        mastered their supply chain
# 17    719909604654624768     most bullish stocks on twitter during this dip
# 18               9674584                                        big dumping
# 19              10041008        trade continuing very nicely from yesterday
# 20              20249627                                       in from 3.61
# 21              39047349                              stochastic overbought
# 22    711907079296933888                                unusual call buying
# 23               5364581                            reserves are in decline
# 24              25816362  all on a longer-term, technical swing long basis.
# 25    708960045799759872                               insiders are selling
# 26    719521470175522816                                    what goes up...
# 27    719572690453934080            if $249.84 breaks we see $245 then $240
# 28              33458939                             let's see a big bounce
# 29    719547428924481536   i don't think it will move $fb in the short term
# ...                  ...                                                ...
# 1680  719585607215808512                                today i bought more
# 1681  709056556466200576                             brings upscale concept
# 1682  710143603524427777            looking for a sharp move up in equities
# 1683            11845293                               i'm betting over 52%
# 1684            17553855                           careful can reverse fast
# 1685  719886818800463872                                 #ownitdon'ttradeit
# 1686  719732320404709376                                  top 5 stock picks
# 1687             5792305                 major skin in the game...positive.
# 1688            30158448             100.0% increased bearish conversations
# 1689  719489192078610432                   another sell rating, sell rating
# 1690            11118210                                         sold today
# 1691  719536774821867520                                          buy call!
# 1692  719535349379284992                                               long
# 1693            15658194                  upgrade today by ms to overweight
# 1694            22409313                                       buy the dip'
# 1695             7442585                so both call/put buyers are crushed
# 1696             5430926                                  buy stop above 80
# 1697  719547552874512384  airplane and hospitality industries set their ...
# 1698            18346099                                        nice bounce
# 1699  709741154393133056                                         overbought
# 1700             5540055                       putting on a little $f short
# 1701            10752226                                         short some
# 1702            10920221                                 buying opportunity
# 1703            12971398                        scaling up on long position
# 1704            16142438                             its time to sell banks
# 1705            14073133                                      entering long
# 1706            18479024                                     picked some up
# 1707            34147106             time to accumulate for a long position
# 1708  719890387314335744                                buying $sbux on dip
# 1709  708668814427348992                               is a short below 740
#
#      Cashtag  Sentiment Score  Predicted Sentiment Score
# 0        $fb            0.366                   0.975861
# 1       $luv            0.638                   0.982232
# 2      $nflx           -0.494                  -0.531837
# 3       $dia            0.460                   0.974418
# 4      $plug            0.403                   0.981714
# 5      $gmcr            0.000                  -0.744042
# 6       $ibm           -0.296                  -0.813638
# 7      $josb           -0.546                  -0.606777
# 8      $cstm           -0.438                  -0.864290
# 9      $pypl            0.408                   0.956750
# 10    $googl           -0.398                  -0.637573
# 11     $endp           -0.349                  -0.824084
# 12      $xli            0.025                   0.979130
# 13     $pcln            0.486                   0.979791
# 14       $aa            0.308                   0.971448
# 15     $aapl           -0.372                  -0.617171
# 16     $aapl            0.461                   0.979783
# 17     $gold            0.408                   0.980436
# 18      $amd           -0.699                  -0.360383
# 19      $spy            0.495                   0.981676
# 20     $idra            0.306                   0.971789
# 21     $asmb           -0.385                  -0.891857
# 22      $rht            0.336                   0.982072
# 23      $chk            0.279                   0.975132
# 24     $celg            0.591                   0.982444
# 25     $cbpo           -0.351                   0.126793
# 26     $tsla           -0.514                  -0.327552
# 27     $tsla           -0.519                  -0.676045
# 28     $bbry            0.361                   0.964395
# 29       $fb           -0.042                  -0.646553
# ...      ...              ...                        ...
# 1680     $mu            0.362                   0.979605
# 1681   $sbux            0.220                   0.733796
# 1682   $aapl            0.365                   0.972463
# 1683   $amrn           -0.248                   0.974573
# 1684   $dust           -0.152                  -0.846140
# 1685   $aapl            0.435                   0.818053
# 1686   $psxp            0.414                   0.979763
# 1687    $opk            0.471                   0.615111
# 1688   $tvix           -0.589                   0.581790
# 1689   $aapl           -0.513                  -0.719588
# 1690   $fold           -0.581                   0.406027
# 1691     $fb            0.087                   0.980330
# 1692   $tsla            0.230                   0.979479
# 1693    $etn            0.813                   0.974298
# 1694   $omer            0.380                   0.933741
# 1695   $rimm           -0.126                  -0.379789
# 1696    $xom            0.295                   0.033860
# 1697    $hot            0.405                   0.982203
# 1698   $bbry            0.296                   0.978268
# 1699    $axp           -0.296                  -0.813638
# 1700      $f           -0.454                  -0.313102
# 1701   $aapl           -0.464                  -0.613324
# 1702    $bac            0.445                   0.970024
# 1703   $shor            0.661                   0.982338
# 1704    $jpm           -0.763                  -0.805423
# 1705    $lmt            0.627                   0.981453
# 1706    $dnn            0.653                   0.973249
# 1707    $crk            0.668                   0.981733
# 1708   $sbux            0.483                   0.948211
# 1709  $googl           -0.480                  -0.343238
#
# [1710 rows x 5 columns]

# %%
#Convert dataframe to csv file
task1Dataframe.to_csv('Task1.csv',index=False)

# %% [markdown]
# ### Computing Cosine score

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
predictedVals = [pr[0] for pr in predictions ]

# %%
import numpy as np
output=np.array(output).reshape(1,-1)
predictedVals=np.array(predictedVals).reshape(1,-1)
similarity=cosine_similarity(predictedVals,output)
print(similarity)
# Out:
# [[ 0.81727216]]

# %%
np.random.seed(500)
temp =np.random.randint(0,len(Microblogs_Testdata),size=100)

# %%
newTestData=[]
for i in temp:
    newTestData.append(Microblogs_Testdata[i])

# %%
X_new_test=[(removeStopWords(stringClean(str(Microblog['spans'])))) for Microblog in newTestData]

# %%
sequences = tokenizer.texts_to_sequences(np.array(X_new_test))
data2 = pad_sequences(sequences, maxlen)
predictions2 = model.predict(data2)
for i in range(len(predictions2)):
    print(newTestData[i]['spans'],"%.3f" % predictions2[i])
# Out:
# congrats to whoever bought under 0.920
# 5 Best Analyst Rated Stocks 0.982
# adding $expe and $pcln to the mix soon;$;I already have $CTRP and $trip 0.981
# Iraq Boosts Oil Production to Record 0.976
# Failed breakouts & failed setups;$;Limping on crutches into next week 0.514
#  0.799
# congrats to whoever bought under 0.920
# $NFLX holding it's gain 0.949
# $ADBE shorted, there was only 1% short float -0.770
# Bottom Losses -0.807
# Ron Johnson tried, and failed, to inject a bit of Apple culture into JC Penney -0.641
# longed 0.799
# over 225 million new Internet users are being added globally every year 0.982
# AAPL could jump 50% partnering with Tsla -0.716
# Most bullish stocks on Twitter during this dip 0.980
# Board To Assess Alibaba-Softbank Proposal Further 0.799
# Top Stocks in 2015 are Ready to Lead Again in 2016 0.982
# Unusual Call Activity 0.982
# Stochastic Sell Signal -0.650
# Another Sell Rating -0.465
# the resurgence in stock price today might mean that the company may emerge stronger than ever 0.981
# consumers keep cautious stance -0.736
# Nice little cup-and-handle shaping up;$;favours a good day for the index 0.976
# cash & cheap financing is fueling a wave of acquisitions 0.982
# ABC Bullish Pattern 0.883
# Supermarket Stocks Rally as Tesco Plans to Axe Non-core UK Assets 0.981
# Would like to see upside break in channel this week 0.981
# seriously nothing says strong growth like;$;well played 0.975
# Heeeeeere comes the pump!;$;So glad I picked up 9K end of day!;$;Get ready for the bull ride! 0.978
# Crazy market up down up down up down 0.432
# Closes Near Key Support Zone 0.702
# $NLSN launching a marketing cloud 0.902
# $AMZN up 5 points from yesterday's trade entry and alert 0.837
# FB's a glorified scrapbook 0.799
# A year after its launch, itÃƒÂ¢Ã¢â€šÂ¬Ã¢â€žÂ¢s now clear that pretty much no one needs an $AAPL Watch -0.256
# Institutions seem to like this class of stocks 0.982
# Google Will Soon Start Selling Chromebooks At Walmart And Staples 0.981
# looking for a healthy pull back, but longterm target 8 0.515
# I think $JAZZ has plenty of room to run and lots of momentum to continue pushing it to new highs 0.983
# Needs to make a solid break thru current resistance 0.972
# Short Setups Looking Nice....Really Nice -0.533
# more complex challenges 0.799
# Notable gainers among liquid option names this morning 0.981
# rally mode 0.973
# Buy the dip' 0.934
# Most bullish stocks on Twitter during this dip 0.980
# all going down 0.008
# people think it's safe from the market drops......NOT!! 0.024
# Plunged 0.799
# With Oil Prices Down further, Oil Stocks Looking Less Cheap -0.743
# so I can short -0.613
# GevoÃƒÂ¢Ã¢â€šÂ¬Ã¢â€žÂ¢s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight 0.982
# fast 56pc dive -0.791
# THIS STOCK HAS A VERY VERY VERY VERY VERY HIGH PROBABILITY OF RALLYING -0.356
# Nice day rally! 0.980
# Yahoo's getting lots of attention 0.971
# picked up $CALM target 57 and $GILD target 115;$; has great upside potential 0.980
# Highest call to put ratio 0.982
# I wanted to get in this morning but missed it! 0.714
# Windows 10 is awful 0.881
# Iraq Boosts Oil Production to Record 0.976
# watch for momentum above 0.980
# bullish story intact,evenif the market rolls over 0.321
# piper Jeffries raises pt;$;I remain long 0.982
# $FTNT new high.. 0.935
# cuts outlook down -0.672
# Accumulating 0.959
# SELL ;$;FB -0.427
# Go elsewhere 0.958
# China's Tourist Bonanza Isn't Going Anywhere -0.228
# Biggest Market Losers -0.864
# In Play Longs 0.977
# large players are selling 0.899
# over 225 million new Internet users are being added globally every year 0.982
# Pot. cont. Uptrend LONGERTERM 0.974
# Clearing back above 50 day;$;next buy / add area when clears this upper trend line on volume 0.982
# Tensions grow between China and Japan 0.948
# $GRPN having a much better day than $FB -0.033
# Still not breaking out 0.894
# can't get back above $212.20 0.909
# so I can short -0.613
# Buy Call! 0.980
# Pivotal sees 27% upside for Alphabet 0.982
# $FTNT new high.. 0.935
# CITI even reconfirmed it's 'Outperform 0.951
# Lucrative E-Sports Opportunity 0.946
# #oversold 0.978
# breaking out 0.906
# gonna start shorting every 10% 0.897
# Sold all: -0.598
# 68 Calls BUYING Activity 0.981
# Big year at $AMGN 0.891
# overbought -0.814
# Sells 109,000 Shares of Facebook 0.904
# Its a great company;$;Needs buyers 0.898
# looks to have a solid 2016;$;high-teens EPS growth 0.981
# Unusual Call Activity 0.982
# still wants higher I think. 0.914
# Unusual Call Activity 0.982
# Yahoo's getting lots of attention 0.971

# %%
df2=pd.DataFrame(newTestData)

# %%
df2['Predicted Sentiment Score']=predictions2
df2.head(10)
# Out:
#   cashtag                  id      source  \
# 0    $PVA            38793629  stocktwits
# 1   $ORCL  710496429974888400     twitter
# 2   $CTRP  709398139195641900     twitter
# 3    $SPX  719493174167625700     twitter
# 4    $SBH             7867073  stocktwits
# 5   $TNET  711745824884187100     twitter
# 6    $PVA            38793629  stocktwits
# 7   $NFLX  719530483898421200     twitter
# 8   $ADBE            21174505  stocktwits
# 9   $OASM  719699054645612500     twitter
#
#                                                spans  \
# 0                   congrats to whoever bought under
# 1                        5 Best Analyst Rated Stocks
# 2  adding $expe and $pcln to the mix soon;$;I alr...
# 3               Iraq Boosts Oil Production to Record
# 4  Failed breakouts & failed setups;$;Limping on ...
# 5
# 6                   congrats to whoever bought under
# 7                            $NFLX holding it's gain
# 8       $ADBE shorted, there was only 1% short float
# 9                                      Bottom Losses
#
#    Predicted Sentiment Score
# 0                   0.919769
# 1                   0.981834
# 2                   0.981309
# 3                   0.975918
# 4                   0.514061
# 5                   0.798638
# 6                   0.919769
# 7                   0.948992
# 8                  -0.769696
# 9                  -0.807218

# %%
df2.to_csv('newTestData.csv',index=False)
