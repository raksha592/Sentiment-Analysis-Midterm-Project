# %% [markdown]
# ## Task 1: Sentiment analysis of twitter and stockwits data

# %%
import json
from pprint import pprint
import matplotlib as mpl
import matplotlib.pyplot as pltfrom 

from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
 
import numpy as np
import pandas as pd

from keras.layers import Flatten
from keras import regularizers
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading data from JSON

# %%
with open('Microblog_Trainingdata.json') as data_file:    
    Microblog_Trainingdata = json.load(data_file)

for i in range(0,len(Microblog_Trainingdata)):
    Microblog_Trainingdata[i]['spans']=Microblog_Trainingdata[i]['spans'][0]
    Microblog_Trainingdata[i]['sentiment score']=float(Microblog_Trainingdata[i]['sentiment score'])
#pprint(Microblog_Trainingdata)
with open('Microblog_Trialdata.json') as data_file:   
    Microblog_Trialdata = json.load(data_file)
    

#pprint(data)
for i in range(0,len(Microblog_Trialdata)):
    Microblog_Trialdata[i]['spans']=Microblog_Trialdata[i]['spans'][0]
    Microblog_Trialdata[i]['sentiment score']=float(Microblog_Trialdata[i]['sentiment score'])

# %%
with open('Microblogs_Testdata.json') as data_file:   
    Microblogs_Testdata = json.load(data_file)
    
#pprint(Microblog_Testdata)

# %%
for i in Microblog_Trialdata:
    Microblog_Trainingdata.append(i)

# %%
def lower_keys(x):
    if isinstance(x, list):
        return [lower_keys(v) for v in x]
    elif isinstance(x, dict):
        return dict((k.lower(), v.lower() if isinstance(v, str) else v) for k, v in x.items())
    else:
        return x
Microblog_Trainingdata=lower_keys(Microblog_Trainingdata)

# %%
import nltk
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
import string
def stringClean( inputString ) :
    return inputString.translate(str.maketrans('','',string.punctuation)).encode("ascii", errors="ignore").decode()

# %%
def removeStopWords(inputString):
    splitString = inputString.split()
    for word in stop:
        for s in splitString:
            if s == word:
                splitString.remove(s)
    return " ".join(splitString)

# %%
def calculateCosineSimilarity( pVal,gVal ):
    similarity = cosine_similarity(pVal,gVal)
    pNorm = np.linalg.norm(pVal)
    gNorm = np.linalg.norm(gVal)
    wt = pNorm/gNorm
    return wt * similarity[0][0]

# %% [markdown]
# ### Loading Testing and Testing data

# %%
maxlen = 0

X_train = []
X_trial=[]
Y_trial=[]
X_test = [Microblog['spans'] for Microblog in Microblogs_Testdata]
Y_train = []
Y_test = []
output=[]
for Microblog in Microblog_Trainingdata :
    X_train.append(removeStopWords(stringClean(Microblog['spans'])))
    Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
    output.append(Microblog['sentiment score'])
    if maxlen < len(Microblog['spans'].split()) :
        maxlen = len(Microblog['spans'].split())

#for Microblog in Microblog_Trialdata :
 #   X_train.append(Microblog['spans'])
  #  Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
   # if maxlen < len(Microblog['spans'].split()) :
    #    maxlen = len(Microblog['spans'].split())


print(len(X_train)+len(X_test), len(Y_train))
# Out:
# 2510 1710

# %% [markdown]
# ### Tokenize the data and pad shorter reviews

# %%
tokenizer = Tokenizer(num_words=maxlen*20)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen)
data.shape
# Out:
# (1710, 25)

# %% [markdown]
# ### LSTM Model

# %%
model = Sequential()
model.add(Embedding(maxlen*20, 32, input_length=maxlen))
#model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='leakyrelu'))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Flatten())
model.add(LSTM(32, dropout=0.3, recurrent_dropout=0.15))
#, kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l1(0.01)
model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 32)            16000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 24,593
# Trainable params: 24,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(data, np.array(Y_train), validation_split=0.2, epochs=15,verbose = 1)
# Out:
# Train on 1368 samples, validate on 342 samples
# Epoch 1/15
# 1368/1368 [==============================] - 3s - loss: 1.7079 - acc: 0.3567 - val_loss: 0.8281 - val_acc: 0.3626
# Epoch 2/15
# 1368/1368 [==============================] - 1s - loss: 0.7051 - acc: 0.5490 - val_loss: 0.6491 - val_acc: 0.6491
# Epoch 3/15
# 1368/1368 [==============================] - 1s - loss: 0.6466 - acc: 0.6462 - val_loss: 0.6245 - val_acc: 0.6579
# Epoch 4/15
# 1368/1368 [==============================] - 1s - loss: 0.6255 - acc: 0.6806 - val_loss: 0.5998 - val_acc: 0.6813
# Epoch 5/15
# 1368/1368 [==============================] - 1s - loss: 0.5807 - acc: 0.7288 - val_loss: 0.5615 - val_acc: 0.7368
# Epoch 6/15
# 1368/1368 [==============================] - 1s - loss: 0.5192 - acc: 0.7800 - val_loss: 0.5085 - val_acc: 0.7778
# Epoch 7/15
# 1368/1368 [==============================] - 1s - loss: 0.4404 - acc: 0.8209 - val_loss: 0.4616 - val_acc: 0.7749
# Epoch 8/15
# 1368/1368 [==============================] - 1s - loss: 0.3933 - acc: 0.8224 - val_loss: 0.5132 - val_acc: 0.7953
# Epoch 9/15
# 1368/1368 [==============================] - 1s - loss: 0.3637 - acc: 0.8304 - val_loss: 0.4969 - val_acc: 0.7749
# Epoch 10/15
# 1368/1368 [==============================] - 1s - loss: 0.3428 - acc: 0.8355 - val_loss: 0.4982 - val_acc: 0.7719
# Epoch 11/15
# 1368/1368 [==============================] - 1s - loss: 0.3248 - acc: 0.8151 - val_loss: 0.5413 - val_acc: 0.7281
# Epoch 12/15
# 1368/1368 [==============================] - 1s - loss: 0.3599 - acc: 0.8187 - val_loss: 0.5533 - val_acc: 0.7690
# Epoch 13/15
# 1368/1368 [==============================] - 1s - loss: 0.3060 - acc: 0.8582 - val_loss: 0.5428 - val_acc: 0.7749
# Epoch 14/15
# 1368/1368 [==============================] - 1s - loss: 0.2892 - acc: 0.8531 - val_loss: 0.5484 - val_acc: 0.7749
# Epoch 15/15
# 1368/1368 [==============================] - 1s - loss: 0.2854 - acc: 0.8341 - val_loss: 0.5969 - val_acc: 0.7719

# %%
sequences = tokenizer.texts_to_sequences(np.array(X_train))
data = pad_sequences(sequences, maxlen)
predictions = model.predict(data)
for i in range(len(predictions)):
    print(Microblog_Trainingdata[i]['spans'],Microblog_Trainingdata[i]['sentiment score'],"%.3f" % predictions[i])
# Out:
# watching for bounce tomorrow 0.366 0.899
# record number of passengers served in 2015 0.638 0.998
# out $nflx -.35 -0.494 -0.002
# looking for a strong bounce 0.46 0.986
# very intrigued with the technology and growth potential 0.403 0.957
# short worked 0.0 -0.131
# overbought -0.296 -0.295
# absolute garbage still up -0.546 0.651
# biggest market losers -0.438 -0.379
# love this company long time. 0.408 0.829
# $goog $googl would suck -0.398 0.075
# who won't pay anymore -0.349 -0.457
# no edge offered 0.025 0.984
# runs into the 50sma on the acquisition news 0.486 0.735
# t can't go down 0.308 0.875
# now seems like its helping the downtrend -0.372 -0.193
# mastered their supply chain 0.461 0.695
# most bullish stocks on twitter during this dip 0.408 0.992
# big dumping -0.699 0.766
# trade continuing very nicely from yesterday 0.495 0.997
# in from 3.61 0.306 0.695
# stochastic overbought -0.385 -0.620
# unusual call buying 0.336 0.989
# reserves are in decline 0.279 0.695
# all on a longer-term, technical swing long basis. 0.591 1.000
# insiders are selling -0.351 0.394
# what goes up... -0.514 0.002
# if $249.84 breaks we see $245 then $240 -0.519 0.007
# let's see a big bounce 0.361 0.912
# i don't think it will move $fb in the short term -0.042 -0.372
# above 2.25 and it could get going? 0.26 0.885
# hold 0.099 0.847
# may feed off $tsla momentum run lately. 0.359 0.922
# possible double bottom set up 0.29 0.954
# trading at all-time high 0.887 0.867
# if positive outcome w/ lung study5/8 we may see a 13d filing by soros 0.33 0.993
# put the chum out there at key support then next level down -0.32 0.539
# #tesla: great company, bad #stock $tsla -0.065 -0.115
# good idea buy half this and half bac? 0.329 0.909
# alibaba ipo hoopla canâ€™t hide risk of chinese stocks -0.39 0.098
# all on a longer-term, technical swing long basis. 0.591 1.000
# on the fence with this one 0.0 0.414
# stay long apple 0.337 0.966
# looks like drought conditions in soil already -0.122 0.149
# unusual call activity 0.332 0.995
# $mdxg -0.402 0.695
# biggest market losers -0.438 -0.379
# hip sinking? -0.411 0.695
# can't imagine shorts wanting to go into the weekend without taking care of their position 0.36 0.908
# nice volume 0.113 0.927
# $simo basing nice 0.408 0.896
# big money is pouring into facebook from all directions 0.645 0.969
# placed an order to sell 5 shares -0.379 0.279
# go $fb go 0.302 0.718
# out $bidu for now -0.221 -0.158
# short setups looking nice....really nice -0.464 -0.076
# defying the downturn 0.407 0.695
# but man this is one to be careful with -0.291 -0.159
# downgrade -0.463 -0.452
# short $tsla calls -0.618 0.302
# was looking for a long entry but today's price action wasn't appealing 0.215 0.977
# just follow the trend, follow the money flow 0.165 0.991
# tapping on 10.00 0.224 0.905
# will re-enter short on bounce.. -0.46 0.550
# found some good bull setups this week 0.448 0.985
# all going down -0.559 0.552
# so volatile! -0.131 0.695
# sold my 81 calls 0.328 0.436
# i'm watching(and buy targets) 0.344 0.989
# beats the estimize eps consensus by 6c and the estimize revenue consensus by 0.366 0.846
# short percent of float 16.80% -0.16 0.170
#  -0.373 0.695
# add to $fxp $skf positions 0.5 0.971
# long 0.488 0.993
# bottom losses -0.473 -0.293
# ure wish bad news came out just a few days earlier -0.221 0.154
#  0.0 0.695
# $wmt, 13% 0.382 0.695
# added 0.274 0.981
# mkt fell on debt downgrade -0.159 -0.730
# $fcx +3.53% 0.339 0.695
# been very frustrating -0.136 0.695
# thanks for the short -0.264 -0.131
# need to break $4 again 0.132 0.624
# fed cuts rates forecast 0.449 0.954
# stochastic overbought -0.516 -0.620
# very tight price 0.0 0.457
# #oversold 0.406 0.970
# a great step for #china to let $fb in 0.417 0.811
# new squeeze plays -0.339 0.001
# $crm seems a little to high also -0.344 0.019
# pie in the sky 0.365 0.991
# moved upper bollinger band 0.498 0.999
# highest call to put ratio 0.348 0.993
# offers will take place until next week 0.409 0.944
# currently it is the shorts rejoicing -0.54 0.387
# breaking out when the market pulls back 0.413 0.634
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.986
# buy the dip' 0.38 0.911
# $mdxg -0.361 0.695
# blackberry messenger is second only to facebook in user loyalty 0.158 0.998
# headed to all time highs 0.407 0.913
# your shit is broke -0.348 0.777
# buy 0.458 0.891
# weak open and it goes r/g within first 30 mins -0.229 -0.103
# down $2.84 premarket -0.512 0.711
# guess who sold off about $800 million in $mdlz -0.428 -0.034
# buying on weakness 0.511 0.733
# shareholders welcome marriott-starwood deal 0.322 0.930
# peachy prospects 0.339 0.695
# another sell rating, sell rating -0.513 -0.406
# nice day rally! 0.529 0.973
# nice day rally! 0.529 0.973
# quality stocks with high cash returns 0.274 0.976
# led light bulb prices rise in japan 0.054 0.999
# closed buy 0.466 0.987
# highest down volume in last 10 days -0.31 0.612
# with $ibb back over support 0.285 0.511
# long into earnings 0.484 0.986
# considering yahoo bid 0.288 0.904
# after weeks of steady gains,advances in mkt breadth slowe -0.146 0.343
# i will buy aggressively if pulls back 0.386 0.783
# nice day rally! 0.529 0.973
# gets 26 patents and goes down -0.373 0.082
# buying on weakness 0.511 0.733
# led light bulb prices rise in japan 0.054 0.999
# is a later riser, 0.203 0.695
# could that have been a strategy to exit shorts before the big pop? 0.316 0.958
# piper upgrades symantec on improving renewal rates and enterprise growth 0.525 0.993
# look for strong solar rebound today! 0.304 0.969
# i think the dnf crew can get this $nflx short into the next 30 days heading into earnings -0.308 -0.171
# red $aapl dragging down $qqq -0.5 -0.081
# cuts outlook down -0.236 -0.448
# weakness continues again. -0.41 0.669
# watchlist top stocks 0.342 0.971
# long 0.428 0.993
# joint bid for yahoo's internet assets 0.228 0.973
# patience pays off 0.272 0.850
# bad governance -0.331 0.214
# bottom losses -0.756 -0.293
# sales numbers still holding up so well 0.315 0.965
# i just feel the people who are buying are the same ones with their finger on the sell button -0.054 -0.484
# gap filled 0.226 0.884
# debt crisis entered a dangerous new phase -0.331 -0.424
# just about to break out to new highs 0.469 0.994
# next resist is 64.40's 0.201 0.631
#  0.0 0.695
# looks really toppy right here. -0.191 -0.075
# this will pop after the holiday 0.555 0.945
# breakup will cost billions -0.397 0.695
# news breaks first and fastest on twitter $twtr 0.364 0.792
# overbought -0.296 -0.295
# continues to consolidate above previous break out area. 0.375 0.875
# good to load up be confident 0.281 0.990
# long 0.394 0.993
# buy call! 0.095 0.988
# companies shld be worried about icloud -0.329 -0.462
# $spy -0.05% 0.028 0.756
# but decent supt here-expect some upside 0.302 0.976
# monday sold -0.37 -0.348
# sector has been taking a beating recently, could be positive here 0.361 0.990
# at 11x earnings, $aapl is a steal 0.561 0.431
# multi top on $mcd -0.474 0.859
# us adds 321k jobs in november 0.243 0.996
# why is $fb falling? -0.304 0.180
# calls for nice gains 0.396 0.991
# someone bought lots of calls mon 0.444 0.998
# moving up again 0.12 0.713
# $ea points to the two facebook games 0.048 0.887
# ready to exit bankruptcy 0.298 0.617
# starting to creep up 0.28 0.820
# looks like bo coming 0.36 0.884
# 2m this year would be amazing 0.151 0.810
# moved upper bollinger band 0.498 0.999
# $gogo short -0.318 -0.131
# eu getting closer to charging google over android -0.319 0.610
# supermarket stocks rally as tesco plans to axe non-core uk assets 0.346 0.991
# china winners 0.452 0.966
# looks like an ascending channel 0.363 0.981
# patience on the buy precedes patience on the sell 0.0 0.141
# oil to break out 0.666 0.916
# brand name is to big for it to fail 0.226 0.780
# top #netpayoutyields 0.426 0.972
# long $amzn oct $240 calls 0.628 0.999
# under pressure along with the market 0.014 0.615
# patience pays off 0.272 0.850
# stock splits are lipstick on a pig! -0.347 0.764
# making new highs for the year 0.53 0.987
# held up well after the big gains! 0.695 0.966
# wait and see before taking any action 0.0 -0.139
# markets are still acting weak -0.443 -0.479
# breaking below support -0.397 0.899
# sold 20% of our concentrated stake -0.344 0.039
# want to go this morning 0.28 0.890
# cracking lower early -0.511 -0.050
# $fb & $ibb down -0.527 0.086
# higher in afternoon trade 0.243 0.940
# oil to break out 0.666 0.916
# added $sso 64.33 0.626 0.981
# $fb $112 calls .55 entry 0.509 0.589
# is tiffany's overvalued -0.25 -0.036
# $intc & $aapl strong 0.722 0.910
# after crunching #'s 0.477 0.695
# biggest gainers today large caps 0.556 0.987
# $aapl a new long if 110.61 is broke 0.379 0.994
# added to our $gild position 0.422 0.999
# largest online gaming market 0.226 0.615
#  -0.541 0.695
# bottom losses -0.659 -0.293
# stopped out even from yesterdays entry -0.413 0.198
# micron shares pounded on fears of loss of business from apple -0.596 0.383
# closed buy 0.466 0.987
# over 225 million new internet users are being added globally every year 0.337 0.999
# $uvxy broke 10.00 amazing!!! 0.265 0.993
# long leaps 0.438 0.993
# looks like that support line around 24.90 held 0.331 0.990
# retreats like clockwork -0.488 0.516
#  0.0 0.695
# its time to sell banks -0.763 -0.604
# upgrades to outperform 0.61 0.994
# unusual call buying 0.336 0.989
# holding strong 0.192 0.997
# three of my hot stocks today 0.461 0.900
# bulls are out 0.323 0.920
# patents system 0.271 0.815
# markets back in black for 2016 0.271 0.958
# the losers buying $tsla at these levels -0.545 -0.301
# adding $expe and $pcln to the mix soon 0.554 0.999
# today's losers -0.317 -0.158
# not feel terribly good -0.126 0.764
# $spy up only 0.6% 0.228 0.756
# record number of passengers served in 2015 0.638 0.998
# while we think $tnh is a winner 0.415 0.858
# reiterated 'outperform' rating 0.694 0.949
# airplanes are still flying 0.262 0.651
# $mtd $341 from $325 0.362 0.695
# bond buying is signaling some bad moves for the market -0.361 0.020
# i see more downside in next two weeks -0.477 -0.183
# has just about run its course -0.449 0.851
# biggest market losers -0.438 -0.379
# loaded up on $bsx yesterday 0.664 0.940
# notable gainers among liquid option names this morning 0.513 0.994
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.026 0.997
# 5-star analyst @brianwieser from pivotal research upgraded rating on $googl to buy 0.561 0.994
# santa rally 0.22 0.932
# iphone 6s is still better than galaxy s7 0.385 0.646
# didn't factor in anything other than google and repeated good earnings 0.102 0.841
# facebook is succeeding where google should have dominated 0.531 0.965
# $uco +4.44% 0.442 0.695
# up on day and will continue a surge next week. 0.509 0.878
# facebook stock is now +$72 0.272 0.965
# ripe for a squeeze again -0.216 -0.075
# biggest market losers -0.438 -0.379
# with personal story sharing declining -0.393 -0.513
# upgrades 0.334 0.943
# saying this is a peak = fear mongering 0.329 0.695
# the most trending 0.216 0.958
# who won't pay anymore -0.349 -0.457
# still they are saying bullish lol -0.038 0.900
# today's bull flag 0.2 0.934
# growth rate of approximately 122.0% to 124.9%. 0.305 0.823
# lots of nice setups in energy  0.293 0.958
# bad governance -0.331 0.214
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# landed in $ea 0.422 0.695
# bought $skf as a hedge 0.466 0.984
# transports always lead the way 0.594 0.988
# here is no case here 0.18 0.695
# $joe getting attention. no.2 on nyse 100 top buying list 0.788 0.967
# short setups looking nice....really nice -0.464 -0.076
# highest close since 0.387 0.675
# should bring $spx down into the close. -0.462 0.615
#  0.295 0.695
# money flow & stochastic dropping -0.577 -0.432
# 9% run for this watch list winner 0.066 0.999
# have had 2 wks of fund inflows for the first time 0.58 0.785
# $goog $googl would suck -0.404 0.075
# ses warrants to buy $1.17b & 14.97% of amerisourcebergen(pbr16) shares 0.301 0.859
# not every idea $amzn has is bad. 0.235 0.817
# looks primed 0.4 0.760
# yahoo extends bidding deadline as interest grows 0.613 0.994
# good news for domestic automakers 0.413 0.772
# mrkt needs to washout -0.055 -0.394
# valuation is high -0.355 -0.028
# $wfm dropping below $30 again -0.499 -0.213
# $htz -0.341 0.695
# recall adds to reliability issues -0.267 0.344
# i'm out -0.14 0.384
# think i may just start to avoid bios -0.23 0.589
# lvmh affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.981
# no crying you get out -0.462 0.559
# trying to break daily trend line! 0.485 0.980
# went long on this 0.449 0.993
# if bulls lucky enuff to get an upside gap fill, better take it 0.054 0.993
# wouldn't call any of these banks h+s quite yet 0.335 0.764
# banks to implode -0.298 0.310
# new recommendation from carl kirst of bmo capital markets 0.566 0.939
# near a buy point last week 0.102 0.934
# pc shipments drop to lowest level since 2007 -0.452 -0.340
# momentum building for breakout trigger 0.592 0.997
# consistent gains but small 0.219 0.966
# $aapl cult on stocktwits is actually disgusting -0.151 0.422
# higher in afternoon trade 0.243 0.940
# sector stocks leading today 0.454 0.976
# $adbe flying 0.361 0.695
# tesla to recall 2,700 model x suvs over seat issue -0.31 -0.470
# back in 0.383 0.583
# us adds 321k jobs in november 0.243 0.996
# under pressure along with the market 0.014 0.615
# cash & cheap financing is fueling a wave of acquisitions 0.39 0.666
# worst #sentiment for #sp1500 #stocks at market close -0.479 0.485
# gold going parabolic 0.442 0.900
# i would take profits if you have them -0.244 0.248
# never widen your stop to stay in a trade -0.412 0.766
# slips alongside shares on nsa leak news -0.198 0.737
# best outperformers ranked 0.492 0.995
# $googl is setting up above its 50-day moving average 0.696 0.747
# weakest sector this year -0.458 0.674
# tesla is recalling 2,700 model x cars -0.291 -0.140
# unusual call activity 0.421 0.995
# wish had my puts bac -0.485 -0.163
# see if they maintain 15% yield 0.078 0.522
# look at all the shorts running for cover 0.375 0.601
# as with all 3x etfs, it is subject to decay due to daily rebalancin -0.234 0.047
# signs of life are emerging :) 0.27 0.721
# markets back in black for 2016 0.271 0.958
# i rather be neutral to bullish rather than bearish 0.185 0.594
# diversifies. adds international exposure 0.219 0.758
# out $aapl -0.27 0.422
# capped -0.172 0.695
# long on 0.185 0.993
# $googl patents turn signal detector for autonomous cars. 0.241 0.852
# moves up a little more today off of cup and handle 0.306 0.887
# makes less profit than the sales of $aapl watch -0.641 0.276
# comparable store sales -4% -0.441 0.183
# making higher highs & higher lows as it consolidates over past several weeks 0.478 0.990
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.936
# sold at 139.26 and flat -0.695 -0.329
# suddenly realizing -0.147 0.695
# long 0.488 0.993
# $fit and $sune have not changed. -0.179 0.695
# $nugt fucking beast mode, kicking shirts in the nugt pouch 0.665 0.695
# my hospital reits are slaughtered -0.399 0.695
# i want to cry -0.595 0.627
# 3 top japan etfs to surge higher in 2h 0.456 0.995
# new bullish conversation activity 0.461 0.969
# bottom losses -0.411 -0.293
# just follow the trend, follow the money flow 0.165 0.991
# short squeeze ready to upside w crossing important technical level 0.219 0.953
# i'll take the other side of that trade 0.422 0.988
# i love this stock/co -0.125 0.493
# no choice but to be positve 0.323 0.695
# word on the street is that allergen is looking at endo international 0.472 0.736
# buy $wynn 0.489 0.891
# $tsla hype the news -0.073 0.374
# three black crows followed by a potential bear flag -0.569 0.079
# looking for a strong bounce 0.46 0.986
# trails $msft $orcl $goog $crm $adbe 0.177 0.957
# stay with best of breed 0.417 0.901
# nice day rally! 0.529 0.973
# orgetting the potential relative value of its users 0.316 0.981
# looking goo for 35.80s break out. it must hold 35.40s 0.307 0.929
# usio ops are profitable -0.362 0.695
# bot $gmcr 75 nov call 0.614 0.995
# reasons for caution about chinese stocks -0.317 -0.107
# outperforms 0.525 0.695
# earish trader bets $550k that stock will sell off -0.493 -0.266
# congrats shorts -0.494 0.387
# downbeaten stocks may be ripe for buys 0.316 0.994
# picked some up 0.653 0.695
# worst performers today -0.351 0.448
# nt done good with that name so will pass it -0.319 0.753
# its been nothing but down -0.43 0.631
# bullish ma crossovers 0.457 0.981
# player onto the 211 puts -0.652 -0.163
# someone wants in 0.29 0.626
# $pcln back over 'up' trendline 0.308 0.881
# found some good bull setups this week 0.448 0.985
# is just humming easing overbought -0.404 -0.295
# just follow the trend, follow the money flow 0.165 0.991
# is up 19% 0.128 0.695
# sector stocks leading today 0.454 0.976
# ron johnson tried, and failed, to inject a bit of apple culture into jc penney -0.335 0.028
# not the prettiest candlesticks 0.0 0.695
# agree risky watching very closely -0.375 0.035
# breakout from the consolidation zone 0.724 0.980
# took small posistion on $tsla -0.114 0.048
# flop would just get everyone running to the fences. -0.546 0.314
# unusual call activity 0.421 0.995
# worst #sentiment for #sp1500 #stocks at market close -0.479 0.485
# new squeeze plays -0.339 0.001
# people are calling it bearish -0.148 -0.195
# long $sq 0.325 0.993
# fader play here -0.219 0.684
# all sectors improved in bullish breadth. 0.647 0.917
# top-rated 0.428 0.695
# stochastic overbought -0.516 -0.620
# china february retail sales: e-commerce remains resilient 0.383 0.958
# china february retail sales: e-commerce remains resilient 0.383 0.958
# large cap tech is finally trying to catch up with the rest of the market 0.373 0.903
# stock dropping hard... -0.626 0.156
# recall will not impact financial results 0.198 0.525
#  0.39 0.695
# very weak res -0.263 -0.448
# gap up today?  0.454 0.909
# top-rated 0.428 0.695
# coming from far could go far 0.298 0.984
# lnkd is great but doesnt the potential side with fb 0.484 0.949
# long $endp @ $26.23 on $agn b/o rumor 0.57 0.993
# oil back above 60 0.543 0.741
# short setups looking nice....really nice -0.464 -0.076
# gist of downgrades was apple failed to make a phone th -0.312 -0.336
# another 3% gain in $rigl 0.378 0.507
# $stx 0.334 0.695
# $grpn having a much better day than $fb -0.285 0.604
# stocks insiders are bullish on 0.433 0.937
# hipments on track to exceed forecasts 0.367 0.695
# lvmh affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.981
# cover all 0.114 0.695
# ss interest rose on 12/15 on day before we hit our lows. http://stks.co/c1qkr -0.405 0.578
# most bullish stocks on twitter during this dip 0.408 0.992
# $fcx 1.9% now -0.327 0.695
# first quarter is amazing 0.322 0.998
# $sap q1 disappoints as #software licenses down -0.431 0.235
# today's losers -0.317 -0.158
# looking for a sharp move up in equities 0.368 0.633
# gap fill coming up 0.511 0.995
# report: apple signs up for google's cloud -0.38 0.423
# $fb to $107 tomorrow!? 0.539 0.864
# over 225 million new internet users are being added globally every year 0.337 0.999
# covered call 0.329 0.995
# long 0.66 0.993
# i've been picking up railroad stocks for the retirement acct 0.441 0.886
# when there is turmoil in the mena region shippers perform 0.397 0.695
# going back in, but slowly 0.119 0.459
# down 12% since i alerted it a short sell on 3-25 -0.391 -0.609
# bet the farm on 0.395 0.695
# interest heats up for @yahoo $yhoo 0.413 0.913
# the parties over -0.223 0.695
# stocks higher in afternoon trade 0.314 0.968
# highest call to put ratio 0.348 0.993
# apparently intel thinks women should get paid the same as men 0.447 0.559
# $gs is looking weak while this market is moving higher not a good sign -0.597 0.619
# 1mil buy order at 0.426 0.891
# top stocks 0.376 0.943
# top stocks in 2015 are ready to lead again in 2016 0.414 0.999
# 640m globally this week on avengers really sick ,stan lee is a beast 0.24 0.945
# plus its irish based 0.226 0.695
# in 0.646 0.695
# 13f shows new stakes in  0.468 0.754
# gap up today?  0.446 0.909
# breakout watch 0.352 0.993
# short setups looking nice....really nice -0.464 -0.076
# getting a lot of hype 0.095 0.476
# court tells states to leave $goog alone 0.291 0.687
# got a nice push today 0.28 0.771
# unloaded $16,673 worth of the ensign group, inc. (nasdaq:ensg) shares -0.46 0.715
# $23 by the end of the week..did you snatch ur 21 0.257 0.638
# continues its rally 0.538 0.929
# it with lawsuit from russian search engine -0.17 0.695
# #oversold 0.406 0.970
# have had 2 wks of fund inflows for the first time 0.58 0.785
# mu down 2.3% today and down 8.9% -0.469 0.803
# unusual call buying 0.336 0.989
# $ko:us #coca-cola co 19oct positive 0.646 0.962
# sales weak -0.515 -0.536
# just broke resistance 0.598 0.845
# $ffiv up 7$ 0.32 0.695
# bot $chrw 0.437 0.954
# break-out thru 50 & 200- dma 0.504 0.953
# now up 2.2% 0.523 0.695
# bid for reargument denied by judge -0.354 0.783
# with upcoming first support in a few days or weeks! 0.274 0.809
# $cafn cachet financial solutions surging forward today post earnings up +13.26% 0.418 0.793
# lots of green on the 5 min 0.318 0.997
# looking to buy 0.32 0.895
# i don't think is the right fit -0.296 -0.246
# stochastics finally starting to turn up 0.702 0.820
# another sell rating -0.389 -0.069
# very nice breakout on a very nice stock 1.0 0.994
# launching shopping bot 0.348 0.954
# buy these 3 stocks while there's blood in the streets 0.415 0.971
# goldman sachs reiterates conviction buy on 0.334 0.945
# losers -0.383 -0.297
# long term uptrend intract so far 0.368 0.987
# the most trending 0.216 0.958
#  0.0 0.695
# will be adding on dips 0.154 0.936
# added long at friday close 0.513 0.998
# losing $400m of $aapl's business -0.015 0.322
# #oversold 0.406 0.970
# picking up a couple shares of $goog today 0.364 0.789
# my broker has no shorts who has them? -0.533 0.387
# sales numbers still holding up so well 0.315 0.965
# trying to drag $bidu with it. -0.524 -0.083
# over 225 million new internet users are being added globally every year 0.337 0.999
# downgraded to neutral at deutsche bank -0.446 -0.054
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.980
# buy zone today 0.285 0.912
# big picture is brilliant 0.355 0.766
# bounce right now has no vol, more vol when it slid 0.19 0.614
# another story stock with an unhappy ending -0.426 0.145
# love it 0.648 0.493
# most bullish stocks on twitter during this dip 0.408 0.992
# mark zuckerberg is doing an amazing job 0.326 0.969
# today's top gainers 0.447 0.990
# has had a history of a lack of pr -0.21 0.695
# closed friday with the rs line in new highs 0.371 1.000
# look out belooooooowwww -0.85 0.739
# whole semiconductor space looks interesting 0.328 0.901
# to combine in $37 billion deal 0.241 0.933
# peaks above hod 0.318 0.966
# problem for shorts 0.358 0.387
# awesomely bullish stocks 0.68 0.965
# there is a good base building 0.228 0.898
# biggest market losers -0.438 -0.379
# highest call to put ratio 0.348 0.993
# sold to close $qqq puts for +34% -0.059 -0.354
# ooks pretty bullish for now 0.323 0.917
# looks really interesting on drop 0.579 0.444
# covered some shorts 0.294 0.798
# add to 0.483 0.964
# triple top forming. 0.028 0.859
# will end up selling for pennies on the dollar -0.441 0.434
# looking sexy this morning 0.678 0.878
# whole foods shareholders vote down activist initiatives -0.076 0.546
# imagine $aapl tv impact!! $$$ 0.24 0.422
# southwest is at its lowest multiple ever 0.106 0.885
# still too early for an entry -0.387 0.186
# moved upper bollinger band 0.498 0.999
# today i bought more 0.087 0.967
# won't have anyone buying products -0.429 0.216
# short setups looking nice....really nice -0.464 -0.076
# still long term fan! 0.377 0.965
# what a nice reversal. 0.318 0.860
# tripadvisor jumps on m&a rumors 0.47 0.695
# $tsla recalls 2,700 model x vehicle -0.336 -0.456
# long tech 0.384 0.999
# breakout should be confirmed 0.448 0.980
# best performers 0.376 0.851
# very tight on the avail stock for shorting -0.406 -0.391
# get into $wfm and $mjn 0.415 0.872
# stochastic overbought -0.516 -0.620
# bounced off target buy area -0.299 0.874
# oversold 0.43 0.970
# double top reject -0.341 0.823
# added. 0.47 0.981
# working on cuba deals 0.419 0.985
# dividend hike green light 0.316 0.999
# i am excited about all these plays 0.322 0.679
# commodity weakness -0.376 0.677
# $fb small flong 109.25 via calls 0.352 0.942
# had a nice breakout of the recent consolidation 0.452 0.994
# sells flat..i am out.. -0.541 0.695
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# reserves are in decline 0.279 0.695
# this pull back of -0.03 0.583
# pie in the sky 0.365 0.991
# first quarter is amazing 0.322 0.998
# $tfm will have a way to go price wise to compete with kroger. $kr 0.129 0.949
# sector stocks leading today 0.454 0.976
# biggest st50 gainers 0.452 0.959
# bears take a clear near term advantage -0.501 0.187
# will a onetime zombie stock rise again? 0.241 0.947
# today's bull flag 0.2 0.934
# iphone se could be doing better than expected 0.395 0.929
# now up to 200 stocks making new 52 week highs 0.458 1.000
# would short $amzn on any rally -0.621 0.687
# after losing about $1 billion on $vrx? -0.643 0.197
# $cat +5.10% 0.586 0.695
# the top 10 brands for #millennials - $aapl is #1, and $fb is way off the list at #65. 0.562 0.976
# looking tasty 0.31 0.736
# sell short position on 0.361 0.536
# nice day rally! 0.529 0.973
# damn me and low priced stocks -0.482 0.373
# spy the bubble is in stock buy backs -0.268 0.909
# sell signal by $ndx internals -0.541 -0.033
# bullshit -0.209 0.695
# $x +2.27% 0.144 0.585
# this is what you get -0.007 0.559
# another one to add, already happily holding 0.448 0.993
# rsi is down at 20 0.418 0.764
# $baba is going to be an interesting one 0.233 0.575
#  0.315 0.695
# buy the dip' 0.38 0.911
# there's no reason why $googl can't get back to $1,000 0.288 0.903
# short -0.453 -0.131
# equity indexes working on a positive engulfing for march 0.308 0.997
# highest call to put ratio 0.348 0.993
# oil slid to a four-year low after -0.369 -0.110
# sideways 0.0 0.695
# unusual call activity 0.421 0.995
# green, lol... make-up to cover ugliness 0.242 0.979
# slight green 0.328 0.979
# pivotal sees 27% upside for alphabet 0.372 0.996
# refuse -0.35 0.695
# profitable hard and software 0.559 0.692
# $msft is opening up its #xboxlive online service 0.225 0.971
# here we gooo 0.268 0.695
# sold my 81 calls -0.312 0.436
# at resistance right here -0.105 0.112
# holding 0.171 0.977
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.392 0.997
# stocks at support w/ high trade quality 0.503 0.989
# finally broke free from big brother's shadow? 0.206 0.816
# i like this ascending triangle 0.478 0.985
# i'd be short $fast -0.625 -0.557
# in play longs 0.273 0.960
# the most trending 0.216 0.958
# supermarket stocks rally as tesco plans to axe non-core uk assets 0.383 0.991
# out of $kre -0.381 0.695
# time to accumulate for a long position 0.668 0.998
# no edge offered 0.025 0.984
# oil to break out 0.666 0.916
# found some good bull setups this week 0.448 0.985
# sets up for breakout 0.528 0.980
# something big is gonna happen here 0.0 0.766
# winning pick this week 0.452 0.905
# calls 0.472 0.917
# double bottom 5.2 0.23 0.768
# lets see one more dip -0.274 0.585
# consistent gains but small 0.219 0.966
# on cusp of a major bollinger breakout on daily 0.511 0.920
# hanging tough in down market due to analyst upgrades 0.394 0.963
# coal stocks are poking their head up 0.362 0.934
# still holding 0.581 0.971
# is exceptionally bullish for romney, the mkt, and the economy. 0.421 0.820
# mid-single digits ebitda growth 0.357 0.823
# posts 60 percent jump in 4q profit 0.586 0.769
# loving btu and the coal stocks in here 0.437 0.967
# watching paint dry 0.0 0.035
# fundamentally nothing has changed 0.198 0.631
# stares into the abyss -0.325 0.695
# smartphone wars wound samsung 0.283 0.695
# where the growth is 0.252 0.823
# long this morning 0.476 0.996
# took my proprietary profit exit -0.334 0.250
# $yhoo refuse of $msft offer of 45 b is going to go down as one of the worst decisions ever. 0.012 0.509
# has gained an average of 0.9% a week for the last nine years 0.279 0.816
# eyeing $ra w take-over interest 0.041 0.860
# added to our $gild position 0.408 0.999
# investor long-term stock recommendation 0.557 0.764
# eps growth is around 12% so far 0.316 0.997
# easonably priced high growth institutional fave glamour name that is going at least 30% higher 0.342 0.765
# bull of the day 0.769 0.910
# let's go up gilead 0.328 0.862
# european debt once again keeps stocks down -0.374 0.412
# nice little cup-and-handle shaping up 0.342 0.980
# bail out 0.058 0.695
# i dumped $pypl and $prlb -0.506 0.695
# top #netpayoutyields 0.426 0.972
# cfo sees profitability from 0.211 0.695
# price target raised 0.269 0.787
# so sad to see such a loved company eating dirt. -0.453 0.720
# is up 19% 0.309 0.695
# have cash to burn. 0.356 0.921
# downbeaten stocks may be ripe for buys 0.316 0.994
# strictly day trading this one long and short off 5 minute 0.035 0.866
# aggressive buy 0.306 0.975
# long 0.444 0.993
# close above 28.64 0.308 0.615
# will this cold put a dent in the massive horizontal rig production -0.237 -0.203
# long 0.394 0.993
# over the tl it can go to 114, below it can go to 90. 0.0 0.819
# accumulating more $bsmx on any pullback 0.417 0.695
# record number of passengers served in 2015 0.638 0.998
# then trail up. 0.236 0.695
# bullshit! all #applestores are empty in #china -0.329 0.767
# downgrade -0.463 -0.452
# another strong rail today after breaking intraday resistance 0.468 0.976
# heard netflix is raising its prices. it's all good it's worth it though 0.275 0.891
# yet not that much (price) has changed 0.036 0.803
# stocks insiders are bullish on 0.433 0.937
# markets are still acting weak -0.443 -0.479
# top #netpayoutyields 0.426 0.972
# s1 above gap. keeping an eye on s2 0.346 0.884
# shorts likely to take profits into close -0.503 0.382
# i see no reason to sell yet -0.093 -0.223
# ripping early 0.325 0.565
# keeping my stops a bit on the tight side 0.135 0.911
# receives 7-year, $50m contract 0.497 0.810
# splat! poor q1 orders -0.453 0.235
# with oil prices down further, oil stocks looking less cheap -0.42 -0.138
# finding support 0.259 0.961
#  0.0 0.695
#  0.406 0.695
# $googl patents turn signal detector for autonomous cars. 0.393 0.852
# wants lower -0.37 -0.173
# add in 0.354 0.964
# i see a 20 percent upside in $fb shares from here 0.589 0.881
# great growth stk & also raised dividend 0.597 0.929
# $endp being sued by ft -0.602 0.695
# breaking 52 week highs timing looks great now 0.419 0.996
# largecap growth fundholders get lift 0.597 0.688
# progress witnessed 0.436 0.695
# trying to drag $bidu with it. -0.524 -0.083
# 60% short interest or not -0.315 -0.011
# the momo leaders are taken down one by one -0.351 0.149
# stochastic overbought -0.385 -0.620
# new squeeze plays -0.339 0.001
# active puts -0.49 -0.163
# mulls sale of $1 billion venture capital portfolio 0.295 0.933
# strong buy within a month 0.119 0.983
# buy these 3 stocks while there's blood in the streets 0.415 0.971
# i'm watching(and buy targets) 0.344 0.989
# $yhoo have lost 50% since nov 14 -0.422 0.114
# wouldn't be surprised to see a green close 0.416 0.902
# failed breakouts & failed setups -0.419 -0.207
# high-flyers have been falling -0.501 0.341
# decision to sell robot business exposes growing pains -0.289 -0.124
# stocks insiders are bullish on 0.433 0.937
# drop expected -0.002 0.238
# upgraded to a buy by alpha street research 0.715 0.987
# worth a chance here 0.145 0.731
# rally friday! 0.66 0.967
# expects to break even 0.219 0.730
# all higher 0.295 0.945
# adobe receives new rating from top analyst 0.141 0.950
# alot to worry about -0.319 0.695
# we see more reasons to be cautious -0.093 -0.275
# huge buy in all these names 0.608 0.980
# $msft 0.43 0.971
# but verizon is still the bidder to beat 0.404 0.772
# could the pride of social media be gettin ready to fall? -0.287 -0.033
# gold going parabolic 0.442 0.900
# hold through all the media bs and you will be profitable 0.543 0.847
# biggest market losers -0.438 -0.379
# #sectorbreadth strongest sector is industrials 0.545 0.790
# uch a bloated valuation -0.536 -0.222
# i love blood like a vampire.....keep bleeding for me -0.391 0.368
# $fb and $ibb still weak -0.355 -0.628
# bull candle 0.335 0.923
# $ief bullish 0.423 0.917
# best scenario going forward is this stock slowly falling everyday -0.264 0.585
# plus its irish based 0.146 0.695
# today's losers -0.317 -0.158
# if that's what you want then buy some 0.245 0.871
# just sold 2 apr-22 115 calls -0.024 0.622
# stochastic overbought -0.385 -0.620
# long position on 0.674 1.000
# new hod 0.432 0.971
# longs 0.511 0.964
# beat 0.284 0.806
# down 25% since tue morning. -0.527 0.788
# 10% dividend increase rewards patient investors 0.484 0.972
# go long until exp imo 0.414 0.995
# remember when zuck in 2010 told us he was going to fix email with it? 0.091 0.838
# bought a little yesterda 0.562 0.989
# long term uptrend 0.53 0.989
# sets up for breakout 0.528 0.980
# picked up $calm 0.47 0.695
# advance 0.604 0.695
# gets a patent and goes up .20 today 0.432 0.533
# don't like -0.483 0.644
# gale stacks up poorly from an insider ownership -0.314 0.695
# nice day rally! 0.529 0.973
# #oversold 0.406 0.970
# took a small position 0.344 0.973
# continues to base on the weekly chart -0.047 0.052
# amazon just signed a deal to lease 20 boeing 767 cargo planes 0.396 0.988
# today's losers -0.317 -0.158
# up $5.80 0.334 0.695
# eps growth is around 12% so far 0.316 0.997
# may not be bad 0.081 0.323
# top #netpayoutyields 0.426 0.972
# next major platform 0.374 0.759
# dailymail content is perfect for yhoo demographics 0.153 0.849
# investors are nervous about outlook, as they should be. -0.357 -0.051
# money flow positive 0.322 0.981
# electronic arts attracts more investors 0.409 0.819
# biggest market losers -0.438 -0.379
# down 5.43 % -0.392 0.695
# multiple expansion intact as well! 0.281 0.857
# added $regn at 402 0.589 0.981
# plunging! back to -0.628 0.583
# running 0.284 0.771
# add to $fxp $skf positions 0.501 0.971
# get ready for the 560 *flush* -0.264 0.487
# it needs a new tablet strategy -0.195 0.198
# taking some profits -0.142 0.021
# down day for all biotechs good to load up 0.281 0.963
# still loving it today 0.385 0.769
# breaking 52 week highs timing looks great now 0.419 0.996
# timberrrr -0.562 0.695
# the best stocks for 2012 0.463 0.977
# double bottom could be in 0.271 0.888
# 3-star analyst joe wittine from longbow research reiterated a hold rating 0.214 0.959
# still having some trouble at the resistance line 0.071 0.970
# accumulation chart continues to make new highs showing accumulation continuing to take place 0.497 0.982
# apple hires former amazon executive george stathakopoulos as head of corporate data security 0.146 0.892
# has been slipping -0.245 0.695
# bullish reversal setup and breakout 0.441 0.995
# near hod 0.366 0.931
# moody's downgrade -0.299 -0.452
# markets back in black for 2016 0.271 0.958
# this one is looking beat up and interesting -0.084 0.854
# $amd is a two dollar spec play -0.163 0.286
# sell signal by $ndx internals -0.501 -0.033
# starting to creep up -0.014 0.820
# invest in elon 0.327 0.695
# still have my position 0.381 0.980
# minuscule 0.09% gain in $ziv -0.059 0.355
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.986
# receivable going to zero -0.343 0.552
# cisco also lower -0.416 -0.403
# bullish ma crossovers 0.457 0.981
# sell $rht -0.591 -0.319
# in play longs 0.273 0.960
# next 5-6 charts illustrate a bullish weekly outcome 0.119 0.934
# i would buy some wtsl at these prices 0.193 0.877
# more positive comments from $ms 0.426 0.962
# volume footprint looks great -0.097 0.832
# drugs and biotech getting perky 0.387 0.476
# wants to ta -0.265 0.626
# companies shld be worried about icloud -0.329 -0.462
# negative p&l on hardware -0.387 0.695
# eyes more disposals in bid to appease city backers 0.286 0.783
# gap fill 53.53 still waiting. 0.085 0.960
# long 0.488 0.993
# pie in the sky 0.365 0.991
# afternoon selloff as usual will be brutal -0.569 0.573
# short more  -0.605 -0.131
# has a great cash balance 0.493 0.942
# calls for nice gains 0.396 0.991
# top holdings 0.311 0.859
# getting out of his -0.374 0.476
# strong 5min @above bollies 0.235 0.961
# near a buy point last week 0.093 0.934
# google will soon start selling chromebooks at walmart and staples 0.34 0.896
# broke out now of his bull flag channel and make new highs 0.369 0.993
# start strong finish weak -0.086 -0.042
# services like $nflx and #hulu are growing much faster than cable 0.364 0.824
# top stocks 0.376 0.943
# goldman sachs reiterates conviction buy on 0.622 0.945
# $aapl max pain -0.063 0.422
# with oil prices down further, oil stocks looking less cheap -0.42 -0.138
# got some more 0.295 0.825
# favorite stocks 0.401 0.886
# buy 0.437 0.891
# run run $amzn up 4.4% now 0.477 0.965
# consumers keep cautious stance -0.258 0.123
# all on a longer-term, technical swing long basis. 0.591 1.000
# $fb is taking the shine off $aapl and $goog -0.13 -0.066
# broken out of a major horizontal resistance 0.345 0.860
# pie in the sky 0.365 0.991
# balancing roic and growth to create value 0.334 0.823
# locked in some $fb puts for nice gain -0.524 0.002
# we close around $34 it's a good sign 0.494 0.922
# $nflx more positive comments from $ms 0.085 0.987
# stochastic overbought -0.516 -0.620
# not all time low , been lower -0.268 -0.717
# if one is to go long, money rotating into large cap tech 0.383 0.993
# looks great 0.396 0.806
# starting to show some relative strength 0.334 0.820
# time to stomp on some dreams. -0.258 0.058
# if positive outcome w/ lung study5/8 we may see a 13d filing by soros 0.33 0.993
# more test of 12.85 coming up 0.152 0.929
# rsi lowest level since october 2012 0.165 0.654
# long setup 0.438 0.993
# baird upgrades tesla motors $tsla to outperform 0.52 0.892
# my 18 year old and 14 year old are never on $fb  -0.258 0.304
# sector stocks leading today 0.454 0.976
# $yoku 0 0.0 0.695
# may not be as secure -0.308 0.785
# the best stocks for 2012 0.463 0.977
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.999
# today's momentum movers 0.282 0.976
# google will soon start selling chromebooks at walmart and staples 0.196 0.896
# found some good bull setups this week 0.448 0.985
# holding up relatively well compared to the broad market 0.394 0.960
# less than stellar day but it held the 50 day moving average -0.14 -0.021
# a beautifully orchestrated marke 0.152 0.695
# up 7$ 0.177 0.695
# cures 96% of hard-to-treat 0.534 0.760
# long 0.23 0.993
#  0.0 0.695
# let it run 0.473 0.923
# yahoo extends bidding deadline as interest grows 0.329 0.994
#  -0.272 0.695
# today i bought more 0.087 0.967
# you will enjoy the bull run that just started 0.376 0.955
# issues statement on debt ceiling -0.341 -0.382
# there's a good short spot -0.434 0.068
# worst performers today -0.365 0.448
# insiders are selling -0.351 0.394
# good news for domestic automakers 0.413 0.772
# can one of the cheerleaders show me actual valuation work -0.205 -0.401
# up to $95 after market! 0.342 0.615
# buying on weakness 0.511 0.733
# three of my hot stocks today 0.461 0.900
# ready for take off! 0.472 0.634
# report: apple signs up for google's cloud 0.15 0.423
# short setups looking nice....really nice -0.464 -0.076
# short $mbly -0.606 -0.131
# will push $nly investment to another time -0.255 -0.296
# notable gainers among liquid option names this morning 0.513 0.994
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.936
# point at a possible move up 0.176 0.960
# they let the stock fall big time after earnings -0.455 -0.110
# not selling before 0.221 0.519
# tremendous opportunity awaits 0.456 0.930
# up 10% in premarket 0.507 0.716
# the overall market improve 0.433 0.615
# gots some $aezs this morning 0.514 0.873
# erinn murphy of piper jaffray thinks $finl is a buy 0.501 0.891
# longer term top building 0.099 0.803
# debt crisis entered a dangerous new phase -0.331 -0.424
# $mu may go down 6% if the bear pattern is confirmed -0.404 -0.291
# looking good 0.255 0.772
# cracking -0.118 0.695
# bullish ma crossovers 0.457 0.981
# still an interesting finance play 0.305 0.821
# broke the downtrend line 0.309 0.975
# some of the stocks that came up on screens for longs 0.431 0.976
# defying the downturn 0.407 0.695
# soars pre-market 0.34 0.711
# this stock is a buy 0.498 0.909
# pain -0.4 0.695
# hi beta hi performers 0.384 0.524
# in trouble ? is that earnings gap still unfilled ? -0.368 0.821
# calls for nice gains 0.396 0.991
# long 0.394 0.993
# bull move ended -0.204 0.340
# trying to lead higher here 0.256 0.994
# bought back more shares here today 0.243 0.894
# getting very close to 200 ma of 110.87, hasnâ€™t closed above 200 ma since july 31, 2015. if / when it does, will be significant. 0.218 0.996
# addding tsla ss , added small vrx long $tsla $vrx 0.394 0.905
# sold xoma -0.281 -0.329
# nice blurb for $bbry 0.183 0.896
# what a nice reversal. 0.318 0.860
# i'm watching(and buy targets) 0.344 0.989
# don't catch falling knives 0.286 0.489
# barclays signs on to apple pay 0.354 0.514
# looking weak -0.352 -0.427
# markets are still acting weak -0.443 -0.479
# short/put positions looking good here -0.485 0.697
# bullish $nflx day trade setup 0.422 0.978
# unusual call activity 0.332 0.995
# institutions seem to like this class of stocks 0.422 0.952
# loading $spy and $aapl puts -0.537 -0.339
# watch $tsla > 34.5 0.339 0.537
# still in bear market -0.421 -0.285
# china winners 0.452 0.966
# stock options trade would have more than doubled your money 0.294 0.387
# master class on how to conquer mobile 0.419 0.936
# got hit hard lower this am -0.551 -0.030
# biggies must be loading up here at lows 0.438 0.636
# has a hard to diminish lead 0.262 0.955
# inverse head and shoulders forming 0.394 0.656
# weak outlook -0.034 -0.682
# indices are rallying today -0.193 0.803
# $gpro up 0.619 0.695
# embarrassing china numbers -0.312 0.712
# possible target 0.162 0.934
# rally friday! 0.66 0.967
# long setup 0.444 0.993
# closed green!!!! 0.622 0.998
#  0.0 0.695
# bumping its head on declining daily 8ma as overhead resistance -0.35 -0.137
# at least you didn't stop out -0.222 0.835
# finds support 0.504 0.810
# long-term potential robust 0.249 0.930
# hopefully peeps shorting $camt for scalps -0.36 -0.143
# now it is time to short $tsla -0.385 -0.597
# keep stock on your watch list 0.271 0.967
# gap up tomorrow 0.439 0.966
# demand ahead 0.532 0.698
# our updated #core4 portfolio 0.452 0.953
# new hod with conviction keeping $570 on watch for resistance 0.529 0.992
# long the market 0.525 0.978
# acting tough on big volume against the tape 0.243 0.789
# best outperformers ranked 0.492 0.995
# infection worries prompt regulatory reviews -0.401 0.695
# back to back intraday reversals -0.53 0.479
# weekly 625 calls now +42.31% 0.144 0.916
# has been a bull and $gld a bear 0.0 -0.141
# watchlist top stocks 0.342 0.971
# i would consider this opportunity to add my position 0.401 0.998
# markets are still acting weak -0.443 -0.479
# bear flag -0.535 -0.143
# took some $endp long this am 0.613 0.967
# yes buy everything up 0.829 0.891
# brent back below 49 -0.353 0.583
# a premier retail dividend play 0.354 0.989
# beat 0.284 0.806
# shipments slid -9.6% to lowest quarterly total since 2007 -0.336 -0.092
# long 0.537 0.993
# bullish ma crossovers 0.457 0.981
# the most trending 0.216 0.958
# unusual call activity 0.421 0.995
# nice day rally! 0.529 0.973
# added long at friday close 0.513 0.998
# looks like might break down -0.516 0.811
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.999
# pushing channel development 0.458 0.931
# bot $ezpw 0.437 0.954
# like this > 0.374 0.516
# short -0.633 -0.131
# chunk of dec $35 puts bought at -0.601 0.176
# not time to buy -0.382 0.602
# round 2 short -0.438 -0.074
# 580+ should be coming very quick, if the fed supports the markets 610 0.296 0.993
# debt crisis entered a dangerous new phase -0.331 -0.424
# some of the stocks that came up on screens for longs 0.431 0.976
# sector stocks leading today 0.454 0.976
# short the market -0.541 -0.027
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# over 16 with conviction 0.585 0.869
# $nflx at $44b 0.215 0.900
# seeing competition -0.216 0.695
# some competitors worry that blackberry is the inevitable successor to northern telecom 0.27 0.935
# moved upper bollinger band 0.498 0.999
# unusual call activity 0.332 0.995
# 4 shorts only -0.53 0.106
# top 5 stock picks 0.414 0.942
# tired of seeing this go down -0.085 0.772
# ascending base breakout starting to gain traction 0.733 0.974
# have enjoyed shorting anglo these last few weeks -0.269 -0.198
# top holdings 0.311 0.859
# $aapl cleary surpassed their bb -0.274 0.422
# all going down -0.559 0.552
# stochastic overbought -0.385 -0.620
# expands share repurchase program 0.285 0.695
# play safe, be long 0.335 0.993
# covered 0.128 0.957
# bullish yeah 0.393 0.917
# closed short position 0.143 0.972
# why $twtr is doomed in 1 chart -0.027 -0.557
# new rsi signal created on $cost - buy 0.497 0.902
# global pc shipments fell 9.6% in q1 -0.152 -0.128
# holding up well today 0.318 0.985
# unusual call activity 0.421 0.995
# all higher 0.293 0.945
# deutsche bank: cuts #starbucks to hold -0.17 0.505
# stocks at support w/ high trade quality 0.503 0.989
# gapping up to all time highs 0.782 0.913
# downgrade -0.463 -0.452
# netapp downgraded by macquarie to underperform -0.574 -0.154
# short the $tsla -0.603 -0.384
# shipments slid -9.6% to lowest quarterly total since 2007 -0.295 -0.092
# fed cuts rates forecast 0.449 0.954
# lost revenue -0.43 0.536
# finding support 0.259 0.961
# confirmation is a hold  0.259 0.847
# sounds like we'll see some green tomorrow 0.395 0.988
# closed friday with the rs line in new highs 0.371 1.000
# beautiful trend/base 0.645 0.695
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# $aapl signs up with google cloud -0.403 0.370
# heading back down to -0.25 0.583
# over 225 million new internet users are being added globally every year 0.337 0.999
# unusual call buying 0.336 0.989
# obby against judge garland or they risk losing the case -0.261 0.004
# probably long 0.29 0.993
# unusual call activity 0.421 0.995
# loooooongggggg base 0.557 0.879
# $pypl w/ a solid start in #ecommerce checkout 0.375 0.966
# want to go this morning 0.28 0.890
# breaking out 0.068 0.864
# nobody is recommending the sale of this stock 0.623 0.764
# all on a longer-term, technical swing long basis. 0.591 1.000
# buying my last round of shorts next week -0.339 0.703
# this stock is such a winner 0.451 0.967
# pivotal upgrades alphabet ahead of q1 results 0.53 0.804
# monday sold -0.37 -0.348
# only those with the stomach for high risk are left -0.151 -0.041
# men sell $svxy puts 0.092 -0.636
# was still up on the screen 0.377 0.651
# some upside today 0.254 0.976
# shorts made a killing last couple days -0.529 0.174
# will be looking to add shares if we get a new high breakout 0.421 0.988
# atching spy 60 min sto for a push -0.035 0.307
# #whisperbeat 0.619 0.695
# bmw entering into ride-share market with i3 0.399 0.615
# rally friday! 0.66 0.967
# staying strong 0.532 0.961
# can $tsla roll over yet? -0.212 0.266
# stock receives ratings downgrade today at jefferies -0.501 0.107
# looks weak now -0.504 -0.415
# small pos, short 180 wkly puts -0.597 -0.486
# downward trendline -0.143 0.695
# isn't cheap -0.353 0.332
# they have real assets 0.432 0.913
# finding support 0.259 0.961
# buy these 3 stocks while there's blood in the streets 0.415 0.971
# risky move -0.078 0.619
# great short entry right now -0.461 -0.524
# google, inc. completes acquisition of icoa 0.267 0.765
# stocks higher in afternoon trade 0.314 0.968
# looking for continuation with volume increase 0.308 0.820
# top #netpayoutyields 0.426 0.972
# actively head & shoulder in progress -0.222 0.656
# with personal story sharing declining -0.572 -0.513
# worst performers -0.244 0.211
# not dipping - testing the 200 day ma 0.281 0.940
# bad apple -0.392 0.278
#  0.0 0.695
# should reward better on good earnings 0.326 0.776
# daily sales slowing again -0.105 -0.037
# in play tmrw 0.805 0.684
# sector stocks leading today 0.454 0.976
# bidding war picks up for the company 0.391 0.969
# is now beaten down, hated -0.303 0.695
# china winners 0.452 0.966
# announces record #esports viewership 0.208 0.938
# shares up ~7% after hours 0.552 0.705
# seriously nothing says strong growth like 0.312 0.875
# call credit spread 0.311 0.969
# they are hitting everything in sight. -0.504 0.695
# bought 3500 shares today! 0.738 0.940
# lnkd is great but doesnt the potential side with fb 0.283 0.949
# short somewhere in the high -0.526 0.036
# #iphone is really annoying. -0.398 0.418
# bought more - bought $fb at 0.506 0.960
# only a 50% gain from these levels -0.22 -0.190
# companies shld be worried about icloud -0.329 -0.462
# ...
# blackberry messenger is second only to facebook in user loyalty 0.243 0.998
# wayyy overvalued right now -0.451 -0.439
# gaining momentum! 0.527 0.955
# surges on deal 0.419 0.956
# long this morning 0.476 0.996
# trade continuing very nicely from yesterday 0.495 0.997
# slow-motion disruption of the global auto industry 0.601 0.695
# bto three 110 puts @ 1.34 -0.267 -0.189
# apple's iphone se: the sold out flop -0.336 -0.437
# potential intermediate top in an uptrend 0.32 0.983
# stocks at support w/ high trade quality 0.503 0.989
# closng higher from here 0.48 0.945
# short-term forecast is now bearish -0.343 0.225
# take it while you can 0.515 0.697
# lets see 14+ today 0.302 0.782
# bought call omnivision tech 0.722 0.999
# pie in the sky 0.365 0.991
# eps growth is around 12% so far 0.316 0.997
# could the pride of social media be gettin ready to fall? -0.403 -0.033
# producing a bullish macd xover 0.691 0.917
# no more buys 0.146 0.923
#  0.0 0.695
# market getting crushed today -0.302 0.575
# today i bought more 0.087 0.967
# bidders line up 0.252 0.965
# led light bulb prices rise in japan 0.054 0.999
# expecting $spy to close above 0.385 0.643
# down 1.1% -0.352 0.695
# short setups looking nice....really nice -0.464 -0.076
# longs 0.511 0.964
# notice how the doomsaying bears disappear during the climbs 0.467 0.501
# recessions -0.307 0.695
# watch is showing serious demand 0.491 0.888
# new 'large player sells' -0.498 0.712
# biggest market losers -0.438 -0.379
# prob a buy if it does 0.428 0.891
# and is overbought -0.48 -0.295
# put money in $hznp better option -0.081 0.171
# sales exceed target 0.526 0.515
# goldman sachs reiterates conviction buy on 0.087 0.945
# red before the bell -0.442 -0.044
# stock will hit $170 easily 0.327 0.764
# downbeaten stocks may be ripe for buys 0.316 0.994
# buy safety equipment maker for $2.5 billion 0.23 0.779
# weak close -0.297 -0.264
# looks like it could be about to fall apart -0.515 0.003
#  0.0 0.695
# shorts are getting nervous 0.366 0.198
# facebook has now been down 10 minutes -0.258 0.948
# monday bulls are out! 0.457 0.910
# today's top gainers 0.447 0.990
# tesla motors recalls -0.424 0.438
# aggressive buy 0.306 0.975
# mentioned as potential suitee, suitor 0.258 0.930
# we see more reasons to be cautious -0.093 -0.275
# do you really think in 4 weeks they capture 10%? impossible. -0.317 -0.055
# friday was last chance under $2 0.228 0.779
# excellent / factual bear argument -0.507 -0.406
# bears take a clear near term advantage -0.501 0.187
# relative weakness is pretty apparent -0.262 0.677
# don't think buyout rumor strong enough too be driving this up just yet -0.02 0.830
# $yhoo +2.61% 0.16 0.849
# $tplm triangle #petroleum 9.80+3% 2m expanding caliber 0.376 0.943
# downbeaten stocks may be ripe for buys 0.316 0.994
# downgrade -0.463 -0.452
# isrg short -0.678 -0.131
# $pozn +30 0.146 0.135
# -2.10% vs -0.90% est -0.489 0.695
# daily mail enters competition to acquire yah 0.342 0.047
# stocks higher in afternoon trade 0.357 0.968
# watchlist top stocks 0.342 0.971
# wants to ta -0.23 0.626
# $viab down 40% -0.516 0.695
# sudden optimism about iphone sales 0.279 0.319
# google, ibm, arm and amd begin the assault on intel's server franchise 0.368 0.765
# monday sold -0.44 -0.348
# earning play $fast 47 puts, $vrx 34 puts , $bidu 182.5 puts -0.387 -0.807
# bullish ma crossovers 0.457 0.981
# watchlist top stocks 0.342 0.971
# looks constructive 0.28 0.760
# $unt trying to break out of 5 day range 0.244 0.921
# today i bought more 0.087 0.967
# failed breakouts & failed setups -0.419 -0.207
# shorting here into close might be play -0.469 0.121
# long play 0.48 0.984
# good for economy 0.273 0.764
# today's bull flag 0.2 0.934
# inside week buy triggers 0.485 0.961
# insiders are selling -0.351 0.394
# long 0.23 0.993
# insiders are selling -0.351 0.394
# revenue grew double-digit 0.454 0.536
# hangin on my a thread -0.337 0.695
# long $tsla 0.607 0.894
# recalls 2,700 model x cars -0.315 0.004
# is in the process of streamlining its structure 0.229 0.695
# in play longs 0.273 0.960
# macd and adx are crossing over the signal lines! 0.569 0.702
# yahoo, facebook in ad partnership talks 0.249 0.990
# buy the dip' 0.38 0.911
# about to break out on the 5-min 0.313 0.879
# long over 3.95/great find - hope that wold be another $anly or $pzzi, still holding second 1/2 0.509 0.999
# moves on both sides possible -0.023 0.908
# fed cuts rates forecast 0.449 0.954
# the parties over -0.223 0.695
# up almost 0.378 0.705
# $lei higher 0.388 0.945
# breakout watch 0.352 0.993
# adding to position here 0.685 0.997
# brutal slide -0.044 0.695
# looks good on the weekly chart 0.379 -0.053
# holding up relatively well compared to the broad market 0.394 0.960
# covered the swing 0.021 0.977
# bullish ma crossovers 0.457 0.981
# top stocks in 2015 are ready to lead again in 2016 0.414 0.999
# making new hod 0.442 0.994
# defect -0.366 0.695
# most bullish stocks on twitter during this dip 0.408 0.992
# strong move today for the junior gold miners 0.75 0.993
# tomorrow party time for the bears!! -0.524 0.252
# it is cheap. 0.183 0.332
# insiders are selling -0.527 0.394
# why the coal & shipping sectors could rise again 0.418 0.997
# small businesses have called $yelp a scam for years -0.45 0.881
# weekly 120 puts +283% -0.35 -0.160
# looking good 0.362 0.772
# i may try a short -0.352 -0.037
# equity indexes working on a positive engulfing for march 0.308 0.997
# and it will continue 0.413 0.695
# to combine in $37 billion deal 0.241 0.933
# another quiet week 0.0 0.877
# deutsche bank downgrades -0.436 0.599
# near-term target $77.38 0.0 0.683
# $fb is taking the shine off $aapl and $goog 0.435 -0.066
# holding up nicely 0.441 0.991
# bought $fb $111 calls 0.579 0.961
# airlines battle for cuba routes $aal $luv $save $jblu 0.092 0.986
# accuses $znga of copyright infringement -0.284 0.695
# mrkt needs to washout -0.055 -0.394
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# shipments slid -9.6% to lowest quarterly total since 2007 -0.283 -0.092
# #joke #bubble #buyerbeware -0.506 0.695
# $azpn is worth $20 a share not $40 -0.563 0.772
# come on and run with the bulls today 0.484 0.960
# $wfc -8.30% -0.584 0.695
# 5 best analyst rated stocks 0.509 0.991
# nothing investors can do to damage apple 0.322 0.713
# don't underestimate mark 0.37 0.823
# unusual call activity 0.421 0.995
# recessions -0.307 0.695
# buying my last round of shorts next week -0.339 0.703
# buy more on the weakness? 0.346 0.843
# good time to buy 0.533 0.631
# the most trending 0.216 0.958
# express scripts loses -0.336 0.695
# debt crisis entered a dangerous new phase -0.331 -0.424
# then shorted it down. -0.405 0.695
# bullish yeah 0.109 0.917
# call sweepers stepping up this morning 0.343 0.983
# failed breakouts & failed setups -0.419 -0.207
# so i can add more 0.307 0.964
# hearing rumours of a major joint venture announcement 0.427 0.811
# $nlsn launching a marketing cloud -0.245 0.483
# moody's downgrade -0.299 -0.452
# tesla dropped a hard j this morning -0.376 0.736
# 15 years after release, windows xp is still the 3rd most popular os 0.2 0.692
# weakness could be opportunity 0.345 0.986
# citing positive spending trends 0.436 0.962
# isn't going anywhere 0.241 0.552
# sector stocks leading today 0.454 0.976
# in play longs 0.273 0.960
# it shoots to the moon as my favorite pumper 0.514 0.695
# best performers 0.307 0.851
# equities recently tagged #undervalued 0.353 0.854
# shorts breakin flag 0.226 0.460
# do i have enough shares ??? 0.429 0.705
# added to $dnkn (longs) 0.528 0.998
# bears take a clear near term advantage -0.501 0.187
# top 5 stock picks 0.414 0.942
# people still coming in 0.257 0.762
# < money-losing$ overvalued china ipo junk -0.638 0.313
# bigger win for 0.273 0.695
# honestly, it's been disappointing -0.443 0.695
# over 225 million new internet users are being added globally every year 0.337 0.999
# grab it while it's cheap 0.488 0.332
# adding $expe and $pcln to the mix soon 0.408 0.999
# short setups looking nice....really nice -0.464 -0.076
# t's time to short at this point -0.489 0.093
# today aside setting up for another drop -0.504 0.249
# the most trending 0.216 0.958
# bail out 0.058 0.695
# $tsla is the only 'auto' stock showing a gain year-to-date -0.334 0.096
# ready to break $qcom watching at 55.7 0.235 0.228
# bearish charts keep getting worse. -0.619 -0.250
# making all kinds of gains ???? 0.42 0.986
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.936
# looking weak and possibly ready to 'let go' -0.482 0.688
# marriott wins new starwood deal by raising cash portion of bid 0.332 0.985
# looks like one of the best values #lithium stocks in the space 0.197 0.955
# watchlist top stocks 0.342 0.971
# soars pre-market 0.398 0.711
# $bbry smack down looks legitimate -0.105 0.760
# allow for the growing middle class 0.289 0.943
# will we see $410 again 0.152 0.522
# bricks and mortar retailers selling cheaper -0.352 0.405
# oil to break out 0.666 0.916
# under $2 today? -0.164 0.835
# falls 18% pre-market on q3 sales results -0.394 0.496
# growing customers globally 0.576 0.957
# little-discussed problem this pro is watching at -0.476 0.035
# an upward movement is expected 0.387 0.695
# market seems stuck in the mud -0.259 -0.285
# will get in on the next run up 0.275 0.738
# fed cuts rates forecast 0.449 0.954
# buy the dip' 0.38 0.911
# next year could be a very good year for them 0.528 0.795
# stock trading lower today  -0.375 0.600
# bear raid -0.48 -0.406
# curing #overbought conditions -0.262 -0.567
# launch updated model s with steeper price tag 0.261 0.431
# getting kneecapped by $bexp selling itself dirt cheap -0.384 -0.032
# $amzn is becoming more and more the go-to site for almost all categories in ecommerce. 0.269 0.931
# alibaba invests in southeast asian retailer lazada 0.0 0.695
# getting sold here. -0.551 -0.453
# the most trending 0.216 0.958
# $aapl could pick em up too. 0.324 0.902
# higher in afternoon trade 0.243 0.940
# $aapl a new long if 110.61 is broke 0.184 0.994
# puts came in -0.517 -0.046
# record number of passengers served in 2015 0.638 0.998
# ure has lots of attractive suitors 0.325 0.960
# delivering the goods again let's see if that can spill over in other chinese internet names 0.502 0.833
# on lows -0.465 0.636
# could be lotto winners 0.29 0.993
# buy the dip' 0.38 0.911
# a good place to take a shot 0.465 0.900
# 5 reasons not to buy gold -0.447 0.939
# in oversold conditions 0.459 0.552
# stocks at support w/ high trade quality 0.503 0.989
# buying $fas last week was the play of the month 0.74 0.820
# slow bleeding death -0.641 0.695
# solarcity customers can produce enough electricity to power tesla fleet 0.601 0.438
# $yhoo bidding heats up 0.281 0.965
# nice day rally! 0.529 0.973
# sector has been taking a beating recently, could be positive here 0.361 0.990
# gevoâ€™s alcohol to jet fuel now eligible to be used for commercial flight 0.031 0.997
# downgrade -0.463 -0.452
# bmw entering into ride-share market with i3 0.132 0.615
# hope kog shorters learned a lesson 0.085 0.808
# has a 42.71% float short. lo -0.392 -0.131
# interest level has skyrocketed here the last two week 0.165 0.491
# new pm high 0.403 0.692
# nice day rally! 0.529 0.973
# long on 0.457 0.993
# 333.0% increased bullish conversations 0.442 0.917
# accumulating -0.099 0.695
# stochastic overbought -0.385 -0.620
# daily mail and general trust eyeing yahoo! 0.39 0.596
# received a buy rating from wells fargo 0.456 0.868
# taking a small chill pill today -0.183 0.702
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.980
# companies shld be worried about icloud -0.329 -0.462
# sector stocks leading today 0.454 0.976
# held the trend line 0.325 0.991
# multi-year stock breakouts 0.612 0.930
# moved upper bollinger band 0.498 0.999
# five stocks that helped starboard valueâ€™s equity portfolio return 6.5% in q1 0.432 0.980
# miles beyond the competition 0.278 0.695
# slips on downgrade -0.093 -0.452
# add in 0.354 0.964
# buy the dip' 0.38 0.911
# price experiencing early rejection -0.228 0.694
# in play longs 0.273 0.960
# will be adding on dips 0.154 0.936
# moved upper bollinger band 0.498 0.999
# yahoo extends bidding deadline as interest grows 0.317 0.994
# sold some $tsla puts this morning -0.211 -0.339
# top holdings 0.311 0.859
# short -0.377 -0.131
# will close below  -0.453 0.615
# famous lunch hour fade down routine 0.002 0.695
# $aapl +1.44% 0.256 0.422
# weak hands being flushed from metals and miners 0.3 -0.448
# can make hod 0.49 0.906
# 13f shows new stakes in  0.468 0.754
# omg omg so excited!!!! 0.219 0.695
# stay long 0.951 0.986
# i hope it gets resolved to the upside 0.042 0.979
# best outperformers ranked 0.492 0.995
# shorts are trapped 0.226 0.387
# they want the stock too keep going up -0.294 0.127
# what's a great move 0.461 0.695
# no edge offered 0.025 0.984
# goes deep into #machinelearning and #ai territory with its new $125,000 supercomputer 0.294 0.320
# $chk +13.56% 0.781 0.695
# slips on downgrade -0.093 -0.452
# same sellers we saw yesterday -0.45 0.940
#  0.172 0.695
# no need for $fb at all unless you want your content censored -0.367 0.491
# ross stores upgraded to outperform at rbc capital markets 0.565 0.995
# upgraded 0.439 0.911
# mrkt needs to washout -0.055 -0.394
# longs 0.511 0.964
# downgraded to neutral at wedbush -0.434 -0.154
# long tech 0.384 0.999
# $tfm will have a way to go price wise to compete -0.085 0.949
# nice day rally! 0.529 0.973
# $sqns drops to $5.15 0.331 0.695
# soars pre-market 0.254 0.711
# china february retail sales: e-commerce remains resilient 0.383 0.958
# double bottom with handle buy point 0.654 0.895
# torture....... -0.303 0.695
# high-flyers have been falling -0.501 0.341
# trails $msft $orcl $goog $crm $adbe 0.179 0.957
# quality stocks with high cash returns 0.274 0.976
# running again 0.286 0.771
# don't look for a dividend at the feb shareholders meeting -0.2 0.929
# make a ton of money 0.382 0.356
# unusual call activity 0.332 0.995
# breaks major support -0.455 0.613
# in the $3s 0.0 0.695
# sanofi often on the wrong end of business. -0.247 0.232
# opening buyer 0.412 0.695
# notable gainers among liquid option names this morning 0.513 0.994
# receives a sell from compass point -0.45 0.445
#  0.0 0.695
# still have positive market bias 0.428 0.894
# stochastic overbought -0.385 -0.620
# earnings will drive stock prices 0.218 0.929
# why the coal & shipping sectors could rise again 0.418 0.997
# long 0.488 0.993
# anyone long before the flush please accept my condolences -0.606 0.993
# thinking that last entry was good but needs a push 0.207 -0.471
# no position -0.118 0.984
# waiting for price to enter buy/support zone 0.358 0.830
# downgrade -0.463 -0.452
# gotta hold 0.345 0.847
# still in massive weekly & monthly uptrend 0.632 0.590
# aggressive buy 0.587 0.975
# keeps outperform rated 0.489 0.967
# stochastic overbought -0.385 -0.620
# good to load up be confident 0.281 0.990
# worst performers today -0.72 0.448
# insiders are selling -0.351 0.394
# pie in the sky 0.365 0.991
# small caps threatening descending triangle breakdown -0.382 0.994
# amazon has been selling surveillance cameras infected with malware -0.186 0.848
# $htz -0.409 0.695
# don't hang your bull hat yet 0.412 0.912
# alphabet inc was just upgraded to buy 0.465 0.964
# today i bought more 0.362 0.967
# brings upscale concept 0.22 0.695
# looking for a sharp move up in equities 0.365 0.633
# i'm betting over 52% -0.248 0.797
# careful can reverse fast -0.152 -0.480
# #ownitdon'ttradeit 0.435 0.695
# top 5 stock picks 0.414 0.942
# major skin in the game...positive. 0.471 0.811
# 100.0% increased bearish conversations -0.589 0.554
# another sell rating, sell rating -0.513 -0.406
# sold today -0.581 0.115
# buy call! 0.087 0.988
# long 0.23 0.993
# upgrade today by ms to overweight 0.813 0.803
# buy the dip' 0.38 0.911
# so both call/put buyers are crushed -0.126 0.695
# buy stop above 80 0.295 0.891
# airplane and hospitality industries set their sights on #cuba 0.405 0.999
# nice bounce 0.296 0.967
# overbought -0.296 -0.295
# putting on a little $f short -0.454 0.280
# short some -0.464 -0.131
# buying opportunity 0.445 0.946
# scaling up on long position 0.661 1.000
# its time to sell banks -0.763 -0.604
# entering long 0.627 0.993
# picked some up 0.653 0.695
# time to accumulate for a long position 0.668 0.998
# buying $sbux on dip 0.483 0.839
# is a short below 740 -0.48 -0.131

# %% [markdown]
# ### Computing Cosine score

# %%
#predictedVals = [pr[0] for pr in predictions ]

# %%
predictedVals = [pr[0] for pr in predictions ]
output = np.array(output).reshape(1,-1)
predictedVals = np.array(predictedVals).reshape(1,-1)


print("Final cosine score :",cosine_similarity(predictedVals,output)[0][0])
# Out:
# Final cosine score : 0.638443989711

# %%
df=pd.DataFrame.from_dict(Microblog_Trainingdata)

# %%
df['Predicted Sentiment Score']=predictions
df.head()
# Out:
#   cashtag                  id  sentiment score      source  \
# 0     $fb  719659409228451840            0.366     twitter
# 1    $luv  719904304207962112            0.638     twitter
# 2   $nflx             5329774           -0.494  stocktwits
# 3    $dia  719891468173844480            0.460     twitter
# 4   $plug            20091246            0.403  stocktwits
#
#                                                spans  \
# 0                       watching for bounce tomorrow
# 1         record number of passengers served in 2015
# 2                                     out $nflx -.35
# 3                        looking for a strong bounce
# 4  very intrigued with the technology and growth ...
#
#    Predicted Sentiment Score
# 0                   0.898739
# 1                   0.998171
# 2                  -0.001671
# 3                   0.985798
# 4                   0.957454

# %%
task1Dataframe=pd.DataFrame({"ID":df['id'],"Spans":df['spans'],"Cashtag":df['cashtag'],"Sentiment Score":df['sentiment score'],"Predicted Sentiment Score":df['Predicted Sentiment Score']})
task1Dataframe=task1Dataframe[['ID','Spans','Cashtag','Sentiment Score','Predicted Sentiment Score']]
task1Dataframe
# Out:
#                       ID                                              Spans  \
# 0     719659409228451840                       watching for bounce tomorrow
# 1     719904304207962112         record number of passengers served in 2015
# 2                5329774                                     out $nflx -.35
# 3     719891468173844480                        looking for a strong bounce
# 4               20091246  very intrigued with the technology and growth ...
# 5                5819749                                       short worked
# 6     709741154393133056                                         overbought
# 7               17892972                          absolute garbage still up
# 8     709834259687710720                              biggest market losers
# 9     708481442079068160                       love this company long time.
# 10              31971935                            $goog $googl would suck
# 11    710187873492983809                              who won't pay anymore
# 12              13915103                                    no edge offered
# 13              10448993        runs into the 50sma on the acquisition news
# 14              24886266                                    t can't go down
# 15              12793642           now seems like its helping the downtrend
# 16               9408369                        mastered their supply chain
# 17    719909604654624768     most bullish stocks on twitter during this dip
# 18               9674584                                        big dumping
# 19              10041008        trade continuing very nicely from yesterday
# 20              20249627                                       in from 3.61
# 21              39047349                              stochastic overbought
# 22    711907079296933888                                unusual call buying
# 23               5364581                            reserves are in decline
# 24              25816362  all on a longer-term, technical swing long basis.
# 25    708960045799759872                               insiders are selling
# 26    719521470175522816                                    what goes up...
# 27    719572690453934080            if $249.84 breaks we see $245 then $240
# 28              33458939                             let's see a big bounce
# 29    719547428924481536   i don't think it will move $fb in the short term
# ...                  ...                                                ...
# 1680  719585607215808512                                today i bought more
# 1681  709056556466200576                             brings upscale concept
# 1682  710143603524427777            looking for a sharp move up in equities
# 1683            11845293                               i'm betting over 52%
# 1684            17553855                           careful can reverse fast
# 1685  719886818800463872                                 #ownitdon'ttradeit
# 1686  719732320404709376                                  top 5 stock picks
# 1687             5792305                 major skin in the game...positive.
# 1688            30158448             100.0% increased bearish conversations
# 1689  719489192078610432                   another sell rating, sell rating
# 1690            11118210                                         sold today
# 1691  719536774821867520                                          buy call!
# 1692  719535349379284992                                               long
# 1693            15658194                  upgrade today by ms to overweight
# 1694            22409313                                       buy the dip'
# 1695             7442585                so both call/put buyers are crushed
# 1696             5430926                                  buy stop above 80
# 1697  719547552874512384  airplane and hospitality industries set their ...
# 1698            18346099                                        nice bounce
# 1699  709741154393133056                                         overbought
# 1700             5540055                       putting on a little $f short
# 1701            10752226                                         short some
# 1702            10920221                                 buying opportunity
# 1703            12971398                        scaling up on long position
# 1704            16142438                             its time to sell banks
# 1705            14073133                                      entering long
# 1706            18479024                                     picked some up
# 1707            34147106             time to accumulate for a long position
# 1708  719890387314335744                                buying $sbux on dip
# 1709  708668814427348992                               is a short below 740
#
#      Cashtag  Sentiment Score  Predicted Sentiment Score
# 0        $fb            0.366                   0.898739
# 1       $luv            0.638                   0.998171
# 2      $nflx           -0.494                  -0.001671
# 3       $dia            0.460                   0.985798
# 4      $plug            0.403                   0.957454
# 5      $gmcr            0.000                  -0.131187
# 6       $ibm           -0.296                  -0.295217
# 7      $josb           -0.546                   0.651011
# 8      $cstm           -0.438                  -0.378919
# 9      $pypl            0.408                   0.829186
# 10    $googl           -0.398                   0.075313
# 11     $endp           -0.349                  -0.456988
# 12      $xli            0.025                   0.984436
# 13     $pcln            0.486                   0.734877
# 14       $aa            0.308                   0.875472
# 15     $aapl           -0.372                  -0.193466
# 16     $aapl            0.461                   0.694999
# 17     $gold            0.408                   0.991767
# 18      $amd           -0.699                   0.765501
# 19      $spy            0.495                   0.996996
# 20     $idra            0.306                   0.694999
# 21     $asmb           -0.385                  -0.619948
# 22      $rht            0.336                   0.988513
# 23      $chk            0.279                   0.694999
# 24     $celg            0.591                   0.999800
# 25     $cbpo           -0.351                   0.394438
# 26     $tsla           -0.514                   0.002018
# 27     $tsla           -0.519                   0.007254
# 28     $bbry            0.361                   0.912312
# 29       $fb           -0.042                  -0.371753
# ...      ...              ...                        ...
# 1680     $mu            0.362                   0.967212
# 1681   $sbux            0.220                   0.694999
# 1682   $aapl            0.365                   0.632522
# 1683   $amrn           -0.248                   0.796647
# 1684   $dust           -0.152                  -0.480407
# 1685   $aapl            0.435                   0.694999
# 1686   $psxp            0.414                   0.942129
# 1687    $opk            0.471                   0.810659
# 1688   $tvix           -0.589                   0.553876
# 1689   $aapl           -0.513                  -0.406102
# 1690   $fold           -0.581                   0.114973
# 1691     $fb            0.087                   0.988229
# 1692   $tsla            0.230                   0.993455
# 1693    $etn            0.813                   0.803465
# 1694   $omer            0.380                   0.910619
# 1695   $rimm           -0.126                   0.694999
# 1696    $xom            0.295                   0.891263
# 1697    $hot            0.405                   0.999036
# 1698   $bbry            0.296                   0.966751
# 1699    $axp           -0.296                  -0.295217
# 1700      $f           -0.454                   0.279913
# 1701   $aapl           -0.464                  -0.131187
# 1702    $bac            0.445                   0.945837
# 1703   $shor            0.661                   0.999680
# 1704    $jpm           -0.763                  -0.604288
# 1705    $lmt            0.627                   0.993455
# 1706    $dnn            0.653                   0.694999
# 1707    $crk            0.668                   0.998007
# 1708   $sbux            0.483                   0.838682
# 1709  $googl           -0.480                  -0.131187
#
# [1710 rows x 5 columns]

# %%
#Convert dataframe to csv file
task1Dataframe.to_csv('Task1.csv',index=False)
