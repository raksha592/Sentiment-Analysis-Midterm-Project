# %% [markdown]
# ## Task 1: Sentiment analysis of twitter and stockwits data

# %%
import json
from pprint import pprint
import matplotlib as mpl
import matplotlib.pyplot as pltfrom 

from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
 
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading data from JSON

# %%
with open('Microblog_Trainingdata.json') as data_file:    
    Microblog_Trainingdata = json.load(data_file)

for i in range(0,len(Microblog_Trainingdata)):
    Microblog_Trainingdata[i]['spans']=Microblog_Trainingdata[i]['spans'][0]
    Microblog_Trainingdata[i]['sentiment score']=float(Microblog_Trainingdata[i]['sentiment score'])
#pprint(Microblog_Trainingdata)
with open('Microblog_Trialdata.json') as data_file:   
    Microblog_Trialdata = json.load(data_file)
    

#pprint(data)
for i in range(0,len(Microblog_Trialdata)):
    Microblog_Trialdata[i]['spans']=Microblog_Trialdata[i]['spans'][0]
    Microblog_Trialdata[i]['sentiment score']=float(Microblog_Trialdata[i]['sentiment score'])

# %%
with open('Microblogs_Testdata.json') as data_file:   
    Microblogs_Testdata = json.load(data_file)
    
#pprint(Microblog_Testdata)

# %%
for i in Microblog_Trialdata:
    Microblog_Trainingdata.append(i)

# %% [markdown]
# ### Loading Testing and Testing data

# %%
maxlen = 0

X_train = []
X_trial=[]
Y_trial=[]
X_test = [Microblog['spans'] for Microblog in Microblogs_Testdata]
Y_train = []
Y_test = []
output=[]
for Microblog in Microblog_Trainingdata :
    X_train.append(Microblog['spans'])
    Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
    output.append(Microblog['sentiment score'])
    if maxlen < len(Microblog['spans'].split()) :
        maxlen = len(Microblog['spans'].split())
    
#for Microblog in Microblog_Trialdata :
 #   X_train.append(Microblog['spans'])
  #  Y_train.append(0 if Microblog['sentiment score']<=0 else 1)
   # if maxlen < len(Microblog['spans'].split()) :
    #    maxlen = len(Microblog['spans'].split())


print(len(X_train)+len(X_test), len(Y_train))
# Out:
# 2510 1710

# %% [markdown]
# ### Selecting top 15000 words using tokenizer library in keras

# %%
tokenizer = Tokenizer(num_words=15000)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen=50)

# %% [markdown]
# ### LSTM Model

# %%
model = Sequential()
model.add(Embedding(15000, 16, input_length=50))
model.add(LSTM(16, dropout=0.15, recurrent_dropout=0.15))
#model.add(Dense(4, activation='tanh'))
model.add(Dense(1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 50, 16)            240000
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 242,129
# Trainable params: 242,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(data, np.array(Y_train), validation_split=0.4, epochs=10,verbose = 1)
# Out:
# Train on 1026 samples, validate on 684 samples
# Epoch 1/10
# 1026/1026 [==============================] - 2s - loss: 1.7765 - acc: 0.3460 - val_loss: 0.9054 - val_acc: 0.3757
# Epoch 2/10
# 1026/1026 [==============================] - 1s - loss: 0.7235 - acc: 0.5556 - val_loss: 0.6852 - val_acc: 0.6243
# Epoch 3/10
# 1026/1026 [==============================] - 1s - loss: 0.6613 - acc: 0.6287 - val_loss: 0.6597 - val_acc: 0.6243
# Epoch 4/10
# 1026/1026 [==============================] - 1s - loss: 0.6416 - acc: 0.6433 - val_loss: 0.6512 - val_acc: 0.6243
# Epoch 5/10
# 1026/1026 [==============================] - 1s - loss: 0.6246 - acc: 0.6472 - val_loss: 0.6430 - val_acc: 0.6243
# Epoch 6/10
# 1026/1026 [==============================] - 1s - loss: 0.5976 - acc: 0.6598 - val_loss: 0.6252 - val_acc: 0.6360
# Epoch 7/10
# 1026/1026 [==============================] - 1s - loss: 0.5675 - acc: 0.6881 - val_loss: 0.6008 - val_acc: 0.6725
# Epoch 8/10
# 1026/1026 [==============================] - 1s - loss: 0.5302 - acc: 0.8168 - val_loss: 0.5705 - val_acc: 0.7178
# Epoch 9/10
# 1026/1026 [==============================] - 1s - loss: 0.4599 - acc: 0.8460 - val_loss: 0.5350 - val_acc: 0.7295
# Epoch 10/10
# 1026/1026 [==============================] - 1s - loss: 0.3916 - acc: 0.9055 - val_loss: 0.5168 - val_acc: 0.7573

# %%
sequences = tokenizer.texts_to_sequences(np.array(X_train))
data = pad_sequences(sequences, maxlen=50)
predictions = model.predict(data)
for i in range(len(predictions)):
    print(Microblog_Trainingdata[i]['spans'],Microblog_Trainingdata[i]['sentiment score'],"%.3f" % predictions[i])
# Out:
# watching for bounce tomorrow 0.366 0.808
# record number of passengers served in 2015 0.638 0.775
# out $NFLX -.35 -0.494 0.541
# Looking for a strong bounce 0.46 0.755
# Very intrigued with the technology and growth potential 0.403 0.768
# short worked 0.0 0.269
# overbought -0.296 -0.030
# absolute garbage still up -0.546 0.658
# Biggest Market Losers -0.438 -0.246
# Love this company long time. 0.408 0.751
# $GOOG $GOOGL would suck -0.398 0.213
# who won't pay anymore -0.349 0.076
# No edge offered 0.025 0.828
# runs into the 50sma on the acquisition news 0.486 0.602
# t can't go down 0.308 0.158
# now seems like its helping the downtrend -0.372 0.402
# mastered their supply chain 0.461 0.819
# Most bullish stocks on Twitter during this dip 0.408 0.764
# big dumping -0.699 0.426
# trade continuing very nicely from yesterday 0.495 0.797
# in from 3.61 0.306 0.832
# Stochastic Overbought -0.385 -0.313
# Unusual call buying 0.336 0.857
# reserves are in decline 0.279 0.799
# all on a longer-term, technical swing long basis. 0.591 0.857
# Insiders Are Selling -0.351 0.346
# What goes up... -0.514 0.742
# if $249.84 breaks we see $245 then $240 -0.519 0.290
# let's see a big bounce 0.361 0.711
# I don't think it will move $FB in the short term -0.042 0.440
# above 2.25 and it could get going? 0.26 0.624
# Hold 0.099 0.784
# may feed off $TSLA momentum run lately. 0.359 0.752
# possible double bottom set up 0.29 0.744
# trading at all-time high 0.887 0.651
# If positive outcome w/ lung study5/8 we may see a 13D Filing by Soros 0.33 0.673
# Put the chum out there at key support then next level down -0.32 -0.036
# #Tesla: Great Company, Bad #Stock $TSLA -0.065 0.240
# Good idea buy half this and half BAC? 0.329 0.687
# Alibaba IPO hoopla canâ€™t hide risk of Chinese stocks -0.39 0.426
# all on a longer-term, technical swing long basis. 0.591 0.857
# on the fence with this one 0.0 0.504
# stay long Apple 0.337 0.690
# looks like drought conditions in soil already -0.122 0.292
# Unusual Call Activity 0.332 0.861
# $MDXG -0.402 0.456
# Biggest Market Losers -0.438 -0.246
# hip sinking? -0.411 0.343
# Can't imagine shorts wanting to go into the weekend without taking care of their position 0.36 0.772
# nice volume 0.113 0.673
# $SIMO Basing nice 0.408 0.615
# Big Money Is Pouring Into Facebook From All Directions 0.645 0.747
# placed an order to sell 5 shares -0.379 0.374
# go $FB go 0.302 0.680
# Out $BIDU for now -0.221 0.615
# Short Setups Looking Nice....Really Nice -0.464 0.173
# Defying the Downturn 0.407 0.810
# but man this is one to be careful with -0.291 0.511
# downgrade -0.463 0.213
# Short $TSLA calls -0.618 0.469
# Was looking for a long entry but today's price action wasn't appealing 0.215 0.661
# just follow the trend, follow the money flow 0.165 0.762
# tapping on 10.00 0.224 0.775
# Will re-enter short on bounce.. -0.46 0.520
# Found some good bull setups this week 0.448 0.800
# all going down -0.559 0.131
# so volatile! -0.131 0.412
# sold my 81 calls 0.328 0.579
# I'm watching(and buy targets) 0.344 0.780
# beats the Estimize EPS Consensus by 6c and the Estimize Revenue Consensus by 0.366 0.694
# Short Percent of Float 16.80% -0.16 0.386
#  -0.373 0.765
# Add to $FXP $SKF positions 0.5 0.774
# long 0.488 0.867
# Bottom Losses -0.473 0.095
# ure wish bad news came out just a few days earlier -0.221 0.167
#  0.0 0.765
# $WMT, 13% 0.382 0.831
# added 0.274 0.788
# mkt fell on debt downgrade -0.159 -0.145
# $FCX +3.53% 0.339 0.765
# been very frustrating -0.136 0.275
# Thanks for the short -0.264 0.302
# need to break $4 again 0.132 0.622
# Fed cuts rates forecast 0.449 0.781
# Stochastic Overbought -0.516 -0.313
# Very tight price 0.0 0.587
# #oversold 0.406 0.848
# a great step for #China to let $FB in 0.417 0.751
# new squeeze plays -0.339 0.435
# $CRM Seems a little to high also -0.344 0.458
# Pie In The Sky 0.365 0.827
# Moved Upper Bollinger Band 0.498 0.838
# Highest call to put ratio 0.348 0.882
# offers will take place until next week 0.409 0.789
# Currently it is the shorts rejoicing -0.54 0.269
# breaking out when the market pulls back 0.413 0.665
# airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU 0.092 0.847
# Buy the dip' 0.38 0.794
# $MDXG -0.361 0.456
# BlackBerry Messenger is second only to Facebook in user loyalty 0.158 0.752
# Headed to all time highs 0.407 0.818
# Your shit is broke -0.348 0.676
# buy 0.458 0.819
# Weak open and it goes r/g within first 30 mins -0.229 0.240
# down $2.84 premarket -0.512 0.353
# Guess who sold off about $800 million in $MDLZ -0.428 0.227
# Buying on Weakness 0.511 0.718
# Shareholders welcome Marriott-Starwood deal 0.322 0.769
# peachy prospects 0.339 0.832
# Another Sell Rating, Sell Rating -0.513 0.281
# Nice day rally! 0.529 0.831
# Nice day rally! 0.529 0.831
# Quality Stocks With High Cash Returns 0.274 0.772
# LED light bulb prices rise in Japan 0.054 0.808
# Closed Buy 0.466 0.836
# highest down volume in last 10 days -0.31 0.444
# With $IBB back over support 0.285 0.667
# long into earnings 0.484 0.696
# considering Yahoo bid 0.288 0.756
# After weeks of steady gains,advances in mkt breadth slowe -0.146 0.298
# I will buy aggressively if pulls back 0.386 0.678
# Nice day rally! 0.529 0.831
# gets 26 patents and goes down -0.373 0.046
# Buying on Weakness 0.511 0.718
# LED light bulb prices rise in Japan 0.054 0.808
# is a later riser, 0.203 0.796
# Could that have been a strategy to exit shorts before the big pop? 0.316 0.676
# Piper upgrades Symantec on improving renewal rates and enterprise growth 0.525 0.788
# Look for strong solar rebound today! 0.304 0.840
# I think the DNF crew can get this $NFLX short into the next 30 days heading into earnings -0.308 0.371
# red $AAPL dragging down $QQQ -0.5 -0.101
# cuts outlook down -0.236 -0.124
# weakness continues again. -0.41 0.568
# Watchlist Top Stocks 0.342 0.801
# Long 0.428 0.867
# joint bid for Yahoo's internet assets 0.228 0.720
# patience pays off 0.272 0.735
# Bad governance -0.331 0.304
# Bottom Losses -0.756 0.095
# sales numbers still holding up so well 0.315 0.800
# I just feel the people who are buying are the same ones with their finger on the sell button -0.054 0.131
# gap filled 0.226 0.808
# debt crisis entered a dangerous new phase -0.331 -0.183
# just about to break out to new highs 0.469 0.774
# next resist is 64.40's 0.201 0.800
#  0.0 0.765
# looks really toppy right here. -0.191 0.397
# this will pop after the holiday 0.555 0.721
# Breakup Will Cost Billions -0.397 0.152
# News breaks first and fastest on Twitter $TWTR 0.364 0.772
# overbought -0.296 -0.030
# Continues to consolidate above previous break out area. 0.375 0.575
# Good to load up Be confident 0.281 0.801
# Long 0.394 0.867
# Buy Call! 0.095 0.873
# companies shld be worried about iCloud -0.329 -0.142
# $SPY -0.05% 0.028 0.767
# but decent supt here-expect some upside 0.302 0.702
# Monday sold -0.37 0.324
# Sector has been taking a beating recently, could be positive here 0.361 0.691
# At 11x earnings, $AAPL is a steal 0.561 0.727
# Multi Top on $MCD -0.474 0.415
# US Adds 321K Jobs In November 0.243 0.809
# Why is $FB falling? -0.304 0.325
# calls for nice gains 0.396 0.746
# someone bought lots of calls MON 0.444 0.738
# moving up again 0.12 0.650
# $EA points to the two Facebook games 0.048 0.716
# ready to exit bankruptcy 0.298 0.745
# starting to creep up 0.28 0.757
# looks like BO coming 0.36 0.735
# 2m this year would be amazing 0.151 0.789
# Moved Upper Bollinger Band 0.498 0.838
# $GOGO short -0.318 0.196
# EU getting closer to charging Google over Android -0.319 0.201
# Supermarket Stocks Rally as Tesco Plans to Axe Non-core UK Assets 0.346 0.764
# China winners 0.452 0.781
# looks like an ascending channel 0.363 0.739
# patience on the buy precedes patience on the sell 0.0 0.299
# Oil To Break Out 0.666 0.647
# brand name is to big for it to fail 0.226 0.782
# Top #NetPayoutYields 0.426 0.856
# Long $AMZN Oct $240 Calls 0.628 0.666
# under pressure along with the market 0.014 0.665
# patience pays off 0.272 0.735
# stock splits are lipstick on a pig! -0.347 0.277
# making new highs for the year 0.53 0.765
# held up well after the big gains! 0.695 0.782
# wait and see before taking any action 0.0 0.346
# Markets Are Still Acting Weak -0.443 -0.329
# breaking below support -0.397 0.615
# sold 20% of our concentrated stake -0.344 0.248
# want to go this morning 0.28 0.813
# cracking lower early -0.511 0.329
# $FB & $IBB down -0.527 -0.019
# Higher In Afternoon Trade 0.243 0.778
# Oil To Break Out 0.666 0.647
# added $SSO 64.33 0.626 0.801
# $FB $112 Calls .55 entry 0.509 0.555
# Is Tiffany's overvalued -0.25 0.319
# $INTC & $AAPL strong 0.722 0.709
# after crunching #'s 0.477 0.748
# Biggest gainers today large caps 0.556 0.820
# $AAPL a new long IF 110.61 is broke 0.379 0.757
# added to our $GILD position 0.422 0.824
# Largest Online Gaming Market 0.226 0.690
#  -0.541 0.765
# Bottom Losses -0.659 0.095
# stopped out even from yesterdays entry -0.413 0.364
# Micron Shares Pounded On Fears Of Loss Of Business From Apple -0.596 0.356
# Closed Buy 0.466 0.836
# over 225 million new Internet users are being added globally every year 0.337 0.673
# $UVXY broke 10.00 amazing!!! 0.265 0.811
# Long LEAPS 0.438 0.828
# Looks like that support line around 24.90 held 0.331 0.706
# retreats like clockwork -0.488 0.304
#  0.0 0.765
# its time to sell banks -0.763 0.432
# upgrades to outperform 0.61 0.823
# Unusual call buying 0.336 0.857
# holding strong 0.192 0.817
# Three of my hot stocks today 0.461 0.840
# Bulls Are Out 0.323 0.594
# patents system 0.271 0.778
# Markets Back in Black for 2016 0.271 0.802
# The losers buying $TSLA at these levels -0.545 0.259
# adding $expe and $pcln to the mix soon 0.554 0.789
# Today's losers -0.317 -0.138
# not feel terribly good -0.126 0.431
# $SPY up only 0.6% 0.228 0.640
# record number of passengers served in 2015 0.638 0.775
# While we think $TNH is a winner 0.415 0.775
# reiterated 'Outperform' rating 0.694 0.672
# airplanes are still flying 0.262 0.756
# $MTD $341 from $325 0.362 0.808
# bond buying is signaling some bad moves for the market -0.361 0.631
# I see more downside in next two weeks -0.477 0.464
# has just about run its course -0.449 0.329
# Biggest Market Losers -0.438 -0.246
# Loaded up on $bsx yesterday 0.664 0.830
# Notable gainers among liquid option names this morning 0.513 0.834
# Gevoâ€™s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight 0.026 0.817
# 5-star analyst @brianwieser from Pivotal Research upgraded rating on $GOOGL to BUY 0.561 0.770
# Santa Rally 0.22 0.848
# iPhone 6s is still better than Galaxy S7 0.385 0.749
# didn't factor in anything other than google and repeated good earnings 0.102 0.621
# Facebook is succeeding where Google should have dominated 0.531 0.743
# $UCO +4.44% 0.442 0.759
# up on day and will continue a surge next week. 0.509 0.800
# Facebook stock is now +$72 0.272 0.702
# ripe for a squeeze again -0.216 0.575
# Biggest Market Losers -0.438 -0.246
# with personal story sharing declining -0.393 0.046
# upgrades 0.334 0.818
# saying this is a peak = fear mongering 0.329 0.773
# the most trending 0.216 0.860
# who won't pay anymore -0.349 0.076
# still they are saying bullish LoL -0.038 0.386
# today's bull flag 0.2 0.648
# growth rate of approximately 122.0% to 124.9%. 0.305 0.654
# lots of nice setups in Energy  0.293 0.740
# Bad governance -0.331 0.304
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# Landed in $EA 0.422 0.819
# bought $skf as a hedge 0.466 0.745
# Transports always lead the way 0.594 0.794
# here is no case here 0.18 0.631
# $JOE Getting attention. No.2 on NYSE 100 top buying list 0.788 0.864
# Short Setups Looking Nice....Really Nice -0.464 0.173
# Highest close since 0.387 0.613
# should bring $SPX down into the close. -0.462 0.431
#  0.295 0.765
# money flow & stochastic dropping -0.577 0.042
# 9% run for this watch list winner 0.066 0.833
# have had 2 wks of fund inflows for the first time 0.58 0.723
# $GOOG $GOOGL would suck -0.404 0.213
# ses warrants to buy $1.17B & 14.97% of AmerisourceBergen(PBR16) shares 0.301 0.561
# Not every idea $AMZN has is bad. 0.235 0.632
# looks primed 0.4 0.790
# Yahoo extends bidding deadline as interest grows 0.613 0.799
# good news for domestic automakers 0.413 0.781
# mrkt needs to washout -0.055 0.179
# valuation is high -0.355 0.554
# $WFM dropping below $30 again -0.499 0.286
# $HTZ -0.341 0.464
# Recall Adds To Reliability Issues -0.267 0.229
# I'm out -0.14 0.628
# Think I may just start to avoid bios -0.23 0.181
# LVMH affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.735
# no crying you get out -0.462 0.456
# Trying to break daily trend line! 0.485 0.821
# Went long on this 0.449 0.820
# If bulls lucky enuff to get an upside gap fill, better take it 0.054 0.621
# wouldn't call any of these banks h+s quite yet 0.335 0.619
# banks to implode -0.298 0.437
# New recommendation from Carl Kirst of BMO Capital Markets 0.566 0.750
# near a buy point last week 0.102 0.813
# PC shipments drop to lowest level since 2007 -0.452 0.139
# Momentum building for breakout trigger 0.592 0.832
# consistent gains but small 0.219 0.825
# $AAPL cult on stocktwits is actually disgusting -0.151 0.209
# Higher In Afternoon Trade 0.243 0.778
# Sector Stocks Leading Today 0.454 0.855
# $ADBE flying 0.361 0.833
# Tesla to recall 2,700 Model X SUVs over seat issue -0.31 -0.064
# Back in 0.383 0.825
# US Adds 321K Jobs In November 0.243 0.809
# under pressure along with the market 0.014 0.665
# cash & cheap financing is fueling a wave of acquisitions 0.39 0.796
# Worst #sentiment for #SP1500 #stocks at market close -0.479 0.528
# gold going parabolic 0.442 0.792
# I would take profits if you have them -0.244 0.024
# never widen your stop to stay in a trade -0.412 0.684
# slips alongside shares on NSA leak news -0.198 0.187
# Best outperformers ranked 0.492 0.833
# $GOOGL is setting up above its 50-day moving average 0.696 0.586
# weakest sector this year -0.458 0.715
# Tesla is recalling 2,700 Model X cars -0.291 0.358
# Unusual Call Activity 0.421 0.861
# Wish had my puts bac -0.485 0.288
# see if they maintain 15% yield 0.078 0.770
# look at all the shorts running for cover 0.375 0.811
# As with all 3x ETFs, it is subject to decay due to daily rebalancin -0.234 0.309
# Signs of life are emerging :) 0.27 0.757
# Markets Back in Black for 2016 0.271 0.802
# I rather be neutral to bullish rather than bearish 0.185 0.633
# Diversifies. Adds International exposure 0.219 0.783
# Out $AAPL -0.27 0.408
# capped -0.172 0.518
# long on 0.185 0.802
# $GOOGL patents turn signal detector for autonomous cars. 0.241 0.707
# moves up a little more today off of cup and handle 0.306 0.751
# makes less profit than the sales of $AAPL Watch -0.641 0.491
# Comparable Store Sales -4% -0.441 0.422
# Making higher highs & higher lows as it consolidates over past several weeks 0.478 0.613
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.605
# sold at 139.26 and flat -0.695 0.351
# suddenly realizing -0.147 0.388
# long 0.488 0.867
# $FIT and $SUNE have not changed. -0.179 0.489
# $NUGT fucking beast mode, kicking shirts in the NUGT pouch 0.665 0.799
# my hospital reits are slaughtered -0.399 0.154
# i want to cry -0.595 0.399
# 3 Top Japan ETFs To Surge Higher In 2H 0.456 0.824
# New bullish conversation activity 0.461 0.817
# Bottom Losses -0.411 0.095
# just follow the trend, follow the money flow 0.165 0.762
# Short Squeeze Ready To Upside w Crossing Important Technical Level 0.219 0.628
# I'll take the other side of that trade 0.422 0.705
# I love this stock/Co -0.125 0.372
# no choice but to be positve 0.323 0.750
# Word on the street is that Allergen is looking at Endo International 0.472 0.753
# buy $WYNN 0.489 0.779
# $TSLA hype the news -0.073 0.507
# Three black crows followed by a potential bear flag -0.569 0.332
# Looking for a strong bounce 0.46 0.755
# trails $MSFT $ORCL $GOOG $CRM $ADBE 0.177 0.801
# Stay With Best Of Breed 0.417 0.738
# Nice day rally! 0.529 0.831
# orgetting the potential relative value of its users 0.316 0.711
# looking goo for 35.80s break out. It must hold 35.40s 0.307 0.700
# USIO ops are profitable -0.362 0.446
# Bot $GMCR 75 Nov Call 0.614 0.832
# Reasons for caution about Chinese stocks -0.317 0.426
# outperforms 0.525 0.799
# earish Trader bets $550K that Stock Will Sell Off -0.493 0.387
# congrats shorts -0.494 0.541
# Downbeaten stocks may be ripe for buys 0.316 0.818
# picked some up 0.653 0.800
# Worst performers today -0.351 0.801
# nt done good with that name so will pass it -0.319 0.432
# its been nothing but down -0.43 -0.018
# Bullish MA Crossovers 0.457 0.855
# player onto the 211 puts -0.652 -0.135
# Someone wants in 0.29 0.791
# $pcln back over 'up' trendline 0.308 0.820
# Found some good bull setups this week 0.448 0.800
# is just humming easing overbought -0.404 -0.261
# just follow the trend, follow the money flow 0.165 0.762
# is up 19% 0.128 0.813
# Sector Stocks Leading Today 0.454 0.855
# Ron Johnson tried, and failed, to inject a bit of Apple culture into JC Penney -0.335 0.085
# not the prettiest candlesticks 0.0 0.243
# agree risky watching very closely -0.375 0.193
# breakout from the consolidation zone 0.724 0.808
# Took Small posistion on $TSLA -0.114 0.311
# flop would just get everyone running to the fences. -0.546 0.298
# Unusual Call Activity 0.421 0.861
# Worst #sentiment for #SP1500 #stocks at market close -0.479 0.528
# new squeeze plays -0.339 0.435
# people are calling it bearish -0.148 0.450
# long $SQ 0.325 0.827
# Fader play here -0.219 0.575
# all sectors improved in bullish breadth. 0.647 0.753
# top-rated 0.428 0.820
# Stochastic Overbought -0.516 -0.313
# China February Retail Sales: E-Commerce Remains Resilient 0.383 0.796
# China February Retail Sales: E-Commerce Remains Resilient 0.383 0.796
# Large cap tech is finally trying to catch up with the rest of the market 0.373 0.666
# Stock dropping hard... -0.626 0.376
# Recall will not impact financial results 0.198 0.714
#  0.39 0.765
# very weak res -0.263 0.039
# gap up today?  0.454 0.864
# top-rated 0.428 0.820
# Coming from far could go far 0.298 0.855
# LNKD is great but doesnt the potential side with Fb 0.484 0.575
# Long $ENDP @ $26.23 on $AGN b/o rumor 0.57 0.817
# oil back above 60 0.543 0.757
# Short Setups Looking Nice....Really Nice -0.464 0.173
# gist of downgrades was apple failed to make a phone th -0.312 0.158
# Another 3% gain in $RIGL 0.378 0.737
# $STX 0.334 0.771
# $GRPN having a much better day than $FB -0.285 0.565
# stocks insiders are bullish on 0.433 0.709
# hipments on track to exceed forecasts 0.367 0.786
# LVMH affordable #luxe doing just fine helped by duty-free & confident mainstream shoppers 0.45 0.735
# cover all 0.114 0.806
# SS interest rose on 12/15 on day before we hit our lows. http://stks.co/c1QKr -0.405 0.054
# Most bullish stocks on Twitter during this dip 0.408 0.764
# $FCX 1.9% now -0.327 0.677
# First quarter is amazing 0.322 0.813
# $SAP Q1 disappoints as #software licenses down -0.431 -0.125
# Today's losers -0.317 -0.138
# looking for a sharp move up in equities 0.368 0.815
# gap fill coming up 0.511 0.810
# Report: Apple signs up for Google's cloud -0.38 0.602
# $FB TO $107 TOMORROW!? 0.539 0.811
# over 225 million new Internet users are being added globally every year 0.337 0.673
# Covered Call 0.329 0.867
# Long 0.66 0.867
# I've been picking up railroad stocks for the retirement acct 0.441 0.732
# when there is turmoil in the MENA region shippers perform 0.397 0.770
# Going back in, but slowly 0.119 0.726
# down 12% since I alerted it a short sell on 3-25 -0.391 0.257
# Bet the farm on 0.395 0.752
# Interest Heats Up for @Yahoo $YHOO 0.413 0.806
# the parties over -0.223 0.494
# Stocks Higher In Afternoon Trade 0.314 0.778
# Highest call to put ratio 0.348 0.882
# Apparently Intel thinks women should get paid the same as men 0.447 0.723
# $GS is looking weak while this market is moving higher not a good sign -0.597 0.532
# 1Mil Buy order at 0.426 0.717
# top stocks 0.376 0.803
# Top Stocks in 2015 are Ready to Lead Again in 2016 0.414 0.776
# 640m globally this week on avengers really sick ,Stan lee is a beast 0.24 0.758
# plus its Irish based 0.226 0.801
# In 0.646 0.836
# 13F Shows New Stakes in  0.468 0.815
# gap up today?  0.446 0.864
# Breakout watch 0.352 0.790
# Short Setups Looking Nice....Really Nice -0.464 0.173
# getting a lot of hype 0.095 0.697
# Court tells states to leave $GOOG alone 0.291 0.666
# Got a nice push today 0.28 0.789
# Unloaded $16,673 Worth of The Ensign Group, Inc. (NASDAQ:ENSG) Shares -0.46 0.099
# $23 by the end of the week..did you snatch ur 21 0.257 0.729
# continues its rally 0.538 0.809
# it With Lawsuit from Russian Search Engine -0.17 0.202
# #oversold 0.406 0.848
# have had 2 wks of fund inflows for the first time 0.58 0.723
# MU down 2.3% today and down 8.9% -0.469 0.433
# Unusual call buying 0.336 0.857
# $KO:US #COCA-COLA CO 19Oct Positive 0.646 0.793
# Sales weak -0.515 -0.153
# just broke resistance 0.598 0.723
# $FFIV up 7$ 0.32 0.808
# bot $CHRW 0.437 0.778
# Break-out thru 50 & 200- DMA 0.504 0.715
# now up 2.2% 0.523 0.789
# Bid for Reargument Denied by Judge -0.354 0.267
# with upcoming first support in a few days or weeks! 0.274 0.486
# $CAFN Cachet Financial Solutions Surging Forward today post earnings Up +13.26% 0.418 0.762
# lots of green on the 5 min 0.318 0.702
# looking to buy 0.32 0.783
# I don't think is the right fit -0.296 0.230
# stochastics finally starting to turn up 0.702 0.776
# Another Sell Rating -0.389 0.438
# Very nice breakout on a very nice stock 1.0 0.511
# launching shopping bot 0.348 0.758
# Buy these 3 stocks while there's blood in the streets 0.415 0.833
# Goldman Sachs reiterates conviction buy on 0.334 0.748
# losers -0.383 -0.084
# Long term uptrend intract so far 0.368 0.831
# the most trending 0.216 0.860
#  0.0 0.765
# Will be adding on dips 0.154 0.771
# Added long at friday close 0.513 0.745
# losing $400M of $AAPL's business -0.015 0.087
# #oversold 0.406 0.848
# Picking up a couple shares of $GOOG today 0.364 0.775
# My broker has no shorts who has them? -0.533 0.025
# sales numbers still holding up so well 0.315 0.800
# trying to drag $bidu with it. -0.524 0.393
# over 225 million new Internet users are being added globally every year 0.337 0.673
# downgraded to neutral at Deutsche Bank -0.446 0.176
# Five Stocks that Helped Starboard Valueâ€™s Equity Portfolio Return 6.5% in Q1 0.432 0.730
# buy zone today 0.285 0.862
# big picture is BRILLIANT 0.355 0.804
# bounce right now has no vol, more vol when it slid 0.19 0.683
# another story stock with an unhappy ending -0.426 0.062
# Love it 0.648 0.660
# Most bullish stocks on Twitter during this dip 0.408 0.764
# Mark Zuckerberg is doing an amazing job 0.326 0.728
# today's top gainers 0.447 0.820
# has had a history of a lack of PR -0.21 0.307
# closed Friday with the RS line in new highs 0.371 0.849
# look out belooooooowwww -0.85 0.378
# whole Semiconductor space looks interesting 0.328 0.709
# To Combine In $37 Billion Deal 0.241 0.739
# peaks above HOD 0.318 0.841
# Problem for shorts 0.358 0.680
# awesomely bullish stocks 0.68 0.788
# There is a good base building 0.228 0.804
# Biggest Market Losers -0.438 -0.246
# Highest call to put ratio 0.348 0.882
# SOLD to close $QQQ puts for +34% -0.059 0.303
# ooks pretty bullish for now 0.323 0.750
# looks really interesting on drop 0.579 0.670
# covered some shorts 0.294 0.684
# Add to 0.483 0.775
# triple top forming. 0.028 0.799
# will end up selling for pennies on the dollar -0.441 0.309
# looking sexy this morning 0.678 0.808
# Whole Foods shareholders vote down activist initiatives -0.076 -0.051
# Imagine $AAPL TV impact!! $$$ 0.24 0.692
# Southwest Is at Its Lowest Multiple Ever 0.106 0.795
# Still too early for an entry -0.387 0.451
# Moved Upper Bollinger Band 0.498 0.838
# Today I bought more 0.087 0.731
# won't have anyone buying products -0.429 0.296
# Short Setups Looking Nice....Really Nice -0.464 0.173
# still long term fan! 0.377 0.750
# What a nice reversal. 0.318 0.732
# TripAdvisor jumps on M&A rumors 0.47 0.758
# $TSLA Recalls 2,700 Model X Vehicle -0.336 -0.035
# Long tech 0.384 0.818
# Breakout Should be Confirmed 0.448 0.638
# Best performers 0.376 0.726
# very tight on the avail stock for shorting -0.406 0.279
# get into $WFM and $MJN 0.415 0.720
# Stochastic Overbought -0.516 -0.313
# Bounced off target buy area -0.299 0.622
# oversold 0.43 0.848
# double top reject -0.341 0.459
# Added. 0.47 0.788
# working on Cuba deals 0.419 0.833
# Dividend Hike Green Light 0.316 0.825
# I am excited about all these plays 0.322 0.392
# commodity weakness -0.376 0.608
# $fb small flong 109.25 via calls 0.352 0.634
# had a nice breakout of the recent consolidation 0.452 0.785
# sells flat..I am out.. -0.541 0.417
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# reserves are in decline 0.279 0.799
# this pull back of -0.03 0.623
# Pie In The Sky 0.365 0.827
# First quarter is amazing 0.322 0.813
# $TFM will have a way to go price wise to compete with Kroger. $KR 0.129 0.694
# Sector Stocks Leading Today 0.454 0.855
# biggest St50 gainers 0.452 0.758
# Bears Take a Clear Near Term Advantage -0.501 0.276
# Will A Onetime Zombie Stock Rise Again? 0.241 0.607
# today's bull flag 0.2 0.648
# iPhone SE Could Be Doing Better Than Expected 0.395 0.619
# Now up to 200 stocks making new 52 week highs 0.458 0.836
# Would short $AMZN on any rally -0.621 0.738
# after losing about $1 billion on $VRX? -0.643 0.529
# $CAT +5.10% 0.586 0.761
# The Top 10 brands for #millennials - $AAPL is #1, and $FB is way off the list at #65. 0.562 0.769
# looking tasty 0.31 0.753
# Sell Short Position on 0.361 0.618
# Nice day rally! 0.529 0.831
# damn me and low priced stocks -0.482 0.500
# Spy the bubble is in stock buy backs -0.268 0.503
# SELL signal by $NDX internals -0.541 -0.072
# Bullshit -0.209 0.465
# $X +2.27% 0.144 0.759
# this is what you get -0.007 0.530
# Another one to add, already happily holding 0.448 0.751
# RSI is down at 20 0.418 0.610
# $BABA is going to be an interesting one 0.233 0.498
#  0.315 0.765
# Buy the dip' 0.38 0.794
# There's no reason why $GOOGL can't get back to $1,000 0.288 0.721
# short -0.453 0.372
# Equity indexes working on a positive engulfing for March 0.308 0.777
# Highest call to put ratio 0.348 0.882
# Oil slid to a four-year low after -0.369 0.358
# sideways 0.0 0.526
# Unusual Call Activity 0.421 0.861
# green, lol... make-up to cover ugliness 0.242 0.801
# slight green 0.328 0.783
# Pivotal sees 27% upside for Alphabet 0.372 0.801
# refuse -0.35 0.480
# profitable hard and software 0.559 0.676
# $MSFT is opening up its #XboxLive online service 0.225 0.771
# here we gooo 0.268 0.757
# sold my 81 calls -0.312 0.579
# at resistance right here -0.105 0.542
# Holding 0.171 0.808
# Gevoâ€™s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight 0.392 0.817
# stocks at support w/ high trade quality 0.503 0.738
# finally broke free from big brother's shadow? 0.206 0.742
# I like this Ascending Triangle 0.478 0.763
# I'd be short $fast -0.625 0.162
# In Play Longs 0.273 0.848
# the most trending 0.216 0.860
# Supermarket Stocks Rally as Tesco Plans to Axe Non-core UK Assets 0.383 0.764
# out of $KRE -0.381 0.380
# time to accumulate for a long position 0.668 0.856
# No edge offered 0.025 0.828
# Oil To Break Out 0.666 0.647
# Found some good bull setups this week 0.448 0.800
# Sets Up for Breakout 0.528 0.864
# Something big is gonna happen here 0.0 0.433
# winning pick this week 0.452 0.844
# calls 0.472 0.725
# Double bottom 5.2 0.23 0.713
# lets see one more dip -0.274 0.630
# consistent gains but small 0.219 0.825
# on cusp of a major bollinger breakout on daily 0.511 0.740
# hanging tough in down market due to analyst upgrades 0.394 0.754
# Coal stocks are poking their head up 0.362 0.766
# Still holding 0.581 0.778
# is exceptionally bullish for Romney, the mkt, and the economy. 0.421 0.789
# Mid-single digits EBITDA growth 0.357 0.800
# posts 60 percent jump in 4Q profit 0.586 0.720
# Loving BTU and the coal stocks in here 0.437 0.696
# watching paint dry 0.0 0.274
# Fundamentally nothing has changed 0.198 0.702
# Stares Into the Abyss -0.325 0.368
# Smartphone Wars Wound Samsung 0.283 0.753
# where the growth is 0.252 0.786
# long this morning 0.476 0.852
# took my proprietary profit exit -0.334 0.434
# $YHOO refuse of $MSFT offer of 45 B is going to go down as one of the worst decisions ever. 0.012 0.701
# has gained an average of 0.9% a week for the last nine years 0.279 0.761
# eyeing $RA w take-over interest 0.041 0.701
# added to our $GILD position 0.408 0.824
# Investor long-term stock recommendation 0.557 0.740
# EPS growth is around 12% so far 0.316 0.836
# easonably priced high growth institutional fave glamour name that is going at least 30% higher 0.342 0.661
# Bull Of The Day 0.769 0.797
# Let's go up Gilead 0.328 0.686
# European Debt once again Keeps Stocks Down -0.374 -0.123
# Nice little cup-and-handle shaping up 0.342 0.768
# bail out 0.058 0.686
# I dumped $PYPL and $PRLB -0.506 0.245
# Top #NetPayoutYields 0.426 0.856
# CFO Sees Profitability From 0.211 0.732
# Price Target Raised 0.269 0.749
# So sad to see such a loved company eating dirt. -0.453 0.035
# is up 19% 0.309 0.813
# have cash to burn. 0.356 0.791
# Downbeaten stocks may be ripe for buys 0.316 0.818
# Strictly day trading this one long and short off 5 minute 0.035 0.682
# Aggressive Buy 0.306 0.819
# Long 0.444 0.867
# close above 28.64 0.308 0.782
# Will this cold put a dent in the massive horizontal rig production -0.237 0.194
# Long 0.394 0.867
# Over the TL it can go to 114, below it can go to 90. 0.0 0.316
# accumulating more $BSMX on any pullback 0.417 0.707
# record number of passengers served in 2015 0.638 0.775
# then trail up. 0.236 0.772
# Bullshit! All #AppleStores are EMPTY in #China -0.329 0.461
# downgrade -0.463 0.213
# another strong rail today after breaking intraday resistance 0.468 0.692
# Heard Netflix is raising its prices. It's all good it's worth it though 0.275 0.709
# yet not that much (price) has changed 0.036 0.623
# stocks insiders are bullish on 0.433 0.709
# Markets Are Still Acting Weak -0.443 -0.329
# Top #NetPayoutYields 0.426 0.856
# S1 above gap. keeping an eye on S2 0.346 0.781
# shorts likely to take profits into close -0.503 0.456
# I see no reason to sell yet -0.093 0.408
# ripping early 0.325 0.670
# Keeping my stops a bit on the tight side 0.135 0.733
# Receives 7-Year, $50M Contract 0.497 0.817
# splat! poor Q1 orders -0.453 0.191
# With Oil Prices Down further, Oil Stocks Looking Less Cheap -0.42 -0.049
# Finding Support 0.259 0.782
#  0.0 0.765
#  0.406 0.765
# $GOOGL patents turn signal detector for autonomous cars. 0.393 0.707
# wants lower -0.37 0.173
# add in 0.354 0.850
# I see a 20 percent upside in $FB shares from here 0.589 0.572
# great growth stk & also raised dividend 0.597 0.755
# $ENDP being sued by FT -0.602 0.213
# Breaking 52 week highs timing looks great now 0.419 0.728
# LargeCap Growth fundholders get lift 0.597 0.741
# progress witnessed 0.436 0.766
# trying to drag $bidu with it. -0.524 0.393
# 60% short interest or not -0.315 0.392
# The momo leaders are taken down one by one -0.351 0.130
# Stochastic Overbought -0.385 -0.313
# new squeeze plays -0.339 0.435
# Active puts -0.49 -0.014
# Mulls Sale of $1 Billion Venture Capital Portfolio 0.295 0.803
# strong buy within a month 0.119 0.755
# Buy these 3 stocks while there's blood in the streets 0.415 0.833
# I'm watching(and buy targets) 0.344 0.780
# $YHOO have lost 50% since Nov 14 -0.422 0.328
# wouldn't be surprised to see a green close 0.416 0.653
# Failed breakouts & failed setups -0.419 0.226
# high-flyers have been falling -0.501 0.106
# decision to sell robot business exposes growing pains -0.289 0.015
# stocks insiders are bullish on 0.433 0.709
# Drop expected -0.002 0.648
# Upgraded to a buy by Alpha Street Research 0.715 0.756
# Worth a chance here 0.145 0.666
# Rally Friday! 0.66 0.858
# expects to break even 0.219 0.774
# all higher 0.295 0.772
# Adobe Receives New Rating from Top Analyst 0.141 0.803
# alot to worry about -0.319 0.157
# We See More Reasons To Be Cautious -0.093 0.263
# huge buy in all these names 0.608 0.826
# $MSFT 0.43 0.825
# but Verizon is still the bidder to beat 0.404 0.803
# Could the pride of social media be gettin ready to fall? -0.287 0.274
# gold going parabolic 0.442 0.792
# hold through all the media BS and you will be profitable 0.543 0.595
# Biggest Market Losers -0.438 -0.246
# #sectorbreadth Strongest sector is Industrials 0.545 0.763
# uch a bloated valuation -0.536 0.084
# I Love blood like a vampire.....Keep bleeding for me -0.391 0.151
# $FB and $IBB still weak -0.355 -0.229
# Bull Candle 0.335 0.798
# $IEF bullish 0.423 0.808
# best scenario going forward is this stock slowly falling everyday -0.264 0.240
# plus its Irish based 0.146 0.801
# Today's losers -0.317 -0.138
# If that's what you want then buy some 0.245 0.714
# Just sold 2 Apr-22 115 calls -0.024 0.351
# Stochastic Overbought -0.385 -0.313
# Long Position on 0.674 0.808
# new HOD 0.432 0.831
# LONGS 0.511 0.845
# beat 0.284 0.828
# down 25% since Tue morning. -0.527 0.553
# 10% Dividend Increase Rewards Patient Investors 0.484 0.819
# Go Long until exp imo 0.414 0.823
# remember when Zuck in 2010 told us he was going to fix email with it? 0.091 0.597
# Bought a little yesterda 0.562 0.778
# long term uptrend 0.53 0.754
# Sets Up for Breakout 0.528 0.864
# picked up $CALM 0.47 0.761
# advance 0.604 0.793
# gets a patent and goes up .20 today 0.432 0.830
# Don't like -0.483 0.556
# GALE stacks up poorly from an insider ownership -0.314 0.196
# Nice day rally! 0.529 0.831
# #oversold 0.406 0.848
# Took a small position 0.344 0.830
# Continues to base on the weekly chart -0.047 0.470
# amazon just signed a deal to lease 20 Boeing 767 cargo planes 0.396 0.727
# Today's losers -0.317 -0.138
# up $5.80 0.334 0.654
# EPS growth is around 12% so far 0.316 0.836
# may not be bad 0.081 0.620
# Top #NetPayoutYields 0.426 0.856
# next major platform 0.374 0.812
# Dailymail content is perfect for YHOO demographics 0.153 0.782
# investors are nervous about outlook, as they should be. -0.357 0.469
# Money flow positive 0.322 0.843
# Electronic Arts attracts more investors 0.409 0.804
# Biggest Market Losers -0.438 -0.246
# down 5.43 % -0.392 0.302
# Multiple expansion intact as well! 0.281 0.820
# Added $REGN at 402 0.589 0.774
# PLUNGING! Back to -0.628 0.669
# running 0.284 0.795
# Add to $FXP $SKF positions 0.501 0.774
# get ready for the 560 *flush* -0.264 0.282
# It Needs A New Tablet Strategy -0.195 0.304
# Taking some profits -0.142 0.347
# Down day for all biotechs Good to load up 0.281 0.764
# still loving it today 0.385 0.806
# Breaking 52 week highs timing looks great now 0.419 0.728
# Timberrrr -0.562 0.475
# The Best Stocks for 2012 0.463 0.798
# double bottom could be in 0.271 0.812
# 3-star analyst Joe Wittine from Longbow Research reiterated a HOLD rating 0.214 0.650
# still having some trouble at the resistance line 0.071 0.811
# Accumulation chart continues to make new highs showing accumulation continuing to take place 0.497 0.755
# Apple hires former Amazon executive George Stathakopoulos as head of corporate data security 0.146 0.799
# has been slipping -0.245 0.312
# bullish reversal setup and breakout 0.441 0.870
# Near HOD 0.366 0.826
# Moody's downgrade -0.299 0.046
# Markets Back in Black for 2016 0.271 0.802
# this one is looking beat up and interesting -0.084 0.721
# $amd is a two dollar spec play -0.163 0.441
# SELL signal by $NDX internals -0.501 -0.072
# starting to creep up -0.014 0.757
# invest in elon 0.327 0.823
# Still have my position 0.381 0.775
# minuscule 0.09% gain in $ZIV -0.059 0.306
# airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU 0.092 0.847
# Receivable going to zero -0.343 0.371
# Cisco also lower -0.416 0.050
# Bullish MA Crossovers 0.457 0.855
# sell $RHT -0.591 0.245
# In Play Longs 0.273 0.848
# next 5-6 charts illustrate a bullish weekly outcome 0.119 0.681
# I would buy some wtsl at these prices 0.193 0.765
# more positive comments from $MS 0.426 0.815
# volume footprint looks great -0.097 0.640
# Drugs and Biotech Getting Perky 0.387 0.773
# wants to ta -0.265 0.363
# companies shld be worried about iCloud -0.329 -0.142
# negative P&L on hardware -0.387 0.260
# eyes more disposals in bid to appease City backers 0.286 0.776
# gap fill 53.53 still waiting. 0.085 0.782
# long 0.488 0.867
# Pie In The Sky 0.365 0.827
# afternoon selloff as usual will be brutal -0.569 0.309
# Short more  -0.605 0.627
# Has a great cash balance 0.493 0.796
# calls for nice gains 0.396 0.746
# Top holdings 0.311 0.832
# getting out of his -0.374 0.420
# strong 5min @above bollies 0.235 0.762
# near a buy point last week 0.093 0.813
# Google Will Soon Start Selling Chromebooks At Walmart And Staples 0.34 0.766
# broke out now of his bull flag channel and make new highs 0.369 0.779
# start strong finish weak -0.086 -0.202
# Services like $NFLX and #Hulu are growing much faster than cable 0.364 0.749
# top stocks 0.376 0.803
# Goldman Sachs reiterates conviction buy on 0.622 0.748
# $AAPL max pain -0.063 0.123
# With Oil Prices Down further, Oil Stocks Looking Less Cheap -0.42 -0.049
# got some more 0.295 0.747
# Favorite Stocks 0.401 0.786
# BUY 0.437 0.819
# run run $AMZN up 4.4% now 0.477 0.674
# consumers keep cautious stance -0.258 0.099
# all on a longer-term, technical swing long basis. 0.591 0.857
# $FB is taking the shine off $AAPL and $GOOG -0.13 0.446
# broken out of a major horizontal resistance 0.345 0.690
# Pie In The Sky 0.365 0.827
# Balancing ROIC and growth to create value 0.334 0.787
# Locked in some $FB puts for nice gain -0.524 0.298
# we close around $34 it's a good sign 0.494 0.619
# $NFLX more positive comments from $MS 0.085 0.811
# Stochastic Overbought -0.516 -0.313
# not all time low , been lower -0.268 -0.153
# if one is to go long, money rotating into large cap tech 0.383 0.755
# looks great 0.396 0.725
# starting to show some relative strength 0.334 0.744
# Time to stomp on some dreams. -0.258 0.373
# If positive outcome w/ lung study5/8 we may see a 13D Filing by Soros 0.33 0.673
# more test of 12.85 coming up 0.152 0.786
# RSI lowest level since October 2012 0.165 0.735
# Long setup 0.438 0.863
# Baird Upgrades Tesla Motors $TSLA to Outperform 0.52 0.732
# my 18 year old and 14 year old are never on $FB  -0.258 0.316
# Sector Stocks Leading Today 0.454 0.855
# $YOKU 0 0.0 0.544
# may not be as secure -0.308 0.368
# The Best Stocks for 2012 0.463 0.798
# Long over 3.95/great find - hope that wold be another $ANLY or $PZZI, still holding second 1/2 0.509 0.760
# today's momentum movers 0.282 0.820
# Google Will Soon Start Selling Chromebooks At Walmart And Staples 0.196 0.766
# Found some good bull setups this week 0.448 0.800
# holding up relatively well compared to the broad market 0.394 0.707
# less than stellar day but it held the 50 day moving average -0.14 0.564
# A beautifully orchestrated marke 0.152 0.764
# up 7$ 0.177 0.812
# Cures 96% of Hard-to-Treat 0.534 0.756
# Long 0.23 0.867
#  0.0 0.765
# let it run 0.473 0.730
# Yahoo extends bidding deadline as interest grows 0.329 0.799
#  -0.272 0.765
# Today I bought more 0.087 0.731
# you will enjoy the bull run that just started 0.376 0.736
# Issues Statement On Debt Ceiling -0.341 0.093
# there's a good short spot -0.434 0.214
# Worst performers today -0.365 0.801
# Insiders Are Selling -0.351 0.346
# good news for domestic automakers 0.413 0.781
# can ONE of the cheerleaders show me actual valuation work -0.205 -0.026
# up to $95 after market! 0.342 0.635
# Buying on Weakness 0.511 0.718
# Three of my hot stocks today 0.461 0.840
# Ready for Take OFF! 0.472 0.712
# Report: Apple signs up for Google's cloud 0.15 0.602
# Short Setups Looking Nice....Really Nice -0.464 0.173
# short $MBLY -0.606 0.294
# will push $NLY investment to another time -0.255 0.524
# Notable gainers among liquid option names this morning 0.513 0.834
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.605
# point at a possible move up 0.176 0.767
# they let the stock fall big time after earnings -0.455 0.487
# not selling before 0.221 0.566
# tremendous opportunity awaits 0.456 0.797
# up 10% in premarket 0.507 0.692
# the overall market improve 0.433 0.763
# gots some $AEZS this morning 0.514 0.832
# Erinn Murphy of Piper Jaffray thinks $FINL is a BUY 0.501 0.794
# longer term top building 0.099 0.841
# debt crisis entered a dangerous new phase -0.331 -0.183
# $MU may go down 6% if the bear pattern is confirmed -0.404 0.298
# looking good 0.255 0.654
# cracking -0.118 0.380
# Bullish MA Crossovers 0.457 0.855
# still an interesting finance play 0.305 0.707
# broke the downtrend line 0.309 0.794
# some of the stocks that came up on screens for longs 0.431 0.840
# Defying the Downturn 0.407 0.810
# soars pre-market 0.34 0.692
# This stock is a buy 0.498 0.803
# PAIN -0.4 0.388
# hi beta hi performers 0.384 0.689
# in trouble ? is that earnings gap still unfilled ? -0.368 0.385
# calls for nice gains 0.396 0.746
# Long 0.394 0.867
# bull move ended -0.204 0.385
# trying to lead higher here 0.256 0.645
# bought back more shares here today 0.243 0.781
# getting very close to 200 MA of 110.87, hasnâ€™t closed above 200 MA since July 31, 2015. If / when it does, will be significant. 0.218 0.704
# addding tsla ss , added small vrx long $TSLA $VRX 0.394 0.584
# sold xoma -0.281 0.261
# nice blurb for $BBRY 0.183 0.747
# What a nice reversal. 0.318 0.732
# I'm watching(and buy targets) 0.344 0.780
# Don't catch falling knives 0.286 0.684
# Barclays signs on to Apple Pay 0.354 0.579
# looking weak -0.352 -0.132
# Markets Are Still Acting Weak -0.443 -0.329
# short/put positions looking good here -0.485 0.551
# bullish $NFLX day trade setup 0.422 0.830
# Unusual Call Activity 0.332 0.861
# Institutions seem to like this class of stocks 0.422 0.732
# loading $SPY and $AAPL puts -0.537 -0.106
# watch $TSLA > 34.5 0.339 0.591
# still in bear market -0.421 0.470
# China winners 0.452 0.781
# stock options trade would have more than doubled your money 0.294 0.673
# master class on how to conquer mobile 0.419 0.770
# got hit hard lower this AM -0.551 0.411
# biggies must be loading up here at lows 0.438 0.701
# has a hard to diminish lead 0.262 0.712
# Inverse Head and Shoulders forming 0.394 0.769
# weak outlook -0.034 -0.011
# Indices are rallying today -0.193 0.698
# $GPRO up 0.619 0.813
# Embarrassing China numbers -0.312 0.390
# Possible target 0.162 0.767
# Rally Friday! 0.66 0.858
# Long setup 0.444 0.863
# CLOSED GREEN!!!! 0.622 0.794
#  0.0 0.765
# bumping its head on declining daily 8ma as overhead resistance -0.35 0.452
# At least you didn't stop out -0.222 0.351
# finds support 0.504 0.797
# Long-Term Potential Robust 0.249 0.812
# hopefully peeps shorting $CAMT for scalps -0.36 0.202
# Now it is time to short $TSLA -0.385 0.172
# keep stock on your watch list 0.271 0.808
# gap up tomorrow 0.439 0.834
# demand ahead 0.532 0.797
# Our updated #core4 portfolio 0.452 0.823
# new HOD with conviction keeping $570 on watch for Resistance 0.529 0.740
# long the market 0.525 0.736
# acting tough on big volume against the tape 0.243 0.759
# Best outperformers ranked 0.492 0.833
# Infection worries prompt regulatory reviews -0.401 0.130
# Back to Back intraday reversals -0.53 0.423
# Weekly 625 calls now +42.31% 0.144 0.716
# has been a bull and $gld a bear 0.0 -0.008
# Watchlist Top Stocks 0.342 0.801
# I would consider this opportunity to add my position 0.401 0.807
# Markets Are Still Acting Weak -0.443 -0.329
# bear flag -0.535 0.438
# took some $ENDP long this am 0.613 0.676
# Yes buy everything up 0.829 0.798
# Brent back below 49 -0.353 0.074
# A Premier Retail Dividend Play 0.354 0.751
# beat 0.284 0.828
# shipments slid -9.6% to lowest quarterly total since 2007 -0.336 -0.015
# long 0.537 0.867
# Bullish MA Crossovers 0.457 0.855
# the most trending 0.216 0.860
# Unusual Call Activity 0.421 0.861
# Nice day rally! 0.529 0.831
# Added long at friday close 0.513 0.745
# Looks like might break down -0.516 0.028
# Long over 3.95/great find - hope that wold be another $ANLY or $PZZI, still holding second 1/2 0.509 0.760
# Pushing Channel Development 0.458 0.772
# bot $EZPW 0.437 0.779
# Like this > 0.374 0.757
# short -0.633 0.372
# CHUNK OF DEC $35 PUTS BOUGHT AT -0.601 0.430
# Not Time To Buy -0.382 0.761
# round 2 short -0.438 0.252
# 580+ should be coming very quick, if the FED supports the markets 610 0.296 0.737
# debt crisis entered a dangerous new phase -0.331 -0.183
# some of the stocks that came up on screens for longs 0.431 0.840
# Sector Stocks Leading Today 0.454 0.855
# short the market -0.541 0.599
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# Over 16 with conviction 0.585 0.656
# $NFLX at $44B 0.215 0.763
# Seeing Competition -0.216 0.239
# Some competitors worry that BlackBerry is the inevitable successor to Northern Telecom 0.27 0.730
# Moved Upper Bollinger Band 0.498 0.838
# Unusual Call Activity 0.332 0.861
# 4 shorts only -0.53 0.601
# TOP 5 STOCK PICKS 0.414 0.742
# tired of seeing this go down -0.085 -0.010
# ascending base breakout starting to gain traction 0.733 0.730
# have enjoyed shorting Anglo these last few weeks -0.269 0.331
# Top holdings 0.311 0.832
# $AAPL cleary surpassed their BB -0.274 0.192
# all going down -0.559 0.131
# Stochastic Overbought -0.385 -0.313
# Expands Share Repurchase Program 0.285 0.793
# Play safe, be long 0.335 0.860
# Covered 0.128 0.801
# Bullish yeah 0.393 0.783
# Closed short position 0.143 0.757
# Why $TWTR is doomed in 1 chart -0.027 0.550
# New RSI signal created on $COST - Buy 0.497 0.679
# Global PC shipments fell 9.6% in Q1 -0.152 0.638
# holding up well today 0.318 0.876
# Unusual Call Activity 0.421 0.861
# all higher 0.293 0.772
# Deutsche Bank: cuts #Starbucks to Hold -0.17 0.652
# stocks at support w/ high trade quality 0.503 0.738
# gapping up to all time highs 0.782 0.816
# downgrade -0.463 0.213
# NetApp downgraded by Macquarie to underperform -0.574 0.591
# short the $TSLA -0.603 0.310
# shipments slid -9.6% to lowest quarterly total since 2007 -0.295 -0.015
# Fed cuts rates forecast 0.449 0.781
# lost revenue -0.43 0.702
# Finding Support 0.259 0.782
# confirmation is a hold  0.259 0.769
# Sounds like we'll see some green tomorrow 0.395 0.771
# closed Friday with the RS line in new highs 0.371 0.849
# Beautiful trend/base 0.645 0.694
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# $AAPL signs up with Google cloud -0.403 0.568
# heading back down to -0.25 0.455
# over 225 million new Internet users are being added globally every year 0.337 0.673
# Unusual call buying 0.336 0.857
# obby against Judge Garland or they risk losing the case -0.261 0.525
# probably long 0.29 0.851
# Unusual Call Activity 0.421 0.861
# Loooooongggggg base 0.557 0.695
# $PYPL w/ a solid start in #ecommerce checkout 0.375 0.635
# want to go this morning 0.28 0.813
# breaking out 0.068 0.632
# Nobody is recommending the sale of this stock 0.623 0.637
# all on a longer-term, technical swing long basis. 0.591 0.857
# buying my last round of shorts next week -0.339 0.712
# This stock is such a winner 0.451 0.747
# Pivotal upgrades Alphabet ahead of Q1 results 0.53 0.760
# Monday sold -0.37 0.324
# only those with the stomach for high risk are left -0.151 0.507
# Men sell $SVXY puts 0.092 -0.082
# was still up on the screen 0.377 0.668
# some upside today 0.254 0.842
# shorts made a killing last couple days -0.529 0.447
# Will be looking to add shares if we get a new high breakout 0.421 0.787
# atching SPY 60 min STO for a push -0.035 0.658
# #whisperbeat 0.619 0.706
# BMW entering into ride-share market with i3 0.399 0.580
# Rally Friday! 0.66 0.858
# staying strong 0.532 0.789
# Can $TSLA roll over yet? -0.212 0.431
# Stock Receives Ratings Downgrade Today at Jefferies -0.501 0.558
# Looks weak now -0.504 0.462
# small pos, short 180 wkly puts -0.597 -0.089
# downward trendline -0.143 0.818
# isn't cheap -0.353 0.368
# they have real assets 0.432 0.661
# Finding Support 0.259 0.782
# Buy these 3 stocks while there's blood in the streets 0.415 0.833
# Risky move -0.078 0.577
# Great short entry right now -0.461 0.465
# Google, Inc. completes acquisition of ICOA 0.267 0.571
# Stocks Higher In Afternoon Trade 0.314 0.778
# Looking for continuation with volume increase 0.308 0.710
# Top #NetPayoutYields 0.426 0.856
# actively Head & Shoulder in progress -0.222 0.778
# with personal story sharing declining -0.572 0.046
# worst performers -0.244 0.640
# not dipping - testing the 200 day ma 0.281 0.767
# Bad Apple -0.392 0.615
#  0.0 0.765
# should reward better on good earnings 0.326 0.617
# daily sales slowing again -0.105 0.531
# In play tmrw 0.805 0.707
# Sector Stocks Leading Today 0.454 0.855
# bidding war picks up for the company 0.391 0.652
# is now beaten down, hated -0.303 0.440
# China winners 0.452 0.781
# Announces Record #Esports Viewership 0.208 0.623
# shares up ~7% after hours 0.552 0.639
# seriously nothing says strong growth like 0.312 0.622
# Call credit spread 0.311 0.687
# they are hitting everything in sight. -0.504 0.631
# bought 3500 shares today! 0.738 0.797
# LNKD is great but doesnt the potential side with Fb 0.283 0.575
# short somewhere in the high -0.526 0.640
# #iPhone is really annoying. -0.398 0.563
# Bought more - Bought $FB at 0.506 0.664
# only a 50% gain from these levels -0.22 0.369
# companies shld be worried about iCloud -0.329 -0.142
# indicators turning up 0.351 0.743
# US Adds 321K Jobs In November 0.183 0.809
# ...
# I blew out $ZMH -0.462 0.561
# LOOKS like we are bouncing 0.391 0.579
# BlackBerry Messenger is second only to Facebook in user loyalty 0.243 0.752
# wayyy overvalued right now -0.451 0.526
# Gaining Momentum! 0.527 0.744
# Surges On Deal 0.419 0.765
# long this morning 0.476 0.852
# trade continuing very nicely from yesterday 0.495 0.797
# slow-motion disruption of the global auto industry 0.601 0.566
# BTO three 110 puts @ 1.34 -0.267 0.427
# Apple's iPhone SE: The Sold Out Flop -0.336 0.438
# Potential intermediate top in an Uptrend 0.32 0.743
# stocks at support w/ high trade quality 0.503 0.738
# closng higher from here 0.48 0.651
# short-term forecast is now bearish -0.343 0.623
# Take it while you can 0.515 0.351
# lets see 14+ today 0.302 0.735
# bought CALL OMNIVISION TECH 0.722 0.780
# Pie In The Sky 0.365 0.827
# EPS growth is around 12% so far 0.316 0.836
# Could the pride of social media be gettin ready to fall? -0.403 0.274
# producing a Bullish MACD Xover 0.691 0.682
# no more buys 0.146 0.813
#  0.0 0.765
# Market getting crushed today -0.302 0.809
# Today I bought more 0.087 0.731
# bidders line up 0.252 0.813
# LED light bulb prices rise in Japan 0.054 0.808
# expecting $SPY to close above 0.385 0.724
# down 1.1% -0.352 0.603
# Short Setups Looking Nice....Really Nice -0.464 0.173
# LONGS 0.511 0.845
# notice how the doomsaying bears disappear during the climbs 0.467 0.648
# recessions -0.307 0.720
# watch is showing serious demand 0.491 0.731
# new 'large player sells' -0.498 0.532
# Biggest Market Losers -0.438 -0.246
# Prob a buy if it does 0.428 0.665
# and is overbought -0.48 -0.045
# put money in $hznp better option -0.081 0.753
# sales exceed target 0.526 0.722
# Goldman Sachs reiterates conviction buy on 0.087 0.748
# red before the bell -0.442 0.627
# stock will hit $170 easily 0.327 0.490
# Downbeaten stocks may be ripe for buys 0.316 0.818
# buy safety equipment maker for $2.5 billion 0.23 0.647
# weak close -0.297 0.396
# looks like it could be about to fall apart -0.515 0.424
#  0.0 0.765
# shorts are getting nervous 0.366 0.415
# Facebook has now been down 10 minutes -0.258 0.425
# Monday Bulls Are Out! 0.457 0.531
# today's top gainers 0.447 0.820
# Tesla Motors recalls -0.424 0.574
# Aggressive Buy 0.306 0.819
# mentioned as potential suitee, suitor 0.258 0.640
# We See More Reasons To Be Cautious -0.093 0.263
# Do you really think in 4 weeks they capture 10%? Impossible. -0.317 0.483
# Friday was last chance under $2 0.228 0.761
# excellent / factual bear argument -0.507 0.357
# Bears Take a Clear Near Term Advantage -0.501 0.276
# relative weakness is pretty apparent -0.262 0.664
# Don't think buyout rumor strong enough too be driving this up just yet -0.02 0.618
# $YHOO +2.61% 0.16 0.840
# $TPLM Triangle #Petroleum 9.80+3% 2M Expanding Caliber 0.376 0.551
# Downbeaten stocks may be ripe for buys 0.316 0.818
# downgrade -0.463 0.213
# ISRG Short -0.678 0.323
# $POZN +30 0.146 0.643
# -2.10% vs -0.90% Est -0.489 0.551
# Daily Mail enters competition to acquire Yah 0.342 0.538
# Stocks Higher In Afternoon Trade 0.357 0.778
# Watchlist Top Stocks 0.342 0.801
# wants to ta -0.23 0.363
# $VIAB down 40% -0.516 0.478
# Sudden optimism about iPhone sales 0.279 0.403
# Google, IBM, ARM And AMD Begin The Assault On Intel's Server Franchise 0.368 0.552
# Monday sold -0.44 0.324
# earning play $fast 47 puts, $vrx 34 puts , $bidu 182.5 puts -0.387 -0.285
# Bullish MA Crossovers 0.457 0.855
# Watchlist Top Stocks 0.342 0.801
# looks constructive 0.28 0.690
# $UNT trying to break out of 5 day range 0.244 0.648
# Today I bought more 0.087 0.731
# Failed breakouts & failed setups -0.419 0.226
# shorting here into close might be play -0.469 0.574
# long play 0.48 0.788
# good for economy 0.273 0.811
# today's bull flag 0.2 0.648
# Inside week buy triggers 0.485 0.723
# Insiders Are Selling -0.351 0.346
# Long 0.23 0.867
# Insiders Are Selling -0.351 0.346
# revenue grew double-digit 0.454 0.675
# hangin on my a thread -0.337 0.630
# Long $TSLA 0.607 0.534
# recalls 2,700 Model X cars -0.315 0.393
# is in the process of streamlining its structure 0.229 0.614
# In Play Longs 0.273 0.848
# MACD and ADX are crossing over the signal lines! 0.569 0.562
# Yahoo, Facebook in Ad Partnership Talks 0.249 0.603
# Buy the dip' 0.38 0.794
# About to break out on the 5-min 0.313 0.670
# Long over 3.95/great find - hope that wold be another $ANLY or $PZZI, still holding second 1/2 0.509 0.760
# Moves on both sides possible -0.023 0.723
# Fed cuts rates forecast 0.449 0.781
# the parties over -0.223 0.494
# up almost 0.378 0.724
# $LEI Higher 0.388 0.732
# Breakout watch 0.352 0.790
# adding to position here 0.685 0.705
# Brutal slide -0.044 0.608
# Looks good on the weekly chart 0.379 0.487
# holding up relatively well compared to the broad market 0.394 0.707
# covered the swing 0.021 0.781
# Bullish MA Crossovers 0.457 0.855
# Top Stocks in 2015 are Ready to Lead Again in 2016 0.414 0.776
# making new HOD 0.442 0.828
# defect -0.366 0.734
# Most bullish stocks on Twitter during this dip 0.408 0.764
# strong move today for the Junior Gold Miners 0.75 0.691
# Tomorrow party time for the Bears!! -0.524 0.574
# It is cheap. 0.183 0.370
# Insiders Are Selling -0.527 0.346
# Why The Coal & Shipping Sectors Could Rise Again 0.418 0.642
# small businesses have called $YELP a scam for years -0.45 0.723
# weekly 120 puts +283% -0.35 0.360
# looking good 0.362 0.654
# I may try a short -0.352 0.279
# Equity indexes working on a positive engulfing for March 0.308 0.777
# and it will continue 0.413 0.696
# To Combine In $37 Billion Deal 0.241 0.739
# Another quiet week 0.0 0.779
# Deutsche Bank downgrades -0.436 0.360
# near-term target $77.38 0.0 0.643
# $FB is taking the shine off $AAPL and $GOOG 0.435 0.446
# holding up nicely 0.441 0.790
# Bought $FB $111 calls 0.579 0.642
# airlines battle for Cuba routes $AAL $LUV $SAVE $JBLU 0.092 0.847
# accuses $ZNGA of copyright infringement -0.284 0.647
# mrkt needs to washout -0.055 0.179
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# shipments slid -9.6% to lowest quarterly total since 2007 -0.283 -0.015
# #joke #bubble #buyerbeware -0.506 0.618
# $AZPN is worth $20 a share not $40 -0.563 0.581
# Come on and run with the bulls today 0.484 0.837
# $WFC -8.30% -0.584 0.616
# 5 Best Analyst Rated Stocks 0.509 0.793
# nothing investors can do to damage Apple 0.322 0.553
# Don't underestimate Mark 0.37 0.621
# Unusual Call Activity 0.421 0.861
# recessions -0.307 0.720
# buying my last round of shorts next week -0.339 0.712
# buy more on the weakness? 0.346 0.710
# Good time to buy 0.533 0.792
# the most trending 0.216 0.860
# Express Scripts loses -0.336 0.690
# debt crisis entered a dangerous new phase -0.331 -0.183
# then shorted it down. -0.405 0.003
# Bullish yeah 0.109 0.783
# Call sweepers stepping up this morning 0.343 0.827
# Failed breakouts & failed setups -0.419 0.226
# so i can add more 0.307 0.675
# hearing rumours of a major joint venture announcement 0.427 0.672
# $NLSN launching a marketing cloud -0.245 0.590
# Moody's downgrade -0.299 0.046
# Tesla dropped a hard J this morning -0.376 0.774
# 15 years after release, Windows XP is still the 3rd most popular OS 0.2 0.596
# weakness could be opportunity 0.345 0.775
# citing positive spending trends 0.436 0.618
# isn't going anywhere 0.241 0.623
# Sector Stocks Leading Today 0.454 0.855
# In Play Longs 0.273 0.848
# it shoots to the MOON as my favorite pumper 0.514 0.620
# Best performers 0.307 0.726
# Equities recently tagged #undervalued 0.353 0.675
# shorts breakin flag 0.226 0.609
# do i have enough shares ??? 0.429 0.484
# added to $DNKN (longs) 0.528 0.824
# Bears Take a Clear Near Term Advantage -0.501 0.276
# TOP 5 STOCK PICKS 0.414 0.742
# People still coming in 0.257 0.785
# < Money-Losing$ OverValued China IPO Junk -0.638 0.317
# Bigger win for 0.273 0.755
# honestly, it's been disappointing -0.443 0.561
# over 225 million new Internet users are being added globally every year 0.337 0.673
# Grab it while it's cheap 0.488 0.339
# adding $expe and $pcln to the mix soon 0.408 0.789
# Short Setups Looking Nice....Really Nice -0.464 0.173
# t's time to short at this point -0.489 0.692
# today aside setting up for another drop -0.504 0.706
# the most trending 0.216 0.860
# bail out 0.058 0.686
# $TSLA is the only 'auto' stock showing a gain year-to-date -0.334 0.572
# ready to break $QCOM watching at 55.7 0.235 0.780
# bearish charts keep getting worse. -0.619 0.566
# making all kinds of gains ???? 0.42 0.762
# looking to add a gold miner and possibly lower pe tech name into close 0.425 0.605
# looking weak and possibly ready to 'let go' -0.482 0.578
# Marriott wins new Starwood deal by raising cash portion of bid 0.332 0.704
# Looks like one of the best values #Lithium stocks in the space 0.197 0.753
# Watchlist Top Stocks 0.342 0.801
# soars pre-market 0.398 0.692
# $BBRY smack down looks legitimate -0.105 0.512
# allow for the growing middle class 0.289 0.668
# Will we see $410 again 0.152 0.535
# Bricks and Mortar retailers selling cheaper -0.352 0.542
# Oil To Break Out 0.666 0.647
# under $2 today? -0.164 0.849
# Falls 18% Pre-Market on Q3 Sales Results -0.394 0.652
# growing customers globally 0.576 0.669
# Little-Discussed Problem This Pro Is Watching At -0.476 0.682
# an upward movement is expected 0.387 0.594
# Market seems stuck in the mud -0.259 0.610
# will get in on the next run up 0.275 0.772
# Fed cuts rates forecast 0.449 0.781
# Buy the dip' 0.38 0.794
# next year could be a very good year for them 0.528 0.270
# Stock Trading Lower Today  -0.375 0.717
# bear raid -0.48 0.458
# curing #overbought conditions -0.262 0.108
# Launch Updated Model S With Steeper Price Tag 0.261 0.547
# getting kneecapped by $BEXP selling itself dirt cheap -0.384 0.011
# $AMZN is becoming more and more the go-to site for almost all categories in ecommerce. 0.269 0.703
# Alibaba invests in Southeast Asian retailer Lazada 0.0 0.584
# getting sold here. -0.551 0.508
# the most trending 0.216 0.860
# $AAPL could pick em up too. 0.324 0.523
# Higher In Afternoon Trade 0.243 0.778
# $AAPL a new long IF 110.61 is broke 0.184 0.757
# puts came in -0.517 0.709
# record number of passengers served in 2015 0.638 0.775
# ure has lots of attractive suitors 0.325 0.611
# delivering the goods again let's see if that can spill over in other chinese internet names 0.502 0.652
# on lows -0.465 0.747
# could be lotto winners 0.29 0.811
# Buy the dip' 0.38 0.794
# A good place to take a shot 0.465 0.685
# 5 Reasons Not to Buy Gold -0.447 0.734
# In oversold conditions 0.459 0.609
# stocks at support w/ high trade quality 0.503 0.738
# Buying $fas last week was the play of the month 0.74 0.725
# Slow bleeding death -0.641 0.548
# SolarCity customers can produce enough electricity to power Tesla fleet 0.601 0.527
# $YHOO bidding heats up 0.281 0.798
# Nice day rally! 0.529 0.831
# Sector has been taking a beating recently, could be positive here 0.361 0.691
# Gevoâ€™s Alcohol to Jet Fuel Now Eligible to be Used for Commercial Flight 0.031 0.817
# downgrade -0.463 0.213
# BMW entering into ride-share market with i3 0.132 0.580
# hope kog shorters learned a lesson 0.085 0.634
# has a 42.71% Float Short. Lo -0.392 0.407
# interest level has skyrocketed here the last two week 0.165 0.740
# new PM high 0.403 0.629
# Nice day rally! 0.529 0.831
# long on 0.457 0.802
# 333.0% increased bullish conversations 0.442 0.663
# Accumulating -0.099 0.716
# Stochastic Overbought -0.385 -0.313
# Daily Mail And General Trust eyeing Yahoo! 0.39 0.708
# received a Buy rating from Wells Fargo 0.456 0.691
# taking a small chill pill today -0.183 0.807
# Five Stocks that Helped Starboard Valueâ€™s Equity Portfolio Return 6.5% in Q1 0.432 0.730
# companies shld be worried about iCloud -0.329 -0.142
# Sector Stocks Leading Today 0.454 0.855
# held the trend line 0.325 0.834
# Multi-year stock breakouts 0.612 0.360
# Moved Upper Bollinger Band 0.498 0.838
# Five Stocks that Helped Starboard Valueâ€™s Equity Portfolio Return 6.5% in Q1 0.432 0.730
# Miles beyond the competition 0.278 0.372
# Slips on Downgrade -0.093 0.082
# add in 0.354 0.850
# Buy the dip' 0.38 0.794
# Price experiencing early rejection -0.228 0.614
# In Play Longs 0.273 0.848
# Will be adding on dips 0.154 0.771
# Moved Upper Bollinger Band 0.498 0.838
# Yahoo extends bidding deadline as interest grows 0.317 0.799
# Sold some $TSLA Puts this morning -0.211 0.603
# Top holdings 0.311 0.832
# short -0.377 0.372
# will close below  -0.453 0.182
# famous lunch hour fade down routine 0.002 0.358
# $AAPL +1.44% 0.256 0.713
# weak hands being flushed from metals and miners 0.3 0.573
# Can make HOD 0.49 0.770
# 13F Shows New Stakes in  0.468 0.815
# Omg OMG so excited!!!! 0.219 0.715
# Stay long 0.951 0.849
# I hope it gets resolved to the upside 0.042 0.662
# Best outperformers ranked 0.492 0.833
# shorts are trapped 0.226 0.583
# they want the stock too keep going up -0.294 0.632
# what's a great move 0.461 0.636
# No edge offered 0.025 0.828
# goes deep into #machinelearning and #AI territory with its new $125,000 supercomputer 0.294 0.572
# $CHK +13.56% 0.781 0.696
# Slips on Downgrade -0.093 0.082
# Same sellers we saw yesterday -0.45 0.753
#  0.172 0.765
# No need for $FB at all unless you want your content censored -0.367 0.568
# Ross Stores Upgraded to Outperform at RBC Capital Markets 0.565 0.724
# upgraded 0.439 0.707
# mrkt needs to washout -0.055 0.179
# LONGS 0.511 0.845
# downgraded to Neutral at Wedbush -0.434 0.592
# Long tech 0.384 0.818
# $TFM will have a way to go price wise to compete -0.085 0.656
# Nice day rally! 0.529 0.831
# $SQNS drops to $5.15 0.331 0.724
# soars pre-market 0.254 0.692
# China February Retail Sales: E-Commerce Remains Resilient 0.383 0.796
# Double bottom with handle buy point 0.654 0.740
# Torture....... -0.303 0.715
# high-flyers have been falling -0.501 0.106
# trails $MSFT $ORCL $GOOG $CRM $ADBE 0.179 0.801
# Quality Stocks With High Cash Returns 0.274 0.772
# running again 0.286 0.672
# don't look for a dividend at the Feb Shareholders meeting -0.2 0.602
# make a ton of money 0.382 0.695
# Unusual Call Activity 0.332 0.861
# breaks major support -0.455 0.754
# in the $3s 0.0 0.724
# Sanofi often on the wrong end of business. -0.247 0.264
# OPENING BUYER 0.412 0.661
# Notable gainers among liquid option names this morning 0.513 0.834
# Receives a Sell from Compass Point -0.45 0.682
#  0.0 0.765
# still have positive market bias 0.428 0.616
# Stochastic Overbought -0.385 -0.313
# Earnings will drive stock prices 0.218 0.687
# Why The Coal & Shipping Sectors Could Rise Again 0.418 0.642
# long 0.488 0.867
# anyone long before the flush please accept my condolences -0.606 0.588
# thinking that last entry was good but needs a push 0.207 0.502
# no position -0.118 0.825
# waiting for price to enter buy/support zone 0.358 0.755
# downgrade -0.463 0.213
# gotta hold 0.345 0.763
# still in massive weekly & monthly uptrend 0.632 0.658
# Aggressive Buy 0.587 0.819
# keeps Outperform rated 0.489 0.769
# Stochastic Overbought -0.385 -0.313
# Good to load up Be confident 0.281 0.801
# Worst performers today -0.72 0.801
# Insiders Are Selling -0.351 0.346
# Pie In The Sky 0.365 0.827
# Small caps threatening descending triangle breakdown -0.382 0.711
# Amazon has been selling surveillance cameras infected with malware -0.186 0.502
# $HTZ -0.409 0.464
# Don't hang your bull hat yet 0.412 0.583
# Alphabet Inc was just upgraded to buy 0.465 0.754
# Today I bought more 0.362 0.731
# brings upscale concept 0.22 0.628
# looking for a sharp move up in equities 0.365 0.815
# I'm betting over 52% -0.248 0.614
# careful can reverse fast -0.152 0.197
# #OwnItDon'tTradeIt 0.435 0.681
# TOP 5 STOCK PICKS 0.414 0.742
# Major skin in the game...positive. 0.471 0.828
# 100.0% increased bearish conversations -0.589 0.613
# Another Sell Rating, Sell Rating -0.513 0.281
# sold today -0.581 0.779
# Buy Call! 0.087 0.873
# Long 0.23 0.867
# UPGRADE today by MS to overweight 0.813 0.671
# Buy the dip' 0.38 0.794
# So both call/put buyers are crushed -0.126 0.627
# Buy stop above 80 0.295 0.603
# Airplane And Hospitality Industries Set Their Sights On #Cuba 0.405 0.778
# nice bounce 0.296 0.694
# overbought -0.296 -0.030
# Putting on a little $F short -0.454 0.252
# short some -0.464 0.668
# buying opportunity 0.445 0.796
# Scaling Up on Long Position 0.661 0.856
# its time to sell banks -0.763 0.432
# Entering long 0.627 0.847
# picked some up 0.653 0.800
# time to accumulate for a long position 0.668 0.856
# Buying $SBUX on dip 0.483 0.740
# is a short below 740 -0.48 0.359

# %%
df=pd.DataFrame.from_dict(Microblog_Trainingdata)

# %%
df['Predicted Sentiment Score']=predictions
df.head()
# Out:
#   cashtag                  id  sentiment score      source  \
# 0     $FB  719659409228451840            0.366     twitter
# 1    $LUV  719904304207962112            0.638     twitter
# 2   $NFLX             5329774           -0.494  stocktwits
# 3    $DIA  719891468173844480            0.460     twitter
# 4   $PLUG            20091246            0.403  stocktwits
#
#                                                spans  \
# 0                       watching for bounce tomorrow
# 1         record number of passengers served in 2015
# 2                                     out $NFLX -.35
# 3                        Looking for a strong bounce
# 4  Very intrigued with the technology and growth ...
#
#    Predicted Sentiment Score
# 0                   0.997842
# 1                   0.999603
# 2                   0.086584
# 3                   0.999048
# 4                   0.998973

# %%
task1Dataframe=pd.DataFrame({"ID":df['id'],"Spans":df['spans'],"Cashtag":df['cashtag'],"Sentiment Score":df['sentiment score'],"Predicted Sentiment Score":df['Predicted Sentiment Score']})
task1Dataframe=task1Dataframe[['ID','Spans','Cashtag','Sentiment Score','Predicted Sentiment Score']]
task1Dataframe.head()
# Out:
#                    ID                                              Spans  \
# 0  719659409228451840                       watching for bounce tomorrow
# 1  719904304207962112         record number of passengers served in 2015
# 2             5329774                                     out $NFLX -.35
# 3  719891468173844480                        Looking for a strong bounce
# 4            20091246  Very intrigued with the technology and growth ...
#
#   Cashtag  Sentiment Score  Predicted Sentiment Score
# 0     $FB            0.366                   0.997842
# 1    $LUV            0.638                   0.999603
# 2   $NFLX           -0.494                   0.086584
# 3    $DIA            0.460                   0.999048
# 4   $PLUG            0.403                   0.998973

# %%
#Convert dataframe to csv file
task1Dataframe.to_csv('Task1.csv',index=False)

# %% [markdown]
# ### Computing Cosine score

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
predictedVals = [pr[0] for pr in predictions ]

# %%
import numpy as np
output=np.array(output).reshape(1,-1)
predictedVals=np.array(predictedVals).reshape(1,-1)
similarity=cosine_similarity(output,predictedVals)

# %%
import nltk

# %%
from nltk.corpus import stopwords
