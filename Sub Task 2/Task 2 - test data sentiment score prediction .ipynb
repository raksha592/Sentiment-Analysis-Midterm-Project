# %% [markdown]
# # Task 2: Sentiment analysis of News Statements & Headlines

# %% [markdown]
# ### Import necessary libraries

# %%
import json
import math
import string
import os
from pprint import pprint
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as pltfrom
from sklearn.metrics.pairwise import cosine_similarity

from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras import regularizers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import nltk
from nltk.corpus import stopwords 
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
# Out:
# Using TensorFlow backend.
# {'divide': 'warn', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %% [markdown]
# ### If NLTK is not installed , download NLTK library

# %%
#if already downloaded this step is not required
#nltk.download()

# %% [markdown]
# ### Helper functions
#   1. Get stopwords from English and remove them from input data
#   2. Remove punctuations and non-ascii characters from input data
#   3. Get Avg no of words in one review
#   4. Calulating cosine similarity and cosine weight for similarity evaluation

# %%
stop = stopwords.words('english')
def removeStopWords(inputString):
    splitString = inputString.split()
    for word in stop:
        for s in splitString:
            if s == word:
                splitString.remove(s)
    return " ".join(splitString)



def stringClean( inputString ) :
    inputString = removeStopWords(inputString)
    return inputString.lower().translate(str.maketrans('','',string.punctuation)).encode("ascii", errors="ignore").decode()


def avgWords( x_train ) :
    reviewLength = 0
    for x in x_train:
        reviewLength = len(x.split())+ reviewLength
    return np.rint(reviewLength/ len(x_train)).astype(int)

# %% [markdown]
# ### Create X_train and X_test
# 1. Load dataset from json file
# 2. Prepare X_train and X_test using data processing functions above
# 3. Convert Y_train in required format

# %%
with open("Headline_Trainingdata.json") as f:
    reviews_train = json.load(f)

with open("Headline_Trialdata.json") as f:
    reviews_trial = json.load(f)

with open("Headlines_Testdata.json", encoding="utf8") as f:
    reviews_test = json.load(f)

reviewLength = 0

X_train = []
#X_test = [stringClean(review['title']).replace(review['company'].lower(), "") for review in reviews_test]
Y_train = []

for review in reviews_train :
    X_train.append(stringClean(review['title']).replace(review['company'].lower(),""))
    Y_train.append(0 if review['sentiment']<0 else 1)
    
for review in reviews_trial :
    reviews_train.append(review)
    X_train.append(stringClean(review['title']).replace(review['company'].lower(),""))
    Y_train.append(0 if review['sentiment']<0 else 1)

# %%
reviewLength = avgWords(X_train)
#print("Avg Length of title:",reviewLength)
#print(X_train)

# %% [markdown]
# ###  Tokenize the data and pad review if it has less than avg length

# %%
tokenizer = Tokenizer(num_words=reviewLength*50)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen=(reviewLength))

# %% [markdown]
# ### Build model
#    1. Embedding layer , 1 LSTM and 1 Dense layer
#    2. Dense layer has 'tanh' as activation function.
#    3. tanh function is a sigmoidal (“s”-shaped), with outputs values in range (-1, 1).

# %%
model = Sequential()
model.add(Embedding(reviewLength*50, 16, input_length=reviewLength))
model.add(LSTM(16, dropout=0.35, recurrent_dropout=0.35))
#model.add(Dense(8, activation='linear',kernel_regularizer=regularizers.l2(0.5), activity_regularizer=regularizers.l1(0.5)))
#model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 7, 16)             5600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                2112
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 7,729
# Trainable params: 7,729
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train model with validation split 0.25 and 25 epochs

# %%
history = model.fit(data, np.array(Y_train),validation_split=0.3, epochs=25 ,verbose = 2,shuffle = True)

#plot_training_curves(history.history);
# Out:
# Train on 809 samples, validate on 347 samples
# Epoch 1/25
# 2s - loss: 1.9009 - acc: 0.3832 - val_loss: 1.1060 - val_acc: 0.4323
# Epoch 2/25
# 0s - loss: 1.0121 - acc: 0.3832 - val_loss: 0.8265 - val_acc: 0.4323
# Epoch 3/25
# 0s - loss: 0.7780 - acc: 0.4302 - val_loss: 0.7096 - val_acc: 0.4957
# Epoch 4/25
# 0s - loss: 0.6974 - acc: 0.5624 - val_loss: 0.6951 - val_acc: 0.5562
# Epoch 5/25
# 0s - loss: 0.6691 - acc: 0.5958 - val_loss: 0.6825 - val_acc: 0.5879
# Epoch 6/25
# 0s - loss: 0.6583 - acc: 0.6106 - val_loss: 0.6685 - val_acc: 0.6052
# Epoch 7/25
# 0s - loss: 0.6307 - acc: 0.6663 - val_loss: 0.6565 - val_acc: 0.6196
# Epoch 8/25
# 0s - loss: 0.6068 - acc: 0.6885 - val_loss: 0.6415 - val_acc: 0.6369
# Epoch 9/25
# 0s - loss: 0.5782 - acc: 0.7169 - val_loss: 0.6246 - val_acc: 0.6599
# Epoch 10/25
# 0s - loss: 0.5433 - acc: 0.7565 - val_loss: 0.6098 - val_acc: 0.6686
# Epoch 11/25
# 0s - loss: 0.5118 - acc: 0.7911 - val_loss: 0.5962 - val_acc: 0.6830
# Epoch 12/25
# 0s - loss: 0.4819 - acc: 0.7701 - val_loss: 0.5891 - val_acc: 0.6772
# Epoch 13/25
# 0s - loss: 0.4496 - acc: 0.7998 - val_loss: 0.5886 - val_acc: 0.6744
# Epoch 14/25
# 0s - loss: 0.4245 - acc: 0.8146 - val_loss: 0.5866 - val_acc: 0.6859
# Epoch 15/25
# 0s - loss: 0.4258 - acc: 0.8220 - val_loss: 0.5981 - val_acc: 0.6772
# Epoch 16/25
# 0s - loss: 0.3834 - acc: 0.8319 - val_loss: 0.6059 - val_acc: 0.6801
# Epoch 17/25
# 0s - loss: 0.3842 - acc: 0.8307 - val_loss: 0.6194 - val_acc: 0.6744
# Epoch 18/25
# 0s - loss: 0.3532 - acc: 0.8405 - val_loss: 0.6327 - val_acc: 0.6859
# Epoch 19/25
# 0s - loss: 0.3510 - acc: 0.8319 - val_loss: 0.7019 - val_acc: 0.6801
# Epoch 20/25
# 0s - loss: 0.3263 - acc: 0.8492 - val_loss: 0.7189 - val_acc: 0.6715
# Epoch 21/25
# 0s - loss: 0.3221 - acc: 0.8517 - val_loss: 0.7400 - val_acc: 0.6686
# Epoch 22/25
# 0s - loss: 0.3133 - acc: 0.8517 - val_loss: 0.7616 - val_acc: 0.6628
# Epoch 23/25
# 0s - loss: 0.2987 - acc: 0.8467 - val_loss: 0.7865 - val_acc: 0.6599
# Epoch 24/25
# 0s - loss: 0.3207 - acc: 0.8628 - val_loss: 0.7979 - val_acc: 0.6657
# Epoch 25/25
# 0s - loss: 0.2912 - acc: 0.8677 - val_loss: 0.8143 - val_acc: 0.6657

# %%
np.random.seed(400)
temp = np.random.randint(0,len(reviews_test), size=100)
X_test = []
randomData = []
for i in temp:
    randomData.append(reviews_test[i])
    X_test.append(stringClean(reviews_test[i]['title']).replace(reviews_test[i]['company'].lower(), ""))

# %% [markdown]
# ### Tokenize Testing data and predict sentiment scores for test data

# %%
sequences = tokenizer.texts_to_sequences(X_test)
data = pad_sequences(sequences, maxlen=reviewLength)
testPredictions = model.predict(data)

# %% [markdown]
# ### Create a dataframe of results and create a csv file

# %%
testData = pd.DataFrame.from_dict(randomData)
testData['Predicted Sentiment Score'] = testPredictions
testData = testData[['id', 'company', 'title','Predicted Sentiment Score']]

if os.path.exists("TestPredictions.csv"):
    os.remove("TestPredictions.csv")

testData.to_csv("TestPredictions.csv", index = False)

# %%
testData
# Out:
#       id                           company  \
# 0   1492                             Shell
# 1   1607                            Diageo
# 2   1462                            Amazon
# 3   1585                     Standard Life
# 4   1284                     Standard Life
# 5   1551                         SABMiller
# 6   1406                   Johnson Matthey
# 7   1389                       AstraZeneca
# 8   1280                     Standard Life
# 9   1251           Berkshire Hathaway Inc.
# 10  1335  Royal Bank of Scotland Group plc
# 11  1342                              HSBC
# 12  1171          Associated British Foods
# 13  1502                       AstraZeneca
# 14  1431                         Rio Tinto
# 15  1306                          Unilever
# 16  1145                             Shell
# 17  1311                         SABMiller
# 18  1414                         Persimmon
# 19  1225                          Barclays
# 20  1469                    Daiichi Sankyo
# 21  1322                                BP
# 22  1167                    Travis Perkins
# 23  1421                           Baxalta
# 24  1350                          BT Group
# 25  1404                             Shell
# 26  1499                         Intertain
# 27  1321                     Standard Life
# 28  1514                       Sainsbury's
# 29  1542                         Tesco PLC
# ..   ...                               ...
# 70  1290                             Tesco
# 71  1611                         Persimmon
# 72  1493                  Imperial Tobacco
# 73  1295                             Shire
# 74  1489        Great Portland Estates plc
# 75  1147                   GlaxoSmithKline
# 76  1159                              AdeS
# 77  1452         Legal & General Group Plc
# 78  1356                              HSBC
# 79  1400                    LloydsPharmacy
# 80  1357   Direct Line Insurance Group PLC
# 81  1217                          BG Group
# 82  1367                                BP
# 83  1416          Lloyds Banking Group PLC
# 84  1492                             Shell
# 85  1609                       AstraZeneca
# 86  1242                         Persimmon
# 87  1508                             Heinz
# 88  1630                          Barclays
# 89  1288                             Shell
# 90  1598                          Barclays
# 91  1633                               GSK
# 92  1314                          BG Group
# 93  1295                             Shire
# 94  1167                    Travis Perkins
# 95  1480                      BHP Billiton
# 96  1306                          Unilever
# 97  1215                          Barclays
# 98  1513                             Shell
# 99  1222                          Barclays
#
#                                                 title  \
# 0   Shell's Arctic return faces hurdle at Seattle ...
# 1   Britain's FTSE recovers two-month low after Di...
# 2   Jim Armitage: Amazon is Primed to deliver pain...
# 3   Industry NewsStandard Life enjoys strong inflo...
# 4                              Standard Life Elevates
# 5       SABMiller revenue hit by weaker EM currencies
# 6   Johnson Matthey share price slumps as company ...
# 7   Why AstraZeneca plc & Dixons Carphone PLC Are ...
# 8   Property Stocks Slump After Standard Life Free...
# 9   Berkshire holders hit Buffett with hard questions
# 10             RBS turns away savers in latest glitch
# 11  Ingenious, HSBC, UBS and Coutts sued by 'tax a...
# 12  Associated British Foods raises guidance as st...
# 13  AstraZeneca lupus drug cuts disease activity i...
# 14  Rio Tinto CEO says iron ore market at equilibrium
# 15  Unilever profit rises despite sales slump in C...
# 16   EU regulators clear Shell's takeover of BG Group
# 17     AB InBev looks to win over SABMiller investors
# 18  Persimmon makes strong start, but notes pre-el...
# 19  Priceline's stock jumps to new high for the ye...
# 20  AstraZeneca Teams With Daiichi Sankyo To Sell ...
# 21  BP to slash 4000 jobs globally as oil prices drop
# 22  UK builders' merchant Travis Perkins reports s...
# 23  Drugmaker Shire bids $30 bln for Baxter spin-o...
# 24  BT share price: Watchdog bans telco's broadban...
# 25  Shell eyes $700 million exit from Gabon - sources
# 26                 Intertain considers London listing
# 27      Standard Life chief agrees Â£600000 bonus cut
# 28  Sainsbury's share price: Supermarket pushes ah...
# 29  Can Christmas Save Sainsbury's plc And Tesco plc?
# ..                                                ...
# 70  Krispy Kreme bring delicious doughnuts to Mary...
# 71  BRIEF-Persimmon says too soon to judge effect ...
# 72  Imperial Tobacco launches caffeinated mouth st...
# 73        Britain's FTSE forges ahead as Shire surges
# 74  Should you buy Associated British Foods plc, G...
# 75                GlaxoSmithKline acquires HIV assets
# 76  The Coca-Cola Company and Coca-Cola FEMSA to A...
# 77  Legal & General eyes company deals as individu...
# 78  HSBC to sell Bermuda trust and investment mana...
# 79             Sainsbury sells unit to LloydsPharmacy
# 80  Are Aviva plc, Direct Line Insurance Group PLC...
# 81  Shell share price: Standard Life announce posi...
# 82  Oil majors like Royal Dutch Shell, Chevron, BP...
# 83  UK to raise 9 billion pounds through Lloyds sh...
# 84  Shell's Arctic return faces hurdle at Seattle ...
# 85  CompaniesAstraZeneca shares hit as 2016 revenu...
# 86     Builder Persimmon hails 6% rise in house sales
# 87  How Kraft-Heinz Merger Came Together in Speedy...
# 88  Exclusive: Barclays reins in foreign exchange ...
# 89  Shell CEO warns renewables shift could spell e...
# 90         Barclays To Pay Ousted Boss Â£500000 Bonus
# 91  GSK and Novartis complete deals to reshape bot...
# 92    Shell to buy BG Group in $69.7 billion takeover
# 93        Britain's FTSE forges ahead as Shire surges
# 94  UK builders' merchant Travis Perkins reports s...
# 95  European stocks hover near 3-week low, Dialog ...
# 96  Unilever profit rises despite sales slump in C...
# 97  DBS, Julius Baer emerge as potential bidders f...
# 98  Exclusive - Shell CEO warns Brexit could slow ...
# 99  PRESS: Barclays To Cut More Than 30000 Jobs - ...
#
#     Predicted Sentiment Score
# 0                   -0.335834
# 1                    0.290011
# 2                    0.472891
# 3                    0.861770
# 4                    0.472891
# 5                    0.159084
# 6                    0.384013
# 7                    0.934580
# 8                   -0.123446
# 9                    0.174216
# 10                   0.345250
# 11                  -0.211669
# 12                   0.607975
# 13                   0.418615
# 14                   0.908202
# 15                   0.996982
# 16                   0.983228
# 17                   0.906422
# 18                   0.976327
# 19                   0.999738
# 20                   0.922161
# 21                   0.359278
# 22                   0.990210
# 23                   0.889665
# 24                   0.403524
# 25                   0.851371
# 26                   0.640622
# 27                  -0.047419
# 28                   0.759335
# 29                   0.138006
# ..                        ...
# 70                   0.472891
# 71                   0.552794
# 72                   0.937462
# 73                   0.954945
# 74                   0.999635
# 75                   0.985836
# 76                   0.992909
# 77                   0.398900
# 78                   0.396361
# 79                   0.985390
# 80                   0.999645
# 81                   0.106856
# 82                  -0.062784
# 83                   0.115921
# 84                  -0.335834
# 85                  -0.096845
# 86                   0.643466
# 87                   0.874317
# 88                   0.763870
# 89                   0.238573
# 90                   0.402158
# 91                   0.560186
# 92                   0.993677
# 93                   0.954945
# 94                   0.990210
# 95                   0.520902
# 96                   0.996982
# 97                   0.963520
# 98                   0.014737
# 99                   0.977796
#
# [100 rows x 4 columns]
