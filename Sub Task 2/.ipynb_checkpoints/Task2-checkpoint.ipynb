# %% [markdown]
# # Task 2: Sentiment analysis of News Statements & Headlines

# %% [markdown]
# ### Import necessary libraries

# %%
import json
import math
import string
import os
from pprint import pprint
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as pltfrom
from sklearn.metrics.pairwise import cosine_similarity

from keras.layers import Embedding, LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Activation
from keras.models import Sequential
from keras import regularizers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import nltk
from nltk.corpus import stopwords 
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
# Out:
# Using TensorFlow backend.
# {'divide': 'warn', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %% [markdown]
# ### If NLTK is not installed , download NLTK library

# %%
#if already downloaded this step is not required
#nltk.download()

# %% [markdown]
# ### Helper functions
#   1. Get stopwords from English and remove them from input data
#   2. Remove punctuations and non-ascii characters from input data
#   3. Get Avg no of words in one review
#   4. Calulating cosine similarity and cosine weight for similarity evaluation

# %%
stop = stopwords.words('english')
def removeStopWords(inputString):
    splitString = inputString.split()
    for word in stop:
        for s in splitString:
            if s == word:
                splitString.remove(s)
    return " ".join(splitString)



def stringClean( inputString ) :
    inputString = removeStopWords(inputString)
    return inputString.lower().translate(str.maketrans('','',string.punctuation)).encode("ascii", errors="ignore").decode()


def calculateCosineSimilarity( pVal,gVal ):
    similarity = cosine_similarity(pVal,gVal)
    pNorm = np.linalg.norm(pVal)
    gNorm = np.linalg.norm(gVal)
    wt = pNorm/gNorm
    return wt * similarity[0][0]
    

def avgWords( x_train ) :
    reviewLength = 0
    for x in x_train:
        reviewLength = len(x.split())+ reviewLength
    return np.rint(reviewLength/ len(x_train)).astype(int)

# %% [markdown]
# ### Create X_train and X_test
# 1. Load dataset from json file
# 2. Prepare X_train and X_test using data processing functions above
# 3. Convert Y_train in required format

# %%
with open("Headline_Trainingdata.json") as f:
    reviews_train = json.load(f)

with open("Headline_Trialdata.json") as f:
    reviews_trial = json.load(f)

with open("Headlines_Testdata.json", encoding="utf8") as f:
    reviews_test = json.load(f)

reviewLength = 0

X_train = []
X_test = [stringClean(review['title']).replace(review['company'].lower(), "") for review in reviews_test]
output = []
Y_train = []

for review in reviews_train :
    X_train.append(stringClean(review['title']).replace(review['company'].lower(),""))
    Y_train.append(0 if review['sentiment']<0 else 1)
    output.append(review['sentiment'])
    
for review in reviews_trial :
    reviews_train.append(review)
    X_train.append(stringClean(review['title']).replace(review['company'].lower(),""))
    Y_train.append(0 if review['sentiment']<0 else 1)
    output.append(review['sentiment'])

# %%
reviewLength = avgWords(X_train)
#print("Avg Length of title:",reviewLength)
#print(X_train)

# %% [markdown]
# ###  Tokenize the data and pad review if it has less than avg length

# %%
tokenizer = Tokenizer(num_words=reviewLength*50)
tokenizer.fit_on_texts(X_train)
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen=(reviewLength))

# %% [markdown]
# ### Build model
#    1. Embedding layer , 1 LSTM and 1 Dense layer
#    2. Dense layer has 'tanh' as activation function.
#    3. tanh function is a sigmoidal (“s”-shaped), with outputs values in range (-1, 1).

# %%
model = Sequential()
model.add(Embedding(reviewLength*50, 16, input_length=reviewLength))
model.add(LSTM(16, dropout=0.35, recurrent_dropout=0.35))
#model.add(Dense(8, activation='linear',kernel_regularizer=regularizers.l2(0.5), activity_regularizer=regularizers.l1(0.5)))
#model.add(Dense(4, activation='linear'))
model.add(Dense(1, activation='tanh'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None,
# 0s - loss: 0.3504 - acc: 0.8418 - val_loss: 0.6941 - val_acc: 0.6888
# Epoch 22/25
# 0s - loss: 0.3445 - acc: 0.8368 - val_loss: 0.7009 - val_acc: 0.6859
# Epoch 23/25
# 0s - loss: 0.3249 - acc: 0.8529 - val_loss: 0.7160 - val_acc: 0.6715
# Epoch 24/25
# 0s - loss: 0.3225 - acc: 0.8541 - val_loss: 0.7387 - val_acc: 0.6686
# Epoch 25/25
# 0s - loss: 0.3171 - acc: 0.8430 - val_loss: 0.7561 - val_acc: 0.6686

# %% [markdown]
# ### Predict sentiment scores for given training data

# %%
sequences = tokenizer.texts_to_sequences(X_train)
data = pad_sequences(sequences, maxlen=reviewLength)
predictions = model.predict(data)

# %% [markdown]
# ### Calculate cosine similarity

# %%
predictedVals = [pr[0] for pr in predictions ]
output = np.array(output).reshape(1,-1)
predictedVals = np.array(predictedVals).reshape(1,-1)


print("Final cosine score :",calculateCosineSimilarity(predictedVals,output))
# Out:
# Final cosine score : 0.693287894111

# %% [markdown]
# ### Create a dataframe of results and create a csv file

# %%
df = pd.DataFrame.from_dict(reviews_train)
df['Predicted Sentiment Score'] = predictedVals[0]
df = df[['id', 'company', 'title','sentiment','Predicted Sentiment Score']]

if os.path.exists("Task2.csv"):
    os.remove("Task2.csv")

df.to_csv('Task2.csv', index = False)

# %%
df
# Out:
#         id                        company  \
# 0        2                      Morrisons
# 1        3                            IMI
# 2        4                       Glencore
# 3        5                        Ryanair
# 4        6                       Barclays
# 5        7                             BP
# 6        8  Bilfinger Industrial Services
# 7        9                       Barclays
# 8       10                   Centrica PLC
# 9       11                       Glencore
# 10      12                       Barclays
# 11      13                     Kingfisher
# 12      14                         Diageo
# 13      15                 Smith & Nephew
# 14      16                      Tesco PLC
# 15      17      Legal & General Group Plc
# 16      18                      Tesco PLC
# 17      19                      Schroders
# 18      20                             BP
# 19      21         Standard Chartered PLC
# 20      22                             BP
# 21      23                   Friends Life
# 22      24                            L&G
# 23      25                        Admiral
# 24      26                      Whitbread
# 25      27                     Kingfisher
# 26      28                   Novo Nordisk
# 27      29                   Mr Bricolage
# 28      30                             BP
# 29      31                Dixons Carphone
# ...    ...                            ...
# 1126  1128                   Centrica PLC
# 1127  1129                    AstraZeneca
# 1128  1130    London Stock Exchange Group
# 1129  1131              Royal Dutch Shell
# 1130  1132                       Barclays
# 1131  1133                       AB InBev
# 1132  1134        Berkshire Hathaway Inc.
# 1133  1135                Marks & Spencer
# 1134  1136             Balfour Beatty plc
# 1135  1137                            CIB
# 1136  1138                       BG Group
# 1137  1139                          Glaxo
# 1138  1140                       Barclays
# 1139  1141                     Kingfisher
# 1140  1142                 Travis Perkins
# 1141  1143         Standard Chartered PLC
# 1142    23                          Tesco
# 1143    90                            CRH
# 1144    91                 Holcim Lafarge
# 1145    98                  Reed Elsevier
# 1146   239                     Kingfisher
# 1147   240                   Mr Bricolage
# 1148   261                       Glencore
# 1149   304                         Diageo
# 1150   675                          Shell
# 1151  1210                          Shire
# 1143       CRH's concrete bid for Holcim Lafarge assets      0.300
# 1144       CRH's concrete bid for Holcim Lafarge assets      0.300
# 1145  Reed Elsevier share price slides on underwhelm...     -0.900
# 1146  Kingfisher bid for Mr Bricolage runs into trouble     -0.300
# 1147  Kingfisher bid for Mr Bricolage runs into trouble     -0.300
# 1148           Glencore's annual results beat forecasts      0.900
# 1149    Diageo stays neutral on India boardroom turmoil     -0.200
# 1150             Shell to Cut 6500 Jobs as Profit Drops     -1.000
# 1151  Markets Shire up 2.5% and Baxalta up 6% on $32...      0.800
# 1152  Markets Shire up 2.5% and Baxalta up 6% on $32...      0.800
# 1153  BP ends 27-year sponsorship of Tate as falling...     -0.200
# 1154  HSBC, Standard Chartered Lead Asia Bank Rout a...     -1.000
# 1155  HSBC, Standard Chartered Lead Asia Bank Rout a...     -1.000
#
#       Predicted Sentiment Score
# 0                      0.464543
# 1                     -0.255118
# 2                      0.978871
# 3                      0.734458
# 4                     -0.109057
# 5                      0.674402
# 6                      0.744841
# 7                     -0.099029
# 8                      0.957207
# 9                      0.188092
# 10                     0.840118
# 11                     0.619289
# 12                     0.292554
# 13                     0.441179
# 14                     0.407589
# 15                     0.521875
# 16                     0.297553
# 17                     0.901478
# 18                     0.995278
# 19                     0.860186
# 20                    -0.439346
# 21                     0.994725
# 22                     0.144853
# 23                     0.975447
# 24                     0.940343
# 25                     0.739939
# 26                     0.965513
# 27                     0.141731
# 28                     0.891560
# 29                     0.918153
# ...                         ...
# 1126                   0.350920
# 1127                   0.800630
# 1128                   0.619497
# 1129                   0.132601
# 1130                  -0.113740
# 1131                   0.983430
# 1132                   0.979571
# 1133                   0.631855
# 1134                   0.998920
# 1135                   0.814357
# 1136                   0.998030
# 1137                   0.827263
# 1138                   0.563332
# 1139                   0.658638
# 1140                   0.995520
# 1141                   0.252478
# 1142                  -0.176329
# 1143                   0.461003
# 1144                   0.504192
# 1145                   0.488431
# 1146                  -0.008725
# 1147                  -0.008725
# 1148                   0.828996
# 1149                   0.441179
# 1150                   0.543440
# 1151                   0.952386
# 1152                   0.980184
# 1153                  -0.210224
# 1154                   0.856959
# 1155                   0.870742
#
# [1156 rows x 5 columns]

# %% [markdown]
# ### Tokenize Testing data and predict sentiment scores for test data

# %%
sequences = tokenizer.texts_to_sequences(X_test)
data = pad_sequences(sequences, maxlen=reviewLength)
testPredictions = model.predict(data)

# %% [markdown]
# ### Create a dataframe of results and create a csv file

# %%
testData = pd.DataFrame.from_dict(reviews_test)
testData['Predicted Sentiment Score'] = testPredictions
testData = testData[['id', 'company', 'title','Predicted Sentiment Score']]

if os.path.exists("TestPredictions_Task2.csv"):
    os.remove("TestPredictions_Task2.csv")

testData.to_csv("TestPredictions_Task2.csv", index = False)

# %%
testData
# Out:
#        id                           company  \
# 0    1144                           Ashtead
# 1    1145                             Shell
# 2    1146                        Prudential
# 3    1147                   GlaxoSmithKline
# 4    1148                          Barclays
# 5    1149                            Diageo
# 6    1150           Borealis Infrastructure
# 7    1151                Burberry Group plc
# 8    1152                   Deutsche Boerse
# 9    1153                         Tesco PLC
# 10   1154                       AstraZeneca
# 11   1155                             Shire
# 12   1156                        Royal Mail
# 13   1157                        Royal Mail
# 14   1158                               ITV
# 15   1159                              AdeS
# 16   1160                          Barclays
# 17   1161                         Morrisons
# 18   1162               Hargreaves Lansdown
# 19   1163                          MOVANTIK
# 20   1164                           EasyJet
# 21   1165                               WPP
# 22   1166                        Old Mutual
# 23   1167                    Travis Perkins
# 24   1168                       AstraZeneca
# 25   1169                          Glencore
# 26   1170                            Acerta
# 27   1171          Associated British Foods
# 28   1172                     Pearson Jones
# 29   1173                             Bunzl
# ..    ...                               ...
# 461  1605                               WPP
# 462  1606                               G4S
# 463  1607                            Diageo
# 464  1608                          Glencore
# 465  1609                       AstraZeneca
# 466  1610                      Crown Castle
# 467  1611                         Persimmon
# 468  1612                         Morrisons
# 469  1613                          Barclays
# 470  1614                   GlaxoSmithKline
# 471  1615                          Petrofac
# 472  1616                   Economist Group
# 473  1617                          Glencore
# 474  1618                         SABMiller
# 475  1619                          Barclays
# 476  1620                       AstraZeneca
# 477  1621                       AstraZeneca
# 478  1622                           Giraffe
# 479  1623  Royal Bank of Scotland Group plc
# 480  1624                         Whitbread
# 481  1625                          Actelion
# 482  1626                           Ashtead
# 483  1627  Royal Bank of Scotland Group plc
# 484  1628                     Premier Foods
# 485  1629                          Barclays
# 486  1630                          Barclays
# 487  1631                          Barclays
# 488  1632                          Glencore
# 489  1633                               GSK
# 490  1634                       AstraZeneca
#
#                                                  title  \
# 0    Ashtead to buy back shares, full-year profit b...
# 1     EU regulators clear Shell's takeover of BG Group
# 2    UK's FTSE has worst day so far in 2015 as BG a...
# 3                  GlaxoSmithKline acquires HIV assets
# 4              Barclays faces another heavy forex fine
# 5    Diageo Shares Surge on Report of Possible Take...
# 6    Borealis Infrastructure putting together new S...
# 7    FTSE 100 falls as China devaluation hits Burbe...
# 8    London Stock Exchange â€“ Deutsche Boerse merg...
# 9    Tesco Abandons Video-Streaming Ambitions in Bl...
# 10   UPDATE 1-AstraZeneca sells rare cancer drug to...
# 11   Homebuilders, Shire Gains Spur FTSE 100 to Ral...
# 12    CompaniesRoyal Mail adds a penny to stamp prices
# 13   Royal Mail shares fall as Ofcom publishes disc...
# 14    ITV backs Carl Frampton to revive the glory days
# 15   The Coca-Cola Company and Coca-Cola FEMSA to A...
# 16   Ex-Barclays Trader in Libor Case Says Boss Hit...
# 17   Morrisons warns of long road to recovery after...
# 18   Hargreaves Lansdown posts record inflows in 4 ...
# 19   AstraZeneca And Daiichi Sankyo To Jointly Comm...
# 20   EasyJet Passenger Numbers And Load Factor Impr...
# 21   WPP wins race for 'programmatic buying' agency...
# 22           Old Mutual nears deal to sell US business
# 23   UK builders' merchant Travis Perkins reports s...
# 24   Clinigen chosen by AstraZeneca to manage acces...
# 25   CompaniesGlencore shares hit 3-month high afte...
# 26   AstraZeneca weighing up Acerta bid to secure b...
# 27   Associated British Foods raises guidance as st...
# 28   Standard Life share price: Insurer buys advice...
# 29   Bunzl Lifts Dividend Again As Acquisitions Con...
# ..                                                 ...
# 461  Chime Communications Set To Be Acquired By WPP...
# 462  G4S sees profits rise but UK contract problems...
# 463  Britain's FTSE recovers two-month low after Di...
# 464  METALS-London copper climbs as shorts cover on...
# 465  CompaniesAstraZeneca shares hit as 2016 revenu...
# 466  Crown Castle buys Tower Development Corp for $...
# 467  BRIEF-Persimmon says too soon to judge effect ...
# 468      Profit slumps at troubled UK grocer Morrisons
# 469  U.K. Stocks Little Changed Near Record as Barc...
# 470             FTSE led lower by M&S, GlaxoSmithKline
# 471  Petrofac share price rises despite Â£30m costs...
# 472  Pearson in Talks to Sell Its Stake in the Econ...
# 473  Investor body in talks with Glencore on $2.5 b...
# 474  Japan's Asahi to submit bid next week for SABM...
# 475  Understated approach of Jenkins failed to win ...
# 476  UPDATE 1-AstraZeneca boosts respiratory unit w...
# 477  AstraZeneca agrees licensing deal for Plendil ...
# 478  Tesco set to sell Kipa, Giraffe businesses - S...
# 479    Foreign exchange probes push RBS to Â£446m loss
# 480    Whitbread share price climbs on Q4 sales growth
# 481  CompaniesActelion shares hit record on Shire t...
# 482  UK Stocks Little Changed as Ashtead Gains, Hou...
# 483  Standard Chartered, RBS Escape Capital Raising...
# 484  CommentOpening Quote: Tesco; Premier Foods jil...
# 485  Barclays share price: Investment bank to shrin...
# 486  Exclusive: Barclays reins in foreign exchange ...
# 487  Copper Falls With Mining Stocks as Barclays Wa...
# 488  LPC-Glencore launches refinancing of US$8.45bn...
# 489  GSK and Novartis complete deals to reshape bot...
# 490  Sanofi poaches AstraZeneca scientist as new re...
#
#      Predicted Sentiment Score
# 0                     0.999726
# 1                     0.993910
# 2                    -0.216989
# 3                     0.930236
# 4                    -0.291009
# 5                     0.884915
# 6                     0.775076
# 7                     0.821193
# 8                     0.307793
# 9                     0.456814
# 10                    0.995039
# 11                    0.801772
# 12                    0.699190
# 13                   -0.000513
# 14                    0.623160
# 15                    0.984905
# 16                   -0.176737
# 17                   -0.060700
# 18                   -0.048208
# 19                    0.993610
# 20                    0.624227
# 21                    0.899554
# 22                    0.673006
# 23                    0.987624
# 24                    0.842865
# 25                    0.871974
# 26                    0.999079
# 27                    0.546925
# 28                    0.817300
# 29                    0.991676
# ..                         ...
# 461                   0.759897
# 462                   0.998853
# 463                   0.369792
# 464                   0.441179
# 465                   0.000171
# 466                   0.592965
# 467                   0.372492
# 468                   0.515463
# 469                   0.277120
# 470                   0.402027
# 471                   0.803815
# 472                   0.469911
# 473                   0.465444
# 474                   0.868572
# 475                   0.941191
# 476                   0.982485
# 477                   0.866513
# 478                   0.723996
# 479                  -0.204631
# 480                   0.261902
# 481                   0.631474
# 482                   0.809770
# 483                   0.534397
# 484                   0.407589
# 485                   0.379607
# 486                   0.653736
# 487                  -0.079006
# 488                   0.983039
# 489                   0.523502
# 490                   0.677418
#
# [491 rows x 4 columns]
